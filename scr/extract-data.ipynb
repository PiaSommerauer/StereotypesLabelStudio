# %% [markdown]
# # Analyze LS output - Dataset Chiara

# %%
import json
import csv
from collections import defaultdict
import spacy
import pandas as pd
import os

# %%
nlp = spacy.load("nl_core_news_sm")

# %%
# labels

labels = [
    "TC-reference",
    "Behav-predicate",
    "individual-TG-levels",
    "middle-TG-levels",
    "high-TG-levels",
    "supra-TG-levels",
    "Exclude", 
    "ChatGPT: punctution",
    "ChatGPT: emoji",
    "Misunderstood task",
    "No consent",
    "Less than 20 words",
    "No consent",
    "Did not finish the study",
    "WPM"

    # negations
    # opposite target category references
]

#    <Header value="Is there a reason to exclude the text?"/>

#     <Choices name="Exclude" toName="text" choice="multiple" showInLine="true">
#     <Choice value="ChatGPT: punctution"/>

#      <Choice value="ChatGPT: structure"/>

#      <Choice value="ChatGPT: emoji"/>

#      <Choice value="Misunderstood task"/>

#      <Choice value="Less than 20 words"/>

#      <Choice value="No consent"/>

#      <Choice value="Did not finish the study"/>

#      <Choice value="WPM"/>


#   </Choices>

# %%
# with open('Chiara_full_dataset/labels-chiara.txt') as infile:
#     labels = [l.strip().strip("'").strip('"') for l in infile.read().strip().split('\n')]
# # labels

# %%
def get_labels(annotations):
    offset_label_dict = defaultdict(list)
    id_relation_dict = defaultdict(list)
    # sort_annotations_by_id
    id_ann_dict = defaultdict(list)
    id_name_dict = dict()
    span_relations_dict = dict()
    text_level = []

    for an in annotations:
        labels_relations = an['result']
        for la in labels_relations:
            # check if label:
            # print(la)
            # print()
            if 'value' in la:
                target_an = la['value']
                if "start" in target_an:
                    start = target_an['start']
                    end = target_an['end']
                    ann_id = la['id']
                    id_ann_dict[ann_id].append(la)
                    for i in range(start, end):
                        offset_label_dict[i].append(la)
                    if 'labels' in target_an:
                        id_name_dict[ann_id] = target_an['labels'][0]
                elif "choices" in target_an:
                    print("no start key but choices")
                    print(target_an)
                    text_level = target_an['choices']
                
                
                # print('offsets')
                # print(start, la, type(start))
                

            elif 'from_id' in la:
                from_id = la['from_id']
                to_id = la['to_id']
                id_relation_dict[(from_id, to_id)].append(la)
                if 'labels' in la:
                    print('relation has labels')
                    print(la['labels'])
                    print()
                    span_relations_dict[(from_id, to_id)] = la['labels']
                
                    
            else:
                print(la)
    return offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict, text_level




def get_chains(id_relations_dict):
    chains = defaultdict(set)
    coref_id = dict()
    n = 0
    for rel_pair, relations in id_relations_dict.items():
        rel1, rel2 = rel_pair

        if n == 0:
            chains[0].add(rel1)
            chains[0].add(rel2)
            n+=1 

        else:
            added = False
            for pair_n, chain in chains.items():
                if rel1 in chain:
                    chain.add(rel2)
                    added = True
                if rel2 in chain:
                    chain.add(rel1)
                    added = True
            if added == False:
                chains[n].add(rel1)
                chains[n].add(rel2)
                n+=1

    for chain_id, chain in chains.items():
        for label_id in chain:
            coref_id[label_id] = chain_id

    return chains, coref_id

#separate_chains(token_data)

def filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2=None):
 # Filter relations on labels
    id_rel_dict_target = dict()
    if target_label2 is None:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
            
                    
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
                    all_labels = [l for l in l['value']['labels']]
                    if len(all_labels) > 1:
                        print('found more labels:', len(all_labels))
            if l1_name == l2_name:
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
    else:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
        
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
            if ((l1_name == target_label1) and (l2_name == target_label2) 
            or (l1_name == target_label2) and (l2_name == target_label1)):
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
        
    return id_rel_dict_target

        
    
def add_singletons(token_data):
    
    coref_ids = []
    for d in token_data:
        if d['ref-relations'] != []:
            coref_ids.extend(d['ref-relations'])
    # [d['ref-relations'] for d in token_data if d['ref-relations'] != '']
    if len(coref_ids) > 0:
        max_coref_id = max(coref_ids)
    
        single_ent_id = max_coref_id +1 
    else:
        single_ent_id = 0
        
    token_data_by_cat = defaultdict(list)
    for d in token_data:
        tcs = d['TC-reference']
        for t in tcs:
            token_data_by_cat[t].append(d)
        
    
    for t, ds in token_data_by_cat.items():
        added_single_ent = False
        for d in ds:
            #rels = d['ref-relations']
            tcs = d['TC-reference']
            ref_id_rels = d['ref-id-relations']

           
            if tcs != [] and  ref_id_rels == []:
                # singleton!
                d['ref-relations'] = [single_ent_id]
                d['ref-id-relations'] = [f'{single_ent_id}-_-{t}']
                added_single_ent = True
            elif len(tcs) != len(ref_id_rels):
                rels_no_coref = [r.split('-_-')[1] for r in ref_id_rels]
                for t in tcs:
                    if t not in rels_no_coref:
                        d['ref-relations'].append(single_ent_id)
                        d['ref-id-relations'].append(f'{single_ent_id}-_-{t}')
                        added_single_ent = True
            else:
                continue
        
        if added_single_ent:
            single_ent_id += 1
            
            
def make_relation_mappings(id_relation_dict, id_name_dict):
    
    coref_mappings = dict()
    behav_mappings = defaultdict(list)
    
    for id_pair, d_list in id_relation_dict.items():
        id1, id2 = id_pair
        label1 = id_name_dict[id1]
        label2 = id_name_dict[id2]

   
        
        #if rel_type == 'ref-behav
        if label1 == label2 == 'TC-reference':
            # print('coref', label1, label2)
            coref_mappings[id1] = id2
            coref_mappings[id2] = id1
        # elif label1 == label2 == 'Behavior-predicate':
        #     pass
        elif label1 == 'Behav-predicate' and label2 == 'TC-reference':
            # 
            behav_mappings[id2].append(id1)
        elif label1 == 'TC-reference' and label2 == 'Behav-predicate':
            behav_mappings[id1].append(id2)

        #elif label1 
            
    return coref_mappings, behav_mappings

# %%
# tok_starts

# %%
### TEST COREF CHAIN CODE

name = 'kim-full-data-update1'
output = 'data'
path = f'../{output}/{name}.json'

dir_out = f'../results/{name}'
if not os.path.isdir(dir_out):
    os.mkdir(dir_out)

with open(path) as infile:
    annotation_data = json.load(infile)
    
for n, data in enumerate(annotation_data):
    ls_id = data['id']
    annotations = data['annotations']

    
    text = data['data']['text']
    text_id = text.split('\n', 1)[0].split(': ')[-1]
    print('text id', text_id)
    print('ls id', ls_id)
    path_out = f'{dir_out}/output-{text_id}_LS-id{ls_id}.csv'
    print('path out', path_out)
    
    offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict, text_level = get_labels(annotations)
    coref_mappings, behav_mappings = make_relation_mappings(id_relation_dict, id_name_dict)
    

    target_label = 'TC-reference'
    id_relations_ref = filter_relations(id_relation_dict, id_ann_dict, target_label)
    
    target_label1 = 'TC-reference'
    target_label2 =  "Behavior-predicate"
    id_relations_behav = filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2)

    span_dict_end = dict()
    # span_dict_start = dict()
    
    for (l1, l2), la in span_relations_dict.items():
        # span_dict_start[l1] = l2
        span_dict_end[l2] = l1
        
        
    coref_chains_ref, coref_dict_ref = get_chains(id_relations_ref)
    coref_chains_behav, coref_dict_behav = get_chains(id_relations_behav)
    
      
    
    doc = nlp(text)

    
    tok_id_ann_id_dict = defaultdict(set)
  
    
    for tok in doc:
        tok_start = tok.idx

        for i in range(tok.idx, tok.idx+len(tok)):
            if i in offset_label_dict:
                anns = offset_label_dict[i]
                for an in anns:
                    an_id = an['id']
                    tok_id_ann_id_dict[tok.i].add(an_id)

    token_data = []
    for tok in doc:
        
        tok_id = tok.i
        tok_dict = defaultdict(list)
        tok_dict['tok-id'] = tok_id
        tok_dict['token'] = tok.text
        tok_dict['ref-relations'] = []
        tok_dict['ref-behav-relations'] = []
        tok_dict['ref-id-relations'] = []
        tok_dict['coref-id-mapping'] = []
        tok_dict['behav-id-mapping'] = []
        tok_dict['ref-span'] = ''
                 
        # tok_dict['ref-behav-relations-new'] = ''

        #tok_dict['TC-COREF'] = ''
        for l in labels:
            tok_dict[l] = []
            if l in text_level:
                tok_dict[l] = True
            
        
        an_ids = tok_id_ann_id_dict[tok_id]
        # print(tok_id, an_ids)

        for an_id in an_ids:        
            anns = id_ann_dict[an_id]
            
     
            #rels = an_rel_dict[an_id]
            for an in anns:
                add_label = ''

                if 'from_name' in an:
                    add_label = an['from_name']
                    
                if 'labels' in an['value']:
                    label = an['value']['labels'][0]
                    if an_id in span_dict_end:
                        an_id_new = span_dict_end[an_id]
                        tok_dict[f'{label}'].append(an_id_new)
                    else:
                        tok_dict[f'{label}'].append(an_id)
                if 'choices' in an['value']:
                    for choice in an['value']['choices']:
                        if add_label != '':
                            if an_id in span_dict_end:
                                an_id_new = span_dict_end[an_id]
                                tok_dict[f'{choice}-{add_label}'].append(an_id_new)
                            else:
                                tok_dict[f'{choice}-{add_label}'].append(an_id)
                        else:
                            if an_id in span_dict_end:
                                an_id_new = span_dict_end[an_id]
                                tok_dict[choice].append(an_id_new)
                            else:
                                tok_dict[choice].append(an_id)

             # coref:
            # if an_id in coref_dict_behav:
            #     pass
            #     # if tok_dict['relations'] == '':
            #     #tok_dict['ref-behav-relations'] = coref_dict[an_id]
            #     # if an_id in span_dict_end:
            #     #     an_id_new = span_dict_end[an_id]
            #     #     tok_dict['ref-behav-relations'].append(coref_dict_behav[an_id_new])
            #     # else:
            #     #     tok_dict['ref-behav-relations'].append(coref_dict_behav[an_id])
            #     #tok_dict['ref-relations'] = coref_dict_ref[an_id]

            if an_id in coref_dict_ref:
                
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                    tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id_new}')
                else:
                    tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                    tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id}')
            
            if an_id in coref_mappings:
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    coref_id = coref_mappings[an_id]
                    if coref_id in span_dict_end:
                        coref_id = span_dict_end[coref_id]
                
                    tok_dict['coref-id-mapping'].append(f'{an_id_new}-_-{coref_id}')
                else:
                    coref_id = coref_mappings[an_id]
                    if coref_id in span_dict_end:
                        coref_id = span_dict_end[coref_id]
                    tok_dict['coref-id-mapping'].append(f'{an_id}-_-{coref_id}')
                
            if an_id in behav_mappings:
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    for behav_id in behav_mappings[an_id_new]:
                        tok_dict['behav-id-mapping'].append(f'{an_id_new}-_-{behav_id}')
                else:
                    for behav_id in behav_mappings[an_id]:
                        tok_dict['behav-id-mapping'].append(f'{an_id}-_-{behav_id}')
          
  
        token_data.append(tok_dict)


    add_singletons(token_data)
    


    
    for tok_dict in token_data:

        for k, v in tok_dict.items():
            if type(v) == list:
                v = [str(i) for i in v]
                tok_dict[k] = ' '.join(v)
            else:
                tok_dict[k] = v
                
                
    # apply span information - same id 
    df = pd.DataFrame(token_data)
    df.to_csv(path_out, index=False)
# Out:
# text id pinl2004022643db-13712588e47d Huisfeest oud txt.1
# ls id 1057
# path out ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Huisfeest oud txt.1_LS-id1057.csv
# relation has labels
# ['behav-span']
#
# text id pinl2004022643db-13712588e47d Ex oud txt.1
# ls id 1058
# path out ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Ex oud txt.1_LS-id1058.csv
# relation has labels
# ['behav-span']
#
# text id pinl2004022643db-13712588e47d Klassiek oud txt.1
# ls id 1059
# path out ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Klassiek oud txt.1_LS-id1059.csv
# text id pinl2004022643db-13712588e47d Bridge oud txt.1
# ls id 1060
# path out ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Bridge oud txt.1_LS-id1060.csv
# text id 63fd069cb47d538f11dc7ed2 Bingo oud txt.1
# ls id 1061
# path out ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 Bingo oud txt.1_LS-id1061.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id 63fd069cb47d538f11dc7ed2 MAX oud txt.1
# ls id 1062
# path out ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 MAX oud txt.1_LS-id1062.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id 63fd069cb47d538f11dc7ed2 Techno oud txt.1
# ls id 1063
# path out ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 Techno oud txt.1_LS-id1063.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id 63fd069cb47d538f11dc7ed2 Mario oud txt.1
# ls id 1064
# path out ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 Mario oud txt.1_LS-id1064.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'ChatGPT: emoji', 'WPM']}
# text id 6310a5b5af42fb718e0f203b Mario jong txt
# ls id 1065
# path out ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b Mario jong txt_LS-id1065.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 6310a5b5af42fb718e0f203b Techno jong txt
# ls id 1066
# path out ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b Techno jong txt_LS-id1066.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 6310a5b5af42fb718e0f203b MAX jong txt
# ls id 1067
# path out ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b MAX jong txt_LS-id1067.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 6310a5b5af42fb718e0f203b Bingo jong txt
# ls id 1068
# path out ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b Bingo jong txt_LS-id1068.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl909067dd848-1371258d9295 Bridge jong txt
# ls id 1069
# path out ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Bridge jong txt_LS-id1069.csv
# relation has labels
# ['behav-span']
#
# text id pinl909067dd848-1371258d9295 Klassiek jong txt
# ls id 1070
# path out ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Klassiek jong txt_LS-id1070.csv
# text id pinl909067dd848-1371258d9295 Ex jong txt
# ls id 1071
# path out ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Ex jong txt_LS-id1071.csv
# text id pinl909067dd848-1371258d9295 Huisfeest jong txt
# ls id 1072
# path out ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Huisfeest jong txt_LS-id1072.csv
# text id 5edab253669692706f731c3d Bingo jong txt.1
# ls id 1073
# path out ../results/kim-full-data-update1/output-5edab253669692706f731c3d Bingo jong txt.1_LS-id1073.csv
# relation has labels
# ['behav-span']
#
# text id 5edab253669692706f731c3d MAX jong txt.1
# ls id 1074
# path out ../results/kim-full-data-update1/output-5edab253669692706f731c3d MAX jong txt.1_LS-id1074.csv
# relation has labels
# ['behav-span']
#
# text id 5edab253669692706f731c3d Techno jong txt.1
# ls id 1075
# path out ../results/kim-full-data-update1/output-5edab253669692706f731c3d Techno jong txt.1_LS-id1075.csv
# text id 5edab253669692706f731c3d Mario jong txt.1
# ls id 1076
# path out ../results/kim-full-data-update1/output-5edab253669692706f731c3d Mario jong txt.1_LS-id1076.csv
# relation has labels
# ['behav-span']
#
# text id pinl62308698482-1367334ebf62 Mario jong txt
# ls id 1077
# path out ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 Mario jong txt_LS-id1077.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# text id pinl62308698482-1367334ebf62 Techno jong txt
# ls id 1078
# path out ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 Techno jong txt_LS-id1078.csv
# text id pinl62308698482-1367334ebf62 MAX jong txt
# ls id 1079
# path out ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 MAX jong txt_LS-id1079.csv
# relation has labels
# ['behav-span']
#
# text id pinl62308698482-1367334ebf62 Bingo jong txt
# ls id 1080
# path out ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 Bingo jong txt_LS-id1080.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# text id 63d187501b04c6fb0697f2b5 Huisfeest oud txt.1
# ls id 1081
# path out ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Huisfeest oud txt.1_LS-id1081.csv
# text id 63d187501b04c6fb0697f2b5 Ex oud txt.1
# ls id 1082
# path out ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Ex oud txt.1_LS-id1082.csv
# text id 63d187501b04c6fb0697f2b5 Klassiek oud txt.1
# ls id 1083
# path out ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Klassiek oud txt.1_LS-id1083.csv
# text id 63d187501b04c6fb0697f2b5 Bridge oud txt.1
# ls id 1084
# path out ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Bridge oud txt.1_LS-id1084.csv
# relation has labels
# ['behav-span']
#
# text id pinl166643c6492-13673346445d Bridge oud txt
# ls id 1085
# path out ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Bridge oud txt_LS-id1085.csv
# relation has labels
# ['behav-span']
#
# text id pinl166643c6492-13673346445d Klassiek oud txt
# ls id 1086
# path out ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Klassiek oud txt_LS-id1086.csv
# relation has labels
# ['behav-span']
#
# text id pinl166643c6492-13673346445d Ex oud txt
# ls id 1087
# path out ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Ex oud txt_LS-id1087.csv
# text id pinl166643c6492-13673346445d Huisfeest oud txt
# ls id 1088
# path out ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Huisfeest oud txt_LS-id1088.csv
# relation has labels
# ['behav-span']
#
# text id 63528428d18878b30041e791 Huisfeest oud txt.1
# ls id 1089
# path out ../results/kim-full-data-update1/output-63528428d18878b30041e791 Huisfeest oud txt.1_LS-id1089.csv
# relation has labels
# ['behav-span']
#
# text id 63528428d18878b30041e791 Ex oud txt.1
# ls id 1090
# path out ../results/kim-full-data-update1/output-63528428d18878b30041e791 Ex oud txt.1_LS-id1090.csv
# text id 63528428d18878b30041e791 Klassiek oud txt.1
# ls id 1091
# path out ../results/kim-full-data-update1/output-63528428d18878b30041e791 Klassiek oud txt.1_LS-id1091.csv
# text id 63528428d18878b30041e791 Bridge oud txt.1
# ls id 1092
# path out ../results/kim-full-data-update1/output-63528428d18878b30041e791 Bridge oud txt.1_LS-id1092.csv
# text id 60076986348bb62629139c82 Mario oud txt
# ls id 1093
# path out ../results/kim-full-data-update1/output-60076986348bb62629139c82 Mario oud txt_LS-id1093.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# text id 60076986348bb62629139c82 Techno oud txt
# ls id 1094
# path out ../results/kim-full-data-update1/output-60076986348bb62629139c82 Techno oud txt_LS-id1094.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# text id 60076986348bb62629139c82 MAX oud txt
# ls id 1095
# path out ../results/kim-full-data-update1/output-60076986348bb62629139c82 MAX oud txt_LS-id1095.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# text id 60076986348bb62629139c82 Bingo oud txt
# ls id 1096
# path out ../results/kim-full-data-update1/output-60076986348bb62629139c82 Bingo oud txt_LS-id1096.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# text id 5cda5b38480d7d00196cd9c0 Bridge oud txt
# ls id 1097
# path out ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Bridge oud txt_LS-id1097.csv
# text id 5cda5b38480d7d00196cd9c0 Klassiek oud txt
# ls id 1098
# path out ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Klassiek oud txt_LS-id1098.csv
# relation has labels
# ['behav-span']
#
# text id 5cda5b38480d7d00196cd9c0 Ex oud txt
# ls id 1099
# path out ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Ex oud txt_LS-id1099.csv
# text id 5cda5b38480d7d00196cd9c0 Huisfeest oud txt
# ls id 1100
# path out ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Huisfeest oud txt_LS-id1100.csv
# text id pinl4253902185-1366118be5a2 Bingo jong txt.1
# ls id 1101
# path out ../results/kim-full-data-update1/output-pinl4253902185-1366118be5a2 Bingo jong txt.1_LS-id1101.csv
# text id pinl4253902185-1366118be5a2 MAX jong txt.1
# ls id 1102
# path out ../results/kim-full-data-update1/output-pinl4253902185-1366118be5a2 MAX jong txt.1_LS-id1102.csv
# text id pinl4253902185-1366118be5a2 Techno jong txt.1
# ls id 1103
# path out ../results/kim-full-data-update1/output-pinl4253902185-1366118be5a2 Techno jong txt.1_LS-id1103.csv
# text id pinl4253902185-1366118be5a2 Mario jong txt.1
# ls id 1104
# path out ../results/kim-full-data-update1/output-pinl4253902185-1366118be5a2 Mario jong txt.1_LS-id1104.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id 5e69375a437a7806d929a40a Mario jong txt
# ls id 1105
# path out ../results/kim-full-data-update1/output-5e69375a437a7806d929a40a Mario jong txt_LS-id1105.csv
# text id 5e69375a437a7806d929a40a Techno jong txt
# ls id 1106
# path out ../results/kim-full-data-update1/output-5e69375a437a7806d929a40a Techno jong txt_LS-id1106.csv
# text id 5e69375a437a7806d929a40a MAX jong txt
# ls id 1107
# path out ../results/kim-full-data-update1/output-5e69375a437a7806d929a40a MAX jong txt_LS-id1107.csv
# text id 5e69375a437a7806d929a40a Bingo jong txt
# ls id 1108
# path out ../results/kim-full-data-update1/output-5e69375a437a7806d929a40a Bingo jong txt_LS-id1108.csv
# text id pinl55238677a141-13678361098b Mario jong txt
# ls id 1109
# path out ../results/kim-full-data-update1/output-pinl55238677a141-13678361098b Mario jong txt_LS-id1109.csv
# text id pinl55238677a141-13678361098b Techno jong txt
# ls id 1110
# path out ../results/kim-full-data-update1/output-pinl55238677a141-13678361098b Techno jong txt_LS-id1110.csv
# text id pinl55238677a141-13678361098b MAX jong txt
# ls id 1111
# path out ../results/kim-full-data-update1/output-pinl55238677a141-13678361098b MAX jong txt_LS-id1111.csv
# text id pinl55238677a141-13678361098b Bingo jong txt
# ls id 1112
# path out ../results/kim-full-data-update1/output-pinl55238677a141-13678361098b Bingo jong txt_LS-id1112.csv
# text id pinl548768121533-136733443406 Huisfeest jong txt.1
# ls id 1113
# path out ../results/kim-full-data-update1/output-pinl548768121533-136733443406 Huisfeest jong txt.1_LS-id1113.csv
# text id pinl548768121533-136733443406 Ex jong txt.1
# ls id 1114
# path out ../results/kim-full-data-update1/output-pinl548768121533-136733443406 Ex jong txt.1_LS-id1114.csv
# text id pinl548768121533-136733443406 Klassiek jong txt.1
# ls id 1115
# path out ../results/kim-full-data-update1/output-pinl548768121533-136733443406 Klassiek jong txt.1_LS-id1115.csv
# text id pinl548768121533-136733443406 Bridge jong txt.1
# ls id 1116
# path out ../results/kim-full-data-update1/output-pinl548768121533-136733443406 Bridge jong txt.1_LS-id1116.csv
# text id pinl546968172740-1368444ba451 Huisfeest jong txt.1
# ls id 1117
# path out ../results/kim-full-data-update1/output-pinl546968172740-1368444ba451 Huisfeest jong txt.1_LS-id1117.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl546968172740-1368444ba451 Ex jong txt.1
# ls id 1118
# path out ../results/kim-full-data-update1/output-pinl546968172740-1368444ba451 Ex jong txt.1_LS-id1118.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl546968172740-1368444ba451 Klassiek jong txt.1
# ls id 1119
# path out ../results/kim-full-data-update1/output-pinl546968172740-1368444ba451 Klassiek jong txt.1_LS-id1119.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl546968172740-1368444ba451 Bridge jong txt.1
# ls id 1120
# path out ../results/kim-full-data-update1/output-pinl546968172740-1368444ba451 Bridge jong txt.1_LS-id1120.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 63c552a4fd6bddcff7b288f7 Mario jong txt
# ls id 1121
# path out ../results/kim-full-data-update1/output-63c552a4fd6bddcff7b288f7 Mario jong txt_LS-id1121.csv
# text id 63c552a4fd6bddcff7b288f7 Techno jong txt
# ls id 1122
# path out ../results/kim-full-data-update1/output-63c552a4fd6bddcff7b288f7 Techno jong txt_LS-id1122.csv
# text id 63c552a4fd6bddcff7b288f7 MAX jong txt
# ls id 1123
# path out ../results/kim-full-data-update1/output-63c552a4fd6bddcff7b288f7 MAX jong txt_LS-id1123.csv
# text id 63c552a4fd6bddcff7b288f7 Bingo jong txt
# ls id 1124
# path out ../results/kim-full-data-update1/output-63c552a4fd6bddcff7b288f7 Bingo jong txt_LS-id1124.csv
# text id pinl40970094ab08-1367334f42d7 Bridge jong txt
# ls id 1125
# path out ../results/kim-full-data-update1/output-pinl40970094ab08-1367334f42d7 Bridge jong txt_LS-id1125.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl40970094ab08-1367334f42d7 Klassiek jong txt
# ls id 1126
# path out ../results/kim-full-data-update1/output-pinl40970094ab08-1367334f42d7 Klassiek jong txt_LS-id1126.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl40970094ab08-1367334f42d7 Ex jong txt
# ls id 1127
# path out ../results/kim-full-data-update1/output-pinl40970094ab08-1367334f42d7 Ex jong txt_LS-id1127.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl40970094ab08-1367334f42d7 Huisfeest jong txt
# ls id 1128
# path out ../results/kim-full-data-update1/output-pinl40970094ab08-1367334f42d7 Huisfeest jong txt_LS-id1128.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl4525640bc14d-13712580ed54 Huisfeest jong txt.1
# ls id 1129
# path out ../results/kim-full-data-update1/output-pinl4525640bc14d-13712580ed54 Huisfeest jong txt.1_LS-id1129.csv
# text id pinl4525640bc14d-13712580ed54 Ex jong txt.1
# ls id 1130
# path out ../results/kim-full-data-update1/output-pinl4525640bc14d-13712580ed54 Ex jong txt.1_LS-id1130.csv
# text id pinl4525640bc14d-13712580ed54 Klassiek jong txt.1
# ls id 1131
# path out ../results/kim-full-data-update1/output-pinl4525640bc14d-13712580ed54 Klassiek jong txt.1_LS-id1131.csv
# text id pinl4525640bc14d-13712580ed54 Bridge jong txt.1
# ls id 1132
# path out ../results/kim-full-data-update1/output-pinl4525640bc14d-13712580ed54 Bridge jong txt.1_LS-id1132.csv
# text id pinl552634805784-13684446e63e Bingo oud txt.1
# ls id 1133
# path out ../results/kim-full-data-update1/output-pinl552634805784-13684446e63e Bingo oud txt.1_LS-id1133.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl552634805784-13684446e63e MAX oud txt.1
# ls id 1134
# path out ../results/kim-full-data-update1/output-pinl552634805784-13684446e63e MAX oud txt.1_LS-id1134.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl552634805784-13684446e63e Techno oud txt.1
# ls id 1135
# path out ../results/kim-full-data-update1/output-pinl552634805784-13684446e63e Techno oud txt.1_LS-id1135.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl552634805784-13684446e63e Mario oud txt.1
# ls id 1136
# path out ../results/kim-full-data-update1/output-pinl552634805784-13684446e63e Mario oud txt.1_LS-id1136.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure']}
# text id 5995b8a6bf8bcf0001ab6aed Bingo oud txt.1
# ls id 1137
# path out ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed Bingo oud txt.1_LS-id1137.csv
# text id 5995b8a6bf8bcf0001ab6aed MAX oud txt.1
# ls id 1138
# path out ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed MAX oud txt.1_LS-id1138.csv
# text id 5995b8a6bf8bcf0001ab6aed Techno oud txt.1
# ls id 1139
# path out ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed Techno oud txt.1_LS-id1139.csv
# relation has labels
# ['ref-span']
#
# text id 5995b8a6bf8bcf0001ab6aed Mario oud txt.1
# ls id 1140
# path out ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed Mario oud txt.1_LS-id1140.csv
# text id 5d641f290540c40015e74213 Mario jong txt
# ls id 1141
# path out ../results/kim-full-data-update1/output-5d641f290540c40015e74213 Mario jong txt_LS-id1141.csv
# text id 5d641f290540c40015e74213 Techno jong txt
# ls id 1142
# path out ../results/kim-full-data-update1/output-5d641f290540c40015e74213 Techno jong txt_LS-id1142.csv
# text id 5d641f290540c40015e74213 MAX jong txt
# ls id 1143
# path out ../results/kim-full-data-update1/output-5d641f290540c40015e74213 MAX jong txt_LS-id1143.csv
# text id 5d641f290540c40015e74213 Bingo jong txt
# ls id 1144
# path out ../results/kim-full-data-update1/output-5d641f290540c40015e74213 Bingo jong txt_LS-id1144.csv
# text id 640550f7006e663f75ca4379 Bingo oud txt.1
# ls id 1145
# path out ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 Bingo oud txt.1_LS-id1145.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# relation has labels
# ['behav-span']
#
# text id 640550f7006e663f75ca4379 MAX oud txt.1
# ls id 1146
# path out ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 MAX oud txt.1_LS-id1146.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# text id 640550f7006e663f75ca4379 Techno oud txt.1
# ls id 1147
# path out ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 Techno oud txt.1_LS-id1147.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# relation has labels
# ['behav-span']
#
# text id 640550f7006e663f75ca4379 Mario oud txt.1
# ls id 1148
# path out ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 Mario oud txt.1_LS-id1148.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# text id 635279674095bcdfa5a55fd5 Huisfeest jong txt.1
# ls id 1149
# path out ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Huisfeest jong txt.1_LS-id1149.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 635279674095bcdfa5a55fd5 Ex jong txt.1
# ls id 1150
# path out ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Ex jong txt.1_LS-id1150.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 635279674095bcdfa5a55fd5 Klassiek jong txt.1
# ls id 1151
# path out ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Klassiek jong txt.1_LS-id1151.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 635279674095bcdfa5a55fd5 Bridge jong txt.1
# ls id 1152
# path out ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Bridge jong txt.1_LS-id1152.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl2697881468e7-1367827835db Huisfeest oud txt.1
# ls id 1153
# path out ../results/kim-full-data-update1/output-pinl2697881468e7-1367827835db Huisfeest oud txt.1_LS-id1153.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl2697881468e7-1367827835db Ex oud txt.1
# ls id 1154
# path out ../results/kim-full-data-update1/output-pinl2697881468e7-1367827835db Ex oud txt.1_LS-id1154.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl2697881468e7-1367827835db Klassiek oud txt.1
# ls id 1155
# path out ../results/kim-full-data-update1/output-pinl2697881468e7-1367827835db Klassiek oud txt.1_LS-id1155.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl2697881468e7-1367827835db Bridge oud txt.1
# ls id 1156
# path out ../results/kim-full-data-update1/output-pinl2697881468e7-1367827835db Bridge oud txt.1_LS-id1156.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl45741a8201-13673345876d Mario oud txt
# ls id 1157
# path out ../results/kim-full-data-update1/output-pinl45741a8201-13673345876d Mario oud txt_LS-id1157.csv
# text id pinl45741a8201-13673345876d Techno oud txt
# ls id 1158
# path out ../results/kim-full-data-update1/output-pinl45741a8201-13673345876d Techno oud txt_LS-id1158.csv
# relation has labels
# ['ref-span']
#
# text id pinl45741a8201-13673345876d MAX oud txt
# ls id 1159
# path out ../results/kim-full-data-update1/output-pinl45741a8201-13673345876d MAX oud txt_LS-id1159.csv
# text id pinl45741a8201-13673345876d Bingo oud txt
# ls id 1160
# path out ../results/kim-full-data-update1/output-pinl45741a8201-13673345876d Bingo oud txt_LS-id1160.csv
# text id 6100359a5c15636d4398e7df Mario jong txt
# ls id 1161
# path out ../results/kim-full-data-update1/output-6100359a5c15636d4398e7df Mario jong txt_LS-id1161.csv
# text id 6100359a5c15636d4398e7df Techno jong txt
# ls id 1162
# path out ../results/kim-full-data-update1/output-6100359a5c15636d4398e7df Techno jong txt_LS-id1162.csv
# text id 6100359a5c15636d4398e7df MAX jong txt
# ls id 1163
# path out ../results/kim-full-data-update1/output-6100359a5c15636d4398e7df MAX jong txt_LS-id1163.csv
# text id 6100359a5c15636d4398e7df Bingo jong txt
# ls id 1164
# path out ../results/kim-full-data-update1/output-6100359a5c15636d4398e7df Bingo jong txt_LS-id1164.csv
# text id 577396832ed4a60001ad4c0e Bridge oud txt
# ls id 1165
# path out ../results/kim-full-data-update1/output-577396832ed4a60001ad4c0e Bridge oud txt_LS-id1165.csv
# text id 577396832ed4a60001ad4c0e Klassiek oud txt
# ls id 1166
# path out ../results/kim-full-data-update1/output-577396832ed4a60001ad4c0e Klassiek oud txt_LS-id1166.csv
# text id 577396832ed4a60001ad4c0e Ex oud txt
# ls id 1167
# path out ../results/kim-full-data-update1/output-577396832ed4a60001ad4c0e Ex oud txt_LS-id1167.csv
# text id 577396832ed4a60001ad4c0e Huisfeest oud txt
# ls id 1168
# path out ../results/kim-full-data-update1/output-577396832ed4a60001ad4c0e Huisfeest oud txt_LS-id1168.csv
# text id 5e853ff6367050000b3520d1 Bridge oud txt
# ls id 1169
# path out ../results/kim-full-data-update1/output-5e853ff6367050000b3520d1 Bridge oud txt_LS-id1169.csv
# text id 5e853ff6367050000b3520d1 Klassiek oud txt
# ls id 1170
# path out ../results/kim-full-data-update1/output-5e853ff6367050000b3520d1 Klassiek oud txt_LS-id1170.csv
# text id 5e853ff6367050000b3520d1 Ex oud txt
# ls id 1171
# path out ../results/kim-full-data-update1/output-5e853ff6367050000b3520d1 Ex oud txt_LS-id1171.csv
# text id 5e853ff6367050000b3520d1 Huisfeest oud txt
# ls id 1172
# path out ../results/kim-full-data-update1/output-5e853ff6367050000b3520d1 Huisfeest oud txt_LS-id1172.csv
# text id 61070b2f6fa9910dfa491e50 Huisfeest jong txt.1
# ls id 1173
# path out ../results/kim-full-data-update1/output-61070b2f6fa9910dfa491e50 Huisfeest jong txt.1_LS-id1173.csv
# text id 61070b2f6fa9910dfa491e50 Ex jong txt.1
# ls id 1174
# path out ../results/kim-full-data-update1/output-61070b2f6fa9910dfa491e50 Ex jong txt.1_LS-id1174.csv
# text id 61070b2f6fa9910dfa491e50 Klassiek jong txt.1
# ls id 1175
# path out ../results/kim-full-data-update1/output-61070b2f6fa9910dfa491e50 Klassiek jong txt.1_LS-id1175.csv
# text id 61070b2f6fa9910dfa491e50 Bridge jong txt.1
# ls id 1176
# path out ../results/kim-full-data-update1/output-61070b2f6fa9910dfa491e50 Bridge jong txt.1_LS-id1176.csv
# text id pinl4801942ad6-13673343bd00 Bingo jong txt.1
# ls id 1177
# path out ../results/kim-full-data-update1/output-pinl4801942ad6-13673343bd00 Bingo jong txt.1_LS-id1177.csv
# text id pinl4801942ad6-13673343bd00 MAX jong txt.1
# ls id 1178
# path out ../results/kim-full-data-update1/output-pinl4801942ad6-13673343bd00 MAX jong txt.1_LS-id1178.csv
# text id pinl4801942ad6-13673343bd00 Techno jong txt.1
# ls id 1179
# path out ../results/kim-full-data-update1/output-pinl4801942ad6-13673343bd00 Techno jong txt.1_LS-id1179.csv
# relation has labels
# ['ref-span']
#
# text id pinl4801942ad6-13673343bd00 Mario jong txt.1
# ls id 1180
# path out ../results/kim-full-data-update1/output-pinl4801942ad6-13673343bd00 Mario jong txt.1_LS-id1180.csv
# text id pinl4745293429bb-13673344bce6 Bingo jong txt.1
# ls id 1181
# path out ../results/kim-full-data-update1/output-pinl4745293429bb-13673344bce6 Bingo jong txt.1_LS-id1181.csv
# text id pinl4745293429bb-13673344bce6 MAX jong txt.1
# ls id 1182
# path out ../results/kim-full-data-update1/output-pinl4745293429bb-13673344bce6 MAX jong txt.1_LS-id1182.csv
# text id pinl4745293429bb-13673344bce6 Techno jong txt.1
# ls id 1183
# path out ../results/kim-full-data-update1/output-pinl4745293429bb-13673344bce6 Techno jong txt.1_LS-id1183.csv
# text id pinl4745293429bb-13673344bce6 Mario jong txt.1
# ls id 1184
# path out ../results/kim-full-data-update1/output-pinl4745293429bb-13673344bce6 Mario jong txt.1_LS-id1184.csv
# text id 6310c693809cf6f3f1180f09 Huisfeest oud txt.1
# ls id 1185
# path out ../results/kim-full-data-update1/output-6310c693809cf6f3f1180f09 Huisfeest oud txt.1_LS-id1185.csv
# text id 6310c693809cf6f3f1180f09 Ex oud txt.1
# ls id 1186
# path out ../results/kim-full-data-update1/output-6310c693809cf6f3f1180f09 Ex oud txt.1_LS-id1186.csv
# text id 6310c693809cf6f3f1180f09 Klassiek oud txt.1
# ls id 1187
# path out ../results/kim-full-data-update1/output-6310c693809cf6f3f1180f09 Klassiek oud txt.1_LS-id1187.csv
# text id 6310c693809cf6f3f1180f09 Bridge oud txt.1
# ls id 1188
# path out ../results/kim-full-data-update1/output-6310c693809cf6f3f1180f09 Bridge oud txt.1_LS-id1188.csv
# text id pinl5247036c38bf-13673346b27e Mario oud txt
# ls id 1189
# path out ../results/kim-full-data-update1/output-pinl5247036c38bf-13673346b27e Mario oud txt_LS-id1189.csv
# text id pinl5247036c38bf-13673346b27e Techno oud txt
# ls id 1190
# path out ../results/kim-full-data-update1/output-pinl5247036c38bf-13673346b27e Techno oud txt_LS-id1190.csv
# text id pinl5247036c38bf-13673346b27e MAX oud txt
# ls id 1191
# path out ../results/kim-full-data-update1/output-pinl5247036c38bf-13673346b27e MAX oud txt_LS-id1191.csv
# text id pinl5247036c38bf-13673346b27e Bingo oud txt
# ls id 1192
# path out ../results/kim-full-data-update1/output-pinl5247036c38bf-13673346b27e Bingo oud txt_LS-id1192.csv
# text id 608956a7cb0f370f25ec12a0 Bridge oud txt
# ls id 1193
# path out ../results/kim-full-data-update1/output-608956a7cb0f370f25ec12a0 Bridge oud txt_LS-id1193.csv
# text id 608956a7cb0f370f25ec12a0 Klassiek oud txt
# ls id 1194
# path out ../results/kim-full-data-update1/output-608956a7cb0f370f25ec12a0 Klassiek oud txt_LS-id1194.csv
# text id 608956a7cb0f370f25ec12a0 Ex oud txt
# ls id 1195
# path out ../results/kim-full-data-update1/output-608956a7cb0f370f25ec12a0 Ex oud txt_LS-id1195.csv
# text id 608956a7cb0f370f25ec12a0 Huisfeest oud txt
# ls id 1196
# path out ../results/kim-full-data-update1/output-608956a7cb0f370f25ec12a0 Huisfeest oud txt_LS-id1196.csv
# text id 63f13e4ae2074d47b8ee57b2 Bridge jong txt
# ls id 1197
# path out ../results/kim-full-data-update1/output-63f13e4ae2074d47b8ee57b2 Bridge jong txt_LS-id1197.csv
# text id 63f13e4ae2074d47b8ee57b2 Klassiek jong txt
# ls id 1198
# path out ../results/kim-full-data-update1/output-63f13e4ae2074d47b8ee57b2 Klassiek jong txt_LS-id1198.csv
# text id 63f13e4ae2074d47b8ee57b2 Ex jong txt
# ls id 1199
# path out ../results/kim-full-data-update1/output-63f13e4ae2074d47b8ee57b2 Ex jong txt_LS-id1199.csv
# text id 63f13e4ae2074d47b8ee57b2 Huisfeest jong txt
# ls id 1200
# path out ../results/kim-full-data-update1/output-63f13e4ae2074d47b8ee57b2 Huisfeest jong txt_LS-id1200.csv
# text id pinl5510481bbd7b-13658567dabd Mario oud txt
# ls id 1201
# path out ../results/kim-full-data-update1/output-pinl5510481bbd7b-13658567dabd Mario oud txt_LS-id1201.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl5510481bbd7b-13658567dabd Techno oud txt
# ls id 1202
# path out ../results/kim-full-data-update1/output-pinl5510481bbd7b-13658567dabd Techno oud txt_LS-id1202.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl5510481bbd7b-13658567dabd MAX oud txt
# ls id 1203
# path out ../results/kim-full-data-update1/output-pinl5510481bbd7b-13658567dabd MAX oud txt_LS-id1203.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl5510481bbd7b-13658567dabd Bingo oud txt
# ls id 1204
# path out ../results/kim-full-data-update1/output-pinl5510481bbd7b-13658567dabd Bingo oud txt_LS-id1204.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl5134789bdd89-136733490a99 Huisfeest jong txt.1
# ls id 1205
# path out ../results/kim-full-data-update1/output-pinl5134789bdd89-136733490a99 Huisfeest jong txt.1_LS-id1205.csv
# text id pinl5134789bdd89-136733490a99 Ex jong txt.1
# ls id 1206
# path out ../results/kim-full-data-update1/output-pinl5134789bdd89-136733490a99 Ex jong txt.1_LS-id1206.csv
# text id pinl5134789bdd89-136733490a99 Klassiek jong txt.1
# ls id 1207
# path out ../results/kim-full-data-update1/output-pinl5134789bdd89-136733490a99 Klassiek jong txt.1_LS-id1207.csv
# text id pinl5134789bdd89-136733490a99 Bridge jong txt.1
# ls id 1208
# path out ../results/kim-full-data-update1/output-pinl5134789bdd89-136733490a99 Bridge jong txt.1_LS-id1208.csv
# text id pinl3829781bb3ae-13678365c257 Bridge jong txt
# ls id 1209
# path out ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Bridge jong txt_LS-id1209.csv
# text id pinl3829781bb3ae-13678365c257 Klassiek jong txt
# ls id 1210
# path out ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Klassiek jong txt_LS-id1210.csv
# text id pinl3829781bb3ae-13678365c257 Ex jong txt
# ls id 1211
# path out ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Ex jong txt_LS-id1211.csv
# text id pinl3829781bb3ae-13678365c257 Huisfeest jong txt
# ls id 1212
# path out ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Huisfeest jong txt_LS-id1212.csv
# text id pinl552579036036-1373475d31ba Huisfeest jong txt.1
# ls id 1213
# path out ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Huisfeest jong txt.1_LS-id1213.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl552579036036-1373475d31ba Ex jong txt.1
# ls id 1214
# path out ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Ex jong txt.1_LS-id1214.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl552579036036-1373475d31ba Klassiek jong txt.1
# ls id 1215
# path out ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Klassiek jong txt.1_LS-id1215.csv
# no start key but choices
# {'choices': ['WPM']}
# text id pinl552579036036-1373475d31ba Bridge jong txt.1
# ls id 1216
# path out ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Bridge jong txt.1_LS-id1216.csv
# no start key but choices
# {'choices': ['WPM']}
# text id 6116d3e040d816a2d509a28a Mario jong txt
# ls id 1217
# path out ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a Mario jong txt_LS-id1217.csv
# text id 6116d3e040d816a2d509a28a Techno jong txt
# ls id 1218
# path out ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a Techno jong txt_LS-id1218.csv
# text id 6116d3e040d816a2d509a28a MAX jong txt
# ls id 1219
# path out ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a MAX jong txt_LS-id1219.csv
# text id 6116d3e040d816a2d509a28a Bingo jong txt
# ls id 1220
# path out ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a Bingo jong txt_LS-id1220.csv
# text id 63f0c1057f083573d83a2d62 Bingo oud txt.1
# ls id 1221
# path out ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 Bingo oud txt.1_LS-id1221.csv
# text id 63f0c1057f083573d83a2d62 MAX oud txt.1
# ls id 1222
# path out ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 MAX oud txt.1_LS-id1222.csv
# text id 63f0c1057f083573d83a2d62 Techno oud txt.1
# ls id 1223
# path out ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 Techno oud txt.1_LS-id1223.csv
# text id 63f0c1057f083573d83a2d62 Mario oud txt.1
# ls id 1224
# path out ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 Mario oud txt.1_LS-id1224.csv
# text id pinl54925326d645-136782792445 Mario jong txt
# ls id 1225
# path out ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 Mario jong txt_LS-id1225.csv
# text id pinl54925326d645-136782792445 Techno jong txt
# ls id 1226
# path out ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 Techno jong txt_LS-id1226.csv
# text id pinl54925326d645-136782792445 MAX jong txt
# ls id 1227
# path out ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 MAX jong txt_LS-id1227.csv
# text id pinl54925326d645-136782792445 Bingo jong txt
# ls id 1228
# path out ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 Bingo jong txt_LS-id1228.csv
# text id pinl6623026d5e1-1371258a84f6 Bridge jong txt
# ls id 1229
# path out ../results/kim-full-data-update1/output-pinl6623026d5e1-1371258a84f6 Bridge jong txt_LS-id1229.csv
# text id pinl6623026d5e1-1371258a84f6 Klassiek jong txt
# ls id 1230
# path out ../results/kim-full-data-update1/output-pinl6623026d5e1-1371258a84f6 Klassiek jong txt_LS-id1230.csv
# text id pinl6623026d5e1-1371258a84f6 Ex jong txt
# ls id 1231
# path out ../results/kim-full-data-update1/output-pinl6623026d5e1-1371258a84f6 Ex jong txt_LS-id1231.csv
# relation has labels
# ['ref-span']
#
# text id pinl6623026d5e1-1371258a84f6 Huisfeest jong txt
# ls id 1232
# path out ../results/kim-full-data-update1/output-pinl6623026d5e1-1371258a84f6 Huisfeest jong txt_LS-id1232.csv
# text id pinl545421671417-136560769cb5 Huisfeest oud txt.1
# ls id 1233
# path out ../results/kim-full-data-update1/output-pinl545421671417-136560769cb5 Huisfeest oud txt.1_LS-id1233.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl545421671417-136560769cb5 Ex oud txt.1
# ls id 1234
# path out ../results/kim-full-data-update1/output-pinl545421671417-136560769cb5 Ex oud txt.1_LS-id1234.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl545421671417-136560769cb5 Klassiek oud txt.1
# ls id 1235
# path out ../results/kim-full-data-update1/output-pinl545421671417-136560769cb5 Klassiek oud txt.1_LS-id1235.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl545421671417-136560769cb5 Bridge oud txt.1
# ls id 1236
# path out ../results/kim-full-data-update1/output-pinl545421671417-136560769cb5 Bridge oud txt.1_LS-id1236.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# text id pinl5034573cf9b1-13734759d15d Bingo oud txt.1
# ls id 1237
# path out ../results/kim-full-data-update1/output-pinl5034573cf9b1-13734759d15d Bingo oud txt.1_LS-id1237.csv
# text id pinl5034573cf9b1-13734759d15d MAX oud txt.1
# ls id 1238
# path out ../results/kim-full-data-update1/output-pinl5034573cf9b1-13734759d15d MAX oud txt.1_LS-id1238.csv
# text id pinl5034573cf9b1-13734759d15d Techno oud txt.1
# ls id 1239
# path out ../results/kim-full-data-update1/output-pinl5034573cf9b1-13734759d15d Techno oud txt.1_LS-id1239.csv
# text id pinl5034573cf9b1-13734759d15d Mario oud txt.1
# ls id 1240
# path out ../results/kim-full-data-update1/output-pinl5034573cf9b1-13734759d15d Mario oud txt.1_LS-id1240.csv
# relation has labels
# ['ref-span']
#
# text id 631b70f229635bd17c04bf5a Mario oud txt
# ls id 1241
# path out ../results/kim-full-data-update1/output-631b70f229635bd17c04bf5a Mario oud txt_LS-id1241.csv
# text id 631b70f229635bd17c04bf5a Techno oud txt
# ls id 1242
# path out ../results/kim-full-data-update1/output-631b70f229635bd17c04bf5a Techno oud txt_LS-id1242.csv
# text id 631b70f229635bd17c04bf5a MAX oud txt
# ls id 1243
# path out ../results/kim-full-data-update1/output-631b70f229635bd17c04bf5a MAX oud txt_LS-id1243.csv
# text id 631b70f229635bd17c04bf5a Bingo oud txt
# ls id 1244
# path out ../results/kim-full-data-update1/output-631b70f229635bd17c04bf5a Bingo oud txt_LS-id1244.csv
# text id pinl5428761e07be-136783609baa Bingo jong txt.1
# ls id 1245
# path out ../results/kim-full-data-update1/output-pinl5428761e07be-136783609baa Bingo jong txt.1_LS-id1245.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl5428761e07be-136783609baa MAX jong txt.1
# ls id 1246
# path out ../results/kim-full-data-update1/output-pinl5428761e07be-136783609baa MAX jong txt.1_LS-id1246.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl5428761e07be-136783609baa Techno jong txt.1
# ls id 1247
# path out ../results/kim-full-data-update1/output-pinl5428761e07be-136783609baa Techno jong txt.1_LS-id1247.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl5428761e07be-136783609baa Mario jong txt.1
# ls id 1248
# path out ../results/kim-full-data-update1/output-pinl5428761e07be-136783609baa Mario jong txt.1_LS-id1248.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id 5f7442471c6afd08d6183a5c Bingo oud txt.1
# ls id 1249
# path out ../results/kim-full-data-update1/output-5f7442471c6afd08d6183a5c Bingo oud txt.1_LS-id1249.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id 5f7442471c6afd08d6183a5c MAX oud txt.1
# ls id 1250
# path out ../results/kim-full-data-update1/output-5f7442471c6afd08d6183a5c MAX oud txt.1_LS-id1250.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id 5f7442471c6afd08d6183a5c Techno oud txt.1
# ls id 1251
# path out ../results/kim-full-data-update1/output-5f7442471c6afd08d6183a5c Techno oud txt.1_LS-id1251.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id 5f7442471c6afd08d6183a5c Mario oud txt.1
# ls id 1252
# path out ../results/kim-full-data-update1/output-5f7442471c6afd08d6183a5c Mario oud txt.1_LS-id1252.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id 5e32dc9166f7ac29f33d0f38 Huisfeest oud txt.1
# ls id 1253
# path out ../results/kim-full-data-update1/output-5e32dc9166f7ac29f33d0f38 Huisfeest oud txt.1_LS-id1253.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution']}
# text id 5e32dc9166f7ac29f33d0f38 Ex oud txt.1
# ls id 1254
# path out ../results/kim-full-data-update1/output-5e32dc9166f7ac29f33d0f38 Ex oud txt.1_LS-id1254.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure']}
# text id 5e32dc9166f7ac29f33d0f38 Klassiek oud txt.1
# ls id 1255
# path out ../results/kim-full-data-update1/output-5e32dc9166f7ac29f33d0f38 Klassiek oud txt.1_LS-id1255.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure']}
# text id 5e32dc9166f7ac29f33d0f38 Bridge oud txt.1
# ls id 1256
# path out ../results/kim-full-data-update1/output-5e32dc9166f7ac29f33d0f38 Bridge oud txt.1_LS-id1256.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure']}
# text id pinl53671293eafd-13678271b720 Bridge oud txt
# ls id 1257
# path out ../results/kim-full-data-update1/output-pinl53671293eafd-13678271b720 Bridge oud txt_LS-id1257.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl53671293eafd-13678271b720 Klassiek oud txt
# ls id 1258
# path out ../results/kim-full-data-update1/output-pinl53671293eafd-13678271b720 Klassiek oud txt_LS-id1258.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl53671293eafd-13678271b720 Ex oud txt
# ls id 1259
# path out ../results/kim-full-data-update1/output-pinl53671293eafd-13678271b720 Ex oud txt_LS-id1259.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl53671293eafd-13678271b720 Huisfeest oud txt
# ls id 1260
# path out ../results/kim-full-data-update1/output-pinl53671293eafd-13678271b720 Huisfeest oud txt_LS-id1260.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id 5bfea682a1f050000102619e Huisfeest jong txt.1
# ls id 1261
# path out ../results/kim-full-data-update1/output-5bfea682a1f050000102619e Huisfeest jong txt.1_LS-id1261.csv
# text id 5bfea682a1f050000102619e Ex jong txt.1
# ls id 1262
# path out ../results/kim-full-data-update1/output-5bfea682a1f050000102619e Ex jong txt.1_LS-id1262.csv
# text id 5bfea682a1f050000102619e Klassiek jong txt.1
# ls id 1263
# path out ../results/kim-full-data-update1/output-5bfea682a1f050000102619e Klassiek jong txt.1_LS-id1263.csv
# text id 5bfea682a1f050000102619e Bridge jong txt.1
# ls id 1264
# path out ../results/kim-full-data-update1/output-5bfea682a1f050000102619e Bridge jong txt.1_LS-id1264.csv
# text id pinl55367730d6a7-1367836888b5 Mario jong txt
# ls id 1265
# path out ../results/kim-full-data-update1/output-pinl55367730d6a7-1367836888b5 Mario jong txt_LS-id1265.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl55367730d6a7-1367836888b5 Techno jong txt
# ls id 1266
# path out ../results/kim-full-data-update1/output-pinl55367730d6a7-1367836888b5 Techno jong txt_LS-id1266.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl55367730d6a7-1367836888b5 MAX jong txt
# ls id 1267
# path out ../results/kim-full-data-update1/output-pinl55367730d6a7-1367836888b5 MAX jong txt_LS-id1267.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl55367730d6a7-1367836888b5 Bingo jong txt
# ls id 1268
# path out ../results/kim-full-data-update1/output-pinl55367730d6a7-1367836888b5 Bingo jong txt_LS-id1268.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id pinl5436849c8130-1367836b8d76 Bridge jong txt
# ls id 1269
# path out ../results/kim-full-data-update1/output-pinl5436849c8130-1367836b8d76 Bridge jong txt_LS-id1269.csv
# text id pinl5436849c8130-1367836b8d76 Klassiek jong txt
# ls id 1270
# path out ../results/kim-full-data-update1/output-pinl5436849c8130-1367836b8d76 Klassiek jong txt_LS-id1270.csv
# text id pinl5436849c8130-1367836b8d76 Ex jong txt
# ls id 1271
# path out ../results/kim-full-data-update1/output-pinl5436849c8130-1367836b8d76 Ex jong txt_LS-id1271.csv
# text id pinl5436849c8130-1367836b8d76 Huisfeest jong txt
# ls id 1272
# path out ../results/kim-full-data-update1/output-pinl5436849c8130-1367836b8d76 Huisfeest jong txt_LS-id1272.csv
# text id 6314e2f458c2eaf0856e34b6 Huisfeest jong txt.1
# ls id 1273
# path out ../results/kim-full-data-update1/output-6314e2f458c2eaf0856e34b6 Huisfeest jong txt.1_LS-id1273.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'ChatGPT: emoji', 'Did not finish the study']}
# text id 6314e2f458c2eaf0856e34b6 Ex jong txt.1
# ls id 1274
# path out ../results/kim-full-data-update1/output-6314e2f458c2eaf0856e34b6 Ex jong txt.1_LS-id1274.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'Did not finish the study']}
# text id 6314e2f458c2eaf0856e34b6 Klassiek jong txt.1
# ls id 1275
# path out ../results/kim-full-data-update1/output-6314e2f458c2eaf0856e34b6 Klassiek jong txt.1_LS-id1275.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'Did not finish the study']}
# text id 6314e2f458c2eaf0856e34b6 Bridge jong txt.1
# ls id 1276
# path out ../results/kim-full-data-update1/output-6314e2f458c2eaf0856e34b6 Bridge jong txt.1_LS-id1276.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'Did not finish the study']}
# text id 634d74e57b1bb0fc6abec9ad Huisfeest jong txt.1
# ls id 1277
# path out ../results/kim-full-data-update1/output-634d74e57b1bb0fc6abec9ad Huisfeest jong txt.1_LS-id1277.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id 634d74e57b1bb0fc6abec9ad Ex jong txt.1
# ls id 1278
# path out ../results/kim-full-data-update1/output-634d74e57b1bb0fc6abec9ad Ex jong txt.1_LS-id1278.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id 634d74e57b1bb0fc6abec9ad Klassiek jong txt.1
# ls id 1279
# path out ../results/kim-full-data-update1/output-634d74e57b1bb0fc6abec9ad Klassiek jong txt.1_LS-id1279.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id 634d74e57b1bb0fc6abec9ad Bridge jong txt.1
# ls id 1280
# path out ../results/kim-full-data-update1/output-634d74e57b1bb0fc6abec9ad Bridge jong txt.1_LS-id1280.csv
# no start key but choices
# {'choices': ['Less than 20 words']}
# text id 5e679c9105af6e041cc7ec36 Bingo oud txt.1
# ls id 1281
# path out ../results/kim-full-data-update1/output-5e679c9105af6e041cc7ec36 Bingo oud txt.1_LS-id1281.csv
# text id 5e679c9105af6e041cc7ec36 MAX oud txt.1
# ls id 1282
# path out ../results/kim-full-data-update1/output-5e679c9105af6e041cc7ec36 MAX oud txt.1_LS-id1282.csv
# text id 5e679c9105af6e041cc7ec36 Techno oud txt.1
# ls id 1283
# path out ../results/kim-full-data-update1/output-5e679c9105af6e041cc7ec36 Techno oud txt.1_LS-id1283.csv
# text id 5e679c9105af6e041cc7ec36 Mario oud txt.1
# ls id 1284
# path out ../results/kim-full-data-update1/output-5e679c9105af6e041cc7ec36 Mario oud txt.1_LS-id1284.csv
# text id pinl402389690a22-136733447e30 Mario jong txt
# ls id 1285
# path out ../results/kim-full-data-update1/output-pinl402389690a22-136733447e30 Mario jong txt_LS-id1285.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl402389690a22-136733447e30 Techno jong txt
# ls id 1286
# path out ../results/kim-full-data-update1/output-pinl402389690a22-136733447e30 Techno jong txt_LS-id1286.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl402389690a22-136733447e30 MAX jong txt
# ls id 1287
# path out ../results/kim-full-data-update1/output-pinl402389690a22-136733447e30 MAX jong txt_LS-id1287.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl402389690a22-136733447e30 Bingo jong txt
# ls id 1288
# path out ../results/kim-full-data-update1/output-pinl402389690a22-136733447e30 Bingo jong txt_LS-id1288.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# text id pinl2744460641de-1367836f353e Mario jong txt
# ls id 1289
# path out ../results/kim-full-data-update1/output-pinl2744460641de-1367836f353e Mario jong txt_LS-id1289.csv
# text id pinl2744460641de-1367836f353e Techno jong txt
# ls id 1290
# path out ../results/kim-full-data-update1/output-pinl2744460641de-1367836f353e Techno jong txt_LS-id1290.csv
# text id pinl2744460641de-1367836f353e MAX jong txt
# ls id 1291
# path out ../results/kim-full-data-update1/output-pinl2744460641de-1367836f353e MAX jong txt_LS-id1291.csv
# text id pinl2744460641de-1367836f353e Bingo jong txt
# ls id 1292
# path out ../results/kim-full-data-update1/output-pinl2744460641de-1367836f353e Bingo jong txt_LS-id1292.csv
# text id 605741ea8c4c8aa92716892f Bridge oud txt
# ls id 1293
# path out ../results/kim-full-data-update1/output-605741ea8c4c8aa92716892f Bridge oud txt_LS-id1293.csv
# text id 605741ea8c4c8aa92716892f Klassiek oud txt
# ls id 1294
# path out ../results/kim-full-data-update1/output-605741ea8c4c8aa92716892f Klassiek oud txt_LS-id1294.csv
# text id 605741ea8c4c8aa92716892f Ex oud txt
# ls id 1295
# path out ../results/kim-full-data-update1/output-605741ea8c4c8aa92716892f Ex oud txt_LS-id1295.csv
# text id 605741ea8c4c8aa92716892f Huisfeest oud txt
# ls id 1296
# path out ../results/kim-full-data-update1/output-605741ea8c4c8aa92716892f Huisfeest oud txt_LS-id1296.csv
# text id 6110feef74be159b1e98aff8 Mario jong txt
# ls id 1297
# path out ../results/kim-full-data-update1/output-6110feef74be159b1e98aff8 Mario jong txt_LS-id1297.csv
# text id 6110feef74be159b1e98aff8 Techno jong txt
# ls id 1298
# path out ../results/kim-full-data-update1/output-6110feef74be159b1e98aff8 Techno jong txt_LS-id1298.csv
# text id 6110feef74be159b1e98aff8 MAX jong txt
# ls id 1299
# path out ../results/kim-full-data-update1/output-6110feef74be159b1e98aff8 MAX jong txt_LS-id1299.csv
# text id 6110feef74be159b1e98aff8 Bingo jong txt
# ls id 1300
# path out ../results/kim-full-data-update1/output-6110feef74be159b1e98aff8 Bingo jong txt_LS-id1300.csv
# text id 5e8076447412d474fce1772f Bridge jong txt
# ls id 1301
# path out ../results/kim-full-data-update1/output-5e8076447412d474fce1772f Bridge jong txt_LS-id1301.csv
# text id 5e8076447412d474fce1772f Klassiek jong txt
# ls id 1302
# path out ../results/kim-full-data-update1/output-5e8076447412d474fce1772f Klassiek jong txt_LS-id1302.csv
# text id 5e8076447412d474fce1772f Ex jong txt
# ls id 1303
# path out ../results/kim-full-data-update1/output-5e8076447412d474fce1772f Ex jong txt_LS-id1303.csv
# ...
# text id pinl5524388e3df0-1373475644e0 Huisfeest jong txt.1
# ls id 2273
# path out ../results/kim-full-data-update1/output-pinl5524388e3df0-1373475644e0 Huisfeest jong txt.1_LS-id2273.csv
# text id pinl5524388e3df0-1373475644e0 Ex jong txt.1
# ls id 2274
# path out ../results/kim-full-data-update1/output-pinl5524388e3df0-1373475644e0 Ex jong txt.1_LS-id2274.csv
# text id pinl5524388e3df0-1373475644e0 Klassiek jong txt.1
# ls id 2275
# path out ../results/kim-full-data-update1/output-pinl5524388e3df0-1373475644e0 Klassiek jong txt.1_LS-id2275.csv
# text id pinl5524388e3df0-1373475644e0 Bridge jong txt.1
# ls id 2276
# path out ../results/kim-full-data-update1/output-pinl5524388e3df0-1373475644e0 Bridge jong txt.1_LS-id2276.csv
# text id pinl5499024bae2e-1367334fcab5 Bingo oud txt.1
# ls id 2277
# path out ../results/kim-full-data-update1/output-pinl5499024bae2e-1367334fcab5 Bingo oud txt.1_LS-id2277.csv
# relation has labels
# ['ref-span']
#
# text id pinl5499024bae2e-1367334fcab5 MAX oud txt.1
# ls id 2278
# path out ../results/kim-full-data-update1/output-pinl5499024bae2e-1367334fcab5 MAX oud txt.1_LS-id2278.csv
# text id pinl5499024bae2e-1367334fcab5 Techno oud txt.1
# ls id 2279
# path out ../results/kim-full-data-update1/output-pinl5499024bae2e-1367334fcab5 Techno oud txt.1_LS-id2279.csv
# text id pinl5499024bae2e-1367334fcab5 Mario oud txt.1
# ls id 2280
# path out ../results/kim-full-data-update1/output-pinl5499024bae2e-1367334fcab5 Mario oud txt.1_LS-id2280.csv
# text id 63c5521bf0d5106e06cab3b7 Bridge oud txt
# ls id 2281
# path out ../results/kim-full-data-update1/output-63c5521bf0d5106e06cab3b7 Bridge oud txt_LS-id2281.csv
# text id 63c5521bf0d5106e06cab3b7 Klassiek oud txt
# ls id 2282
# path out ../results/kim-full-data-update1/output-63c5521bf0d5106e06cab3b7 Klassiek oud txt_LS-id2282.csv
# text id 63c5521bf0d5106e06cab3b7 Ex oud txt
# ls id 2283
# path out ../results/kim-full-data-update1/output-63c5521bf0d5106e06cab3b7 Ex oud txt_LS-id2283.csv
# text id 63c5521bf0d5106e06cab3b7 Huisfeest oud txt
# ls id 2284
# path out ../results/kim-full-data-update1/output-63c5521bf0d5106e06cab3b7 Huisfeest oud txt_LS-id2284.csv
# text id pinl242023641094-1367334b0e77 Bingo oud txt.1
# ls id 2285
# path out ../results/kim-full-data-update1/output-pinl242023641094-1367334b0e77 Bingo oud txt.1_LS-id2285.csv
# text id pinl242023641094-1367334b0e77 MAX oud txt.1
# ls id 2286
# path out ../results/kim-full-data-update1/output-pinl242023641094-1367334b0e77 MAX oud txt.1_LS-id2286.csv
# text id pinl242023641094-1367334b0e77 Techno oud txt.1
# ls id 2287
# path out ../results/kim-full-data-update1/output-pinl242023641094-1367334b0e77 Techno oud txt.1_LS-id2287.csv
# text id pinl242023641094-1367334b0e77 Mario oud txt.1
# ls id 2288
# path out ../results/kim-full-data-update1/output-pinl242023641094-1367334b0e77 Mario oud txt.1_LS-id2288.csv
# text id 5fdec49451f3a96b50962819 Huisfeest jong txt.1
# ls id 2289
# path out ../results/kim-full-data-update1/output-5fdec49451f3a96b50962819 Huisfeest jong txt.1_LS-id2289.csv
# text id 5fdec49451f3a96b50962819 Ex jong txt.1
# ls id 2290
# path out ../results/kim-full-data-update1/output-5fdec49451f3a96b50962819 Ex jong txt.1_LS-id2290.csv
# text id 5fdec49451f3a96b50962819 Klassiek jong txt.1
# ls id 2291
# path out ../results/kim-full-data-update1/output-5fdec49451f3a96b50962819 Klassiek jong txt.1_LS-id2291.csv
# text id 5fdec49451f3a96b50962819 Bridge jong txt.1
# ls id 2292
# path out ../results/kim-full-data-update1/output-5fdec49451f3a96b50962819 Bridge jong txt.1_LS-id2292.csv
# text id pinl5517519828ca-1367836ad50d Bridge oud txt
# ls id 2293
# path out ../results/kim-full-data-update1/output-pinl5517519828ca-1367836ad50d Bridge oud txt_LS-id2293.csv
# text id pinl5517519828ca-1367836ad50d Klassiek oud txt
# ls id 2294
# path out ../results/kim-full-data-update1/output-pinl5517519828ca-1367836ad50d Klassiek oud txt_LS-id2294.csv
# text id pinl5517519828ca-1367836ad50d Ex oud txt
# ls id 2295
# path out ../results/kim-full-data-update1/output-pinl5517519828ca-1367836ad50d Ex oud txt_LS-id2295.csv
# text id pinl5517519828ca-1367836ad50d Huisfeest oud txt
# ls id 2296
# path out ../results/kim-full-data-update1/output-pinl5517519828ca-1367836ad50d Huisfeest oud txt_LS-id2296.csv
# text id pinl4947260d03e8-1368444b2d6a Bingo oud txt.1
# ls id 2297
# path out ../results/kim-full-data-update1/output-pinl4947260d03e8-1368444b2d6a Bingo oud txt.1_LS-id2297.csv
# text id pinl4947260d03e8-1368444b2d6a MAX oud txt.1
# ls id 2298
# path out ../results/kim-full-data-update1/output-pinl4947260d03e8-1368444b2d6a MAX oud txt.1_LS-id2298.csv
# text id pinl4947260d03e8-1368444b2d6a Techno oud txt.1
# ls id 2299
# path out ../results/kim-full-data-update1/output-pinl4947260d03e8-1368444b2d6a Techno oud txt.1_LS-id2299.csv
# text id pinl4947260d03e8-1368444b2d6a Mario oud txt.1
# ls id 2300
# path out ../results/kim-full-data-update1/output-pinl4947260d03e8-1368444b2d6a Mario oud txt.1_LS-id2300.csv
# text id pinl44437218a0d-13658566fb63 Huisfeest oud txt.1
# ls id 2301
# path out ../results/kim-full-data-update1/output-pinl44437218a0d-13658566fb63 Huisfeest oud txt.1_LS-id2301.csv
# text id pinl44437218a0d-13658566fb63 Ex oud txt.1
# ls id 2302
# path out ../results/kim-full-data-update1/output-pinl44437218a0d-13658566fb63 Ex oud txt.1_LS-id2302.csv
# text id pinl44437218a0d-13658566fb63 Klassiek oud txt.1
# ls id 2303
# path out ../results/kim-full-data-update1/output-pinl44437218a0d-13658566fb63 Klassiek oud txt.1_LS-id2303.csv
# text id pinl44437218a0d-13658566fb63 Bridge oud txt.1
# ls id 2304
# path out ../results/kim-full-data-update1/output-pinl44437218a0d-13658566fb63 Bridge oud txt.1_LS-id2304.csv
# text id pinl551953500442-13678360675a Bridge jong txt
# ls id 2305
# path out ../results/kim-full-data-update1/output-pinl551953500442-13678360675a Bridge jong txt_LS-id2305.csv
# text id pinl551953500442-13678360675a Klassiek jong txt
# ls id 2306
# path out ../results/kim-full-data-update1/output-pinl551953500442-13678360675a Klassiek jong txt_LS-id2306.csv
# text id pinl551953500442-13678360675a Ex jong txt
# ls id 2307
# path out ../results/kim-full-data-update1/output-pinl551953500442-13678360675a Ex jong txt_LS-id2307.csv
# text id pinl551953500442-13678360675a Huisfeest jong txt
# ls id 2308
# path out ../results/kim-full-data-update1/output-pinl551953500442-13678360675a Huisfeest jong txt_LS-id2308.csv
# text id pinl5134666c2690-1371258511f8 Mario oud txt
# ls id 2309
# path out ../results/kim-full-data-update1/output-pinl5134666c2690-1371258511f8 Mario oud txt_LS-id2309.csv
# text id pinl5134666c2690-1371258511f8 Techno oud txt
# ls id 2310
# path out ../results/kim-full-data-update1/output-pinl5134666c2690-1371258511f8 Techno oud txt_LS-id2310.csv
# text id pinl5134666c2690-1371258511f8 MAX oud txt
# ls id 2311
# path out ../results/kim-full-data-update1/output-pinl5134666c2690-1371258511f8 MAX oud txt_LS-id2311.csv
# text id pinl5134666c2690-1371258511f8 Bingo oud txt
# ls id 2312
# path out ../results/kim-full-data-update1/output-pinl5134666c2690-1371258511f8 Bingo oud txt_LS-id2312.csv
# text id 610d9524847500f0c4992921 Bridge jong txt
# ls id 2313
# path out ../results/kim-full-data-update1/output-610d9524847500f0c4992921 Bridge jong txt_LS-id2313.csv
# text id 610d9524847500f0c4992921 Klassiek jong txt
# ls id 2314
# path out ../results/kim-full-data-update1/output-610d9524847500f0c4992921 Klassiek jong txt_LS-id2314.csv
# text id 610d9524847500f0c4992921 Ex jong txt
# ls id 2315
# path out ../results/kim-full-data-update1/output-610d9524847500f0c4992921 Ex jong txt_LS-id2315.csv
# text id 610d9524847500f0c4992921 Huisfeest jong txt
# ls id 2316
# path out ../results/kim-full-data-update1/output-610d9524847500f0c4992921 Huisfeest jong txt_LS-id2316.csv
# text id pinl174532f7f93-136648263810 Bingo oud txt.1
# ls id 2317
# path out ../results/kim-full-data-update1/output-pinl174532f7f93-136648263810 Bingo oud txt.1_LS-id2317.csv
# relation has labels
# ['ref-span']
#
# text id pinl174532f7f93-136648263810 MAX oud txt.1
# ls id 2318
# path out ../results/kim-full-data-update1/output-pinl174532f7f93-136648263810 MAX oud txt.1_LS-id2318.csv
# text id pinl174532f7f93-136648263810 Techno oud txt.1
# ls id 2319
# path out ../results/kim-full-data-update1/output-pinl174532f7f93-136648263810 Techno oud txt.1_LS-id2319.csv
# text id pinl174532f7f93-136648263810 Mario oud txt.1
# ls id 2320
# path out ../results/kim-full-data-update1/output-pinl174532f7f93-136648263810 Mario oud txt.1_LS-id2320.csv
# text id pinl53850574cb6e-1367836dff01 Bingo jong txt.1
# ls id 2321
# path out ../results/kim-full-data-update1/output-pinl53850574cb6e-1367836dff01 Bingo jong txt.1_LS-id2321.csv
# text id pinl53850574cb6e-1367836dff01 MAX jong txt.1
# ls id 2322
# path out ../results/kim-full-data-update1/output-pinl53850574cb6e-1367836dff01 MAX jong txt.1_LS-id2322.csv
# text id pinl53850574cb6e-1367836dff01 Techno jong txt.1
# ls id 2323
# path out ../results/kim-full-data-update1/output-pinl53850574cb6e-1367836dff01 Techno jong txt.1_LS-id2323.csv
# text id pinl53850574cb6e-1367836dff01 Mario jong txt.1
# ls id 2324
# path out ../results/kim-full-data-update1/output-pinl53850574cb6e-1367836dff01 Mario jong txt.1_LS-id2324.csv
# text id 5faee7e9dea90c0d6c03a15a Mario jong txt
# ls id 2325
# path out ../results/kim-full-data-update1/output-5faee7e9dea90c0d6c03a15a Mario jong txt_LS-id2325.csv
# text id 5faee7e9dea90c0d6c03a15a Techno jong txt
# ls id 2326
# path out ../results/kim-full-data-update1/output-5faee7e9dea90c0d6c03a15a Techno jong txt_LS-id2326.csv
# text id 5faee7e9dea90c0d6c03a15a MAX jong txt
# ls id 2327
# path out ../results/kim-full-data-update1/output-5faee7e9dea90c0d6c03a15a MAX jong txt_LS-id2327.csv
# text id 5faee7e9dea90c0d6c03a15a Bingo jong txt
# ls id 2328
# path out ../results/kim-full-data-update1/output-5faee7e9dea90c0d6c03a15a Bingo jong txt_LS-id2328.csv
# text id pinl55150924bbd1-13678270537a Bingo jong txt.1
# ls id 2329
# path out ../results/kim-full-data-update1/output-pinl55150924bbd1-13678270537a Bingo jong txt.1_LS-id2329.csv
# relation has labels
# ['behav-span']
#
# text id pinl55150924bbd1-13678270537a MAX jong txt.1
# ls id 2330
# path out ../results/kim-full-data-update1/output-pinl55150924bbd1-13678270537a MAX jong txt.1_LS-id2330.csv
# text id pinl55150924bbd1-13678270537a Techno jong txt.1
# ls id 2331
# path out ../results/kim-full-data-update1/output-pinl55150924bbd1-13678270537a Techno jong txt.1_LS-id2331.csv
# text id pinl55150924bbd1-13678270537a Mario jong txt.1
# ls id 2332
# path out ../results/kim-full-data-update1/output-pinl55150924bbd1-13678270537a Mario jong txt.1_LS-id2332.csv
# text id pinl5515176fa075-13684445ad91 Mario oud txt
# ls id 2333
# path out ../results/kim-full-data-update1/output-pinl5515176fa075-13684445ad91 Mario oud txt_LS-id2333.csv
# text id pinl5515176fa075-13684445ad91 Techno oud txt
# ls id 2334
# path out ../results/kim-full-data-update1/output-pinl5515176fa075-13684445ad91 Techno oud txt_LS-id2334.csv
# text id pinl5515176fa075-13684445ad91 MAX oud txt
# ls id 2335
# path out ../results/kim-full-data-update1/output-pinl5515176fa075-13684445ad91 MAX oud txt_LS-id2335.csv
# text id pinl5515176fa075-13684445ad91 Bingo oud txt
# ls id 2336
# path out ../results/kim-full-data-update1/output-pinl5515176fa075-13684445ad91 Bingo oud txt_LS-id2336.csv
# relation has labels
# ['ref-span']
#
# text id pinl553855292ca7-1371564aaa2e Bridge oud txt
# ls id 2337
# path out ../results/kim-full-data-update1/output-pinl553855292ca7-1371564aaa2e Bridge oud txt_LS-id2337.csv
# text id pinl553855292ca7-1371564aaa2e Klassiek oud txt
# ls id 2338
# path out ../results/kim-full-data-update1/output-pinl553855292ca7-1371564aaa2e Klassiek oud txt_LS-id2338.csv
# text id pinl553855292ca7-1371564aaa2e Ex oud txt
# ls id 2339
# path out ../results/kim-full-data-update1/output-pinl553855292ca7-1371564aaa2e Ex oud txt_LS-id2339.csv
# text id pinl553855292ca7-1371564aaa2e Huisfeest oud txt
# ls id 2340
# path out ../results/kim-full-data-update1/output-pinl553855292ca7-1371564aaa2e Huisfeest oud txt_LS-id2340.csv
# text id pinl54436410aa05-136844446317 Bridge jong txt
# ls id 2341
# path out ../results/kim-full-data-update1/output-pinl54436410aa05-136844446317 Bridge jong txt_LS-id2341.csv
# text id pinl54436410aa05-136844446317 Klassiek jong txt
# ls id 2342
# path out ../results/kim-full-data-update1/output-pinl54436410aa05-136844446317 Klassiek jong txt_LS-id2342.csv
# text id pinl54436410aa05-136844446317 Ex jong txt
# ls id 2343
# path out ../results/kim-full-data-update1/output-pinl54436410aa05-136844446317 Ex jong txt_LS-id2343.csv
# text id pinl54436410aa05-136844446317 Huisfeest jong txt
# ls id 2344
# path out ../results/kim-full-data-update1/output-pinl54436410aa05-136844446317 Huisfeest jong txt_LS-id2344.csv
# text id pinl5485795b02f1-13658560daaa Huisfeest oud txt.1
# ls id 2345
# path out ../results/kim-full-data-update1/output-pinl5485795b02f1-13658560daaa Huisfeest oud txt.1_LS-id2345.csv
# text id pinl5485795b02f1-13658560daaa Ex oud txt.1
# ls id 2346
# path out ../results/kim-full-data-update1/output-pinl5485795b02f1-13658560daaa Ex oud txt.1_LS-id2346.csv
# text id pinl5485795b02f1-13658560daaa Klassiek oud txt.1
# ls id 2347
# path out ../results/kim-full-data-update1/output-pinl5485795b02f1-13658560daaa Klassiek oud txt.1_LS-id2347.csv
# text id pinl5485795b02f1-13658560daaa Bridge oud txt.1
# ls id 2348
# path out ../results/kim-full-data-update1/output-pinl5485795b02f1-13658560daaa Bridge oud txt.1_LS-id2348.csv
# text id 633b071944af879cb95cd6ca Mario oud txt
# ls id 2349
# path out ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca Mario oud txt_LS-id2349.csv
# text id 633b071944af879cb95cd6ca Techno oud txt
# ls id 2350
# path out ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca Techno oud txt_LS-id2350.csv
# text id 633b071944af879cb95cd6ca MAX oud txt
# ls id 2351
# path out ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca MAX oud txt_LS-id2351.csv
# text id 633b071944af879cb95cd6ca Bingo oud txt
# ls id 2352
# path out ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca Bingo oud txt_LS-id2352.csv
# text id pinl552445246839-1373475b7c4e Mario oud txt
# ls id 2353
# path out ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e Mario oud txt_LS-id2353.csv
# text id pinl552445246839-1373475b7c4e Techno oud txt
# ls id 2354
# path out ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e Techno oud txt_LS-id2354.csv
# text id pinl552445246839-1373475b7c4e MAX oud txt
# ls id 2355
# path out ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e MAX oud txt_LS-id2355.csv
# text id pinl552445246839-1373475b7c4e Bingo oud txt
# ls id 2356
# path out ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e Bingo oud txt_LS-id2356.csv
# text id pinl5503236a6d6b-1367827b5b1d Huisfeest oud txt.1
# ls id 2357
# path out ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Huisfeest oud txt.1_LS-id2357.csv
# text id pinl5503236a6d6b-1367827b5b1d Ex oud txt.1
# ls id 2358
# path out ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Ex oud txt.1_LS-id2358.csv
# text id pinl5503236a6d6b-1367827b5b1d Klassiek oud txt.1
# ls id 2359
# path out ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Klassiek oud txt.1_LS-id2359.csv
# text id pinl5503236a6d6b-1367827b5b1d Bridge oud txt.1
# ls id 2360
# path out ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Bridge oud txt.1_LS-id2360.csv
# text id pinl5526801ce01f-1366482f36ca Huisfeest oud txt.1
# ls id 2361
# path out ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Huisfeest oud txt.1_LS-id2361.csv
# text id pinl5526801ce01f-1366482f36ca Ex oud txt.1
# ls id 2362
# path out ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Ex oud txt.1_LS-id2362.csv
# text id pinl5526801ce01f-1366482f36ca Klassiek oud txt.1
# ls id 2363
# path out ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Klassiek oud txt.1_LS-id2363.csv
# text id pinl5526801ce01f-1366482f36ca Bridge oud txt.1
# ls id 2364
# path out ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Bridge oud txt.1_LS-id2364.csv
