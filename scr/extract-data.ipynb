# %% [markdown]
# # Analyze LS output - Dataset Chiara

# %%
import json
import csv
from collections import defaultdict
import spacy
import pandas as pd
import os

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# labels

labels = [
    "TC-reference",
    "Behav-predicate",
    "individual-TG-levels",
    "middle-TG-levels",
    "high-TG-levels",
    "supra-TG-levels",
    # negations
    # opposite target category references
]

# %%
# with open('Chiara_full_dataset/labels-chiara.txt') as infile:
#     labels = [l.strip().strip("'").strip('"') for l in infile.read().strip().split('\n')]
# # labels

# %%
def get_labels(annotations):
    offset_label_dict = defaultdict(list)
    id_relation_dict = defaultdict(list)
    # sort_annotations_by_id
    id_ann_dict = defaultdict(list)
    id_name_dict = dict()
    span_relations_dict = dict()

    for an in annotations:
        labels_relations = an['result']
        for la in labels_relations:
            # check if label:
            # print(la)
            # print()
            if 'value' in la:
                target_an = la['value']
                if "start" in target_an:
                    start = target_an['start']
                    end = target_an['end']
                    ann_id = la['id']
                    id_ann_dict[ann_id].append(la)
                    for i in range(start, end):
                        offset_label_dict[i].append(la)
                    if 'labels' in target_an:
                        id_name_dict[ann_id] = target_an['labels'][0]
                elif "choices" in target_an:
                    print("no start key but choices")
                    print(target_an)
                
                
                # print('offsets')
                # print(start, la, type(start))
                

            elif 'from_id' in la:
                from_id = la['from_id']
                to_id = la['to_id']
                id_relation_dict[(from_id, to_id)].append(la)
                if 'labels' in la:
                    print('relation has labels')
                    print(la['labels'])
                    print()
                    span_relations_dict[(from_id, to_id)] = la['labels']
                
                    
            else:
                print(la)
    return offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict




def get_chains(id_relations_dict):
    chains = defaultdict(set)
    coref_id = dict()
    n = 0
    for rel_pair, relations in id_relations_dict.items():
        rel1, rel2 = rel_pair

        if n == 0:
            chains[0].add(rel1)
            chains[0].add(rel2)
            n+=1 

        else:
            added = False
            for pair_n, chain in chains.items():
                if rel1 in chain:
                    chain.add(rel2)
                    added = True
                if rel2 in chain:
                    chain.add(rel1)
                    added = True
            if added == False:
                chains[n].add(rel1)
                chains[n].add(rel2)
                n+=1

    for chain_id, chain in chains.items():
        for label_id in chain:
            coref_id[label_id] = chain_id

    return chains, coref_id

#separate_chains(token_data)

def filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2=None):
 # Filter relations on labels
    id_rel_dict_target = dict()
    if target_label2 is None:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
            
                    
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
                    all_labels = [l for l in l['value']['labels']]
                    if len(all_labels) > 1:
                        print('found more labels:', len(all_labels))
            if l1_name == l2_name:
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
    else:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
        
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
            if ((l1_name == target_label1) and (l2_name == target_label2) 
            or (l1_name == target_label2) and (l2_name == target_label1)):
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
        
    return id_rel_dict_target

        
    
def add_singletons(token_data):
    
    coref_ids = []
    for d in token_data:
        if d['ref-relations'] != []:
            coref_ids.extend(d['ref-relations'])
    # [d['ref-relations'] for d in token_data if d['ref-relations'] != '']
    if len(coref_ids) > 0:
        max_coref_id = max(coref_ids)
    
        single_ent_id = max_coref_id +1 
    else:
        single_ent_id = 0
        
    token_data_by_cat = defaultdict(list)
    for d in token_data:
        tcs = d['TC-reference']
        for t in tcs:
            token_data_by_cat[t].append(d)
        
    
    for t, ds in token_data_by_cat.items():
        added_single_ent = False
        for d in ds:
            #rels = d['ref-relations']
            tcs = d['TC-reference']
            ref_id_rels = d['ref-id-relations']

           
            if tcs != [] and  ref_id_rels == []:
                # singleton!
                d['ref-relations'] = [single_ent_id]
                d['ref-id-relations'] = [f'{single_ent_id}-_-{t}']
                added_single_ent = True
            elif len(tcs) != len(ref_id_rels):
                rels_no_coref = [r.split('-_-')[1] for r in ref_id_rels]
                for t in tcs:
                    if t not in rels_no_coref:
                        d['ref-relations'].append(single_ent_id)
                        d['ref-id-relations'].append(f'{single_ent_id}-_-{t}')
                        added_single_ent = True
            else:
                continue
        
        if added_single_ent:
            single_ent_id += 1
            
            
def make_relation_mappings(id_relation_dict, id_name_dict):
    
    coref_mappings = dict()
    behav_mappings = defaultdict(list)
    
    for id_pair, d_list in id_relation_dict.items():
        id1, id2 = id_pair
        label1 = id_name_dict[id1]
        label2 = id_name_dict[id2]

   
        
        #if rel_type == 'ref-behav
        if label1 == label2 == 'TC-reference':
            # print('coref', label1, label2)
            coref_mappings[id1] = id2
            coref_mappings[id2] = id1
        # elif label1 == label2 == 'Behavior-predicate':
        #     pass
        elif label1 == 'Behav-predicate' and label2 == 'TC-reference':
            # 
            behav_mappings[id2].append(id1)
        elif label1 == 'TC-reference' and label2 == 'Behav-predicate':
            behav_mappings[id1].append(id2)

        #elif label1 
            
    return coref_mappings, behav_mappings

# %%
### TEST COREF CHAIN CODE

name = 'kim-full-data-update1'
output = 'data'
path = f'../{output}/{name}.json'

dir_out = f'../results/{name}'
if not os.path.isdir(dir_out):
    os.mkdir(dir_out)

with open(path) as infile:
    annotation_data = json.load(infile)
    
for n, data in enumerate(annotation_data):
    ls_id = data['id']
    annotations = data['annotations']

    
    text = data['data']['text']
    text_id = text.split('\n', 1)[0].split(': ')[-1]
    print(text_id, ls_id)
    path_out = f'{dir_out}/output-{text_id}_LS-id{ls_id}.csv'
    print(path_out)
    
    offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict = get_labels(annotations)
    coref_mappings, behav_mappings = make_relation_mappings(id_relation_dict, id_name_dict)
    

    target_label = 'TC-reference'
    id_relations_ref = filter_relations(id_relation_dict, id_ann_dict, target_label)
    
    target_label1 = 'TC-reference'
    target_label2 =  "Behavior-predicate"
    id_relations_behav = filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2)

    span_dict_end = dict()
    # span_dict_start = dict()
    
    for (l1, l2), la in span_relations_dict.items():
        # span_dict_start[l1] = l2
        span_dict_end[l2] = l1
        
        
    coref_chains_ref, coref_dict_ref = get_chains(id_relations_ref)
    coref_chains_behav, coref_dict_behav = get_chains(id_relations_behav)
    
      
    
    doc = nlp(text)

    
    tok_id_ann_id_dict = defaultdict(set)
  
    
    for tok in doc:
        tok_start = tok.idx

        for i in range(tok.idx, tok.idx+len(tok)):
            if i in offset_label_dict:
                anns = offset_label_dict[i]
                for an in anns:
                    an_id = an['id']
                    tok_id_ann_id_dict[tok.i].add(an_id)

    token_data = []
    for tok in doc:
        
        tok_id = tok.i
        tok_dict = defaultdict(list)
        tok_dict['tok-id'] = tok_id
        tok_dict['token'] = tok.text
        tok_dict['ref-relations'] = []
        tok_dict['ref-behav-relations'] = []
        tok_dict['ref-id-relations'] = []
        tok_dict['coref-id-mapping'] = []
        tok_dict['behav-id-mapping'] = []
        tok_dict['ref-span'] = ''
                 
        # tok_dict['ref-behav-relations-new'] = ''

        #tok_dict['TC-COREF'] = ''
        for l in labels:
            tok_dict[l] = []
            
        
        an_ids = tok_id_ann_id_dict[tok_id]
        # print(tok_id, an_ids)

        for an_id in an_ids:        
            anns = id_ann_dict[an_id]
            
     
            #rels = an_rel_dict[an_id]
            for an in anns:
                add_label = ''

                if 'from_name' in an:
                    add_label = an['from_name']
                    
                if 'labels' in an['value']:
                    label = an['value']['labels'][0]
                    if an_id in span_dict_end:
                        an_id_new = span_dict_end[an_id]
                        tok_dict[f'{label}'].append(an_id_new)
                    else:
                        tok_dict[f'{label}'].append(an_id)
                if 'choices' in an['value']:
                    for choice in an['value']['choices']:
                        if add_label != '':
                            if an_id in span_dict_end:
                                an_id_new = span_dict_end[an_id]
                                tok_dict[f'{choice}-{add_label}'].append(an_id_new)
                            else:
                                tok_dict[f'{choice}-{add_label}'].append(an_id)
                        else:
                            if an_id in span_dict_end:
                                an_id_new = span_dict_end[an_id]
                                tok_dict[choice].append(an_id_new)
                            else:
                                tok_dict[choice].append(an_id)

             # coref:
            # if an_id in coref_dict_behav:
            #     pass
            #     # if tok_dict['relations'] == '':
            #     #tok_dict['ref-behav-relations'] = coref_dict[an_id]
            #     # if an_id in span_dict_end:
            #     #     an_id_new = span_dict_end[an_id]
            #     #     tok_dict['ref-behav-relations'].append(coref_dict_behav[an_id_new])
            #     # else:
            #     #     tok_dict['ref-behav-relations'].append(coref_dict_behav[an_id])
            #     #tok_dict['ref-relations'] = coref_dict_ref[an_id]

            if an_id in coref_dict_ref:
                
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                    tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id_new}')
                else:
                    tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                    tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id}')
            
            if an_id in coref_mappings:
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    coref_id = coref_mappings[an_id]
                    if coref_id in span_dict_end:
                        coref_id = span_dict_end[coref_id]
                
                    tok_dict['coref-id-mapping'].append(f'{an_id_new}-_-{coref_id}')
                else:
                    coref_id = coref_mappings[an_id]
                    if coref_id in span_dict_end:
                        coref_id = span_dict_end[coref_id]
                    tok_dict['coref-id-mapping'].append(f'{an_id}-_-{coref_id}')
                
            if an_id in behav_mappings:
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    for behav_id in behav_mappings[an_id_new]:
                        tok_dict['behav-id-mapping'].append(f'{an_id_new}-_-{behav_id}')
                else:
                    for behav_id in behav_mappings[an_id]:
                        tok_dict['behav-id-mapping'].append(f'{an_id}-_-{behav_id}')
          
  
        token_data.append(tok_dict)


    add_singletons(token_data)
    


    
    for tok_dict in token_data:

        for k, v in tok_dict.items():
            if type(v) == list:
                v = [str(i) for i in v]
                tok_dict[k] = ' '.join(v)
            else:
                tok_dict[k] = v
                
                
    # apply span information - same id

        
    df = pd.DataFrame(token_data)
    df.to_csv(path_out, index=False)
# Out:
# pinl2004022643db-13712588e47d Huisfeest oud txt.1 1057
# ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Huisfeest oud txt.1_LS-id1057.csv
# relation has labels
# ['behav-span']
#
# pinl2004022643db-13712588e47d Ex oud txt.1 1058
# ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Ex oud txt.1_LS-id1058.csv
# relation has labels
# ['behav-span']
#
# pinl2004022643db-13712588e47d Klassiek oud txt.1 1059
# ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Klassiek oud txt.1_LS-id1059.csv
# pinl2004022643db-13712588e47d Bridge oud txt.1 1060
# ../results/kim-full-data-update1/output-pinl2004022643db-13712588e47d Bridge oud txt.1_LS-id1060.csv
# 63fd069cb47d538f11dc7ed2 Bingo oud txt.1 1061
# ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 Bingo oud txt.1_LS-id1061.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# 63fd069cb47d538f11dc7ed2 MAX oud txt.1 1062
# ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 MAX oud txt.1_LS-id1062.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# 63fd069cb47d538f11dc7ed2 Techno oud txt.1 1063
# ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 Techno oud txt.1_LS-id1063.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'WPM']}
# 63fd069cb47d538f11dc7ed2 Mario oud txt.1 1064
# ../results/kim-full-data-update1/output-63fd069cb47d538f11dc7ed2 Mario oud txt.1_LS-id1064.csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure', 'ChatGPT: emoji', 'WPM']}
# 6310a5b5af42fb718e0f203b Mario jong txt 1065
# ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b Mario jong txt_LS-id1065.csv
# no start key but choices
# {'choices': ['WPM']}
# 6310a5b5af42fb718e0f203b Techno jong txt 1066
# ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b Techno jong txt_LS-id1066.csv
# no start key but choices
# {'choices': ['WPM']}
# 6310a5b5af42fb718e0f203b MAX jong txt 1067
# ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b MAX jong txt_LS-id1067.csv
# no start key but choices
# {'choices': ['WPM']}
# 6310a5b5af42fb718e0f203b Bingo jong txt 1068
# ../results/kim-full-data-update1/output-6310a5b5af42fb718e0f203b Bingo jong txt_LS-id1068.csv
# no start key but choices
# {'choices': ['WPM']}
# pinl909067dd848-1371258d9295 Bridge jong txt 1069
# ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Bridge jong txt_LS-id1069.csv
# relation has labels
# ['behav-span']
#
# pinl909067dd848-1371258d9295 Klassiek jong txt 1070
# ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Klassiek jong txt_LS-id1070.csv
# pinl909067dd848-1371258d9295 Ex jong txt 1071
# ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Ex jong txt_LS-id1071.csv
# pinl909067dd848-1371258d9295 Huisfeest jong txt 1072
# ../results/kim-full-data-update1/output-pinl909067dd848-1371258d9295 Huisfeest jong txt_LS-id1072.csv
# 5edab253669692706f731c3d Bingo jong txt.1 1073
# ../results/kim-full-data-update1/output-5edab253669692706f731c3d Bingo jong txt.1_LS-id1073.csv
# relation has labels
# ['behav-span']
#
# 5edab253669692706f731c3d MAX jong txt.1 1074
# ../results/kim-full-data-update1/output-5edab253669692706f731c3d MAX jong txt.1_LS-id1074.csv
# relation has labels
# ['behav-span']
#
# 5edab253669692706f731c3d Techno jong txt.1 1075
# ../results/kim-full-data-update1/output-5edab253669692706f731c3d Techno jong txt.1_LS-id1075.csv
# 5edab253669692706f731c3d Mario jong txt.1 1076
# ../results/kim-full-data-update1/output-5edab253669692706f731c3d Mario jong txt.1_LS-id1076.csv
# relation has labels
# ['behav-span']
#
# pinl62308698482-1367334ebf62 Mario jong txt 1077
# ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 Mario jong txt_LS-id1077.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# pinl62308698482-1367334ebf62 Techno jong txt 1078
# ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 Techno jong txt_LS-id1078.csv
# pinl62308698482-1367334ebf62 MAX jong txt 1079
# ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 MAX jong txt_LS-id1079.csv
# relation has labels
# ['behav-span']
#
# pinl62308698482-1367334ebf62 Bingo jong txt 1080
# ../results/kim-full-data-update1/output-pinl62308698482-1367334ebf62 Bingo jong txt_LS-id1080.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# 63d187501b04c6fb0697f2b5 Huisfeest oud txt.1 1081
# ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Huisfeest oud txt.1_LS-id1081.csv
# 63d187501b04c6fb0697f2b5 Ex oud txt.1 1082
# ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Ex oud txt.1_LS-id1082.csv
# 63d187501b04c6fb0697f2b5 Klassiek oud txt.1 1083
# ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Klassiek oud txt.1_LS-id1083.csv
# 63d187501b04c6fb0697f2b5 Bridge oud txt.1 1084
# ../results/kim-full-data-update1/output-63d187501b04c6fb0697f2b5 Bridge oud txt.1_LS-id1084.csv
# relation has labels
# ['behav-span']
#
# pinl166643c6492-13673346445d Bridge oud txt 1085
# ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Bridge oud txt_LS-id1085.csv
# relation has labels
# ['behav-span']
#
# pinl166643c6492-13673346445d Klassiek oud txt 1086
# ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Klassiek oud txt_LS-id1086.csv
# relation has labels
# ['behav-span']
#
# pinl166643c6492-13673346445d Ex oud txt 1087
# ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Ex oud txt_LS-id1087.csv
# pinl166643c6492-13673346445d Huisfeest oud txt 1088
# ../results/kim-full-data-update1/output-pinl166643c6492-13673346445d Huisfeest oud txt_LS-id1088.csv
# relation has labels
# ['behav-span']
#
# 63528428d18878b30041e791 Huisfeest oud txt.1 1089
# ../results/kim-full-data-update1/output-63528428d18878b30041e791 Huisfeest oud txt.1_LS-id1089.csv
# relation has labels
# ['behav-span']
#
# 63528428d18878b30041e791 Ex oud txt.1 1090
# ../results/kim-full-data-update1/output-63528428d18878b30041e791 Ex oud txt.1_LS-id1090.csv
# 63528428d18878b30041e791 Klassiek oud txt.1 1091
# ../results/kim-full-data-update1/output-63528428d18878b30041e791 Klassiek oud txt.1_LS-id1091.csv
# 63528428d18878b30041e791 Bridge oud txt.1 1092
# ../results/kim-full-data-update1/output-63528428d18878b30041e791 Bridge oud txt.1_LS-id1092.csv
# 60076986348bb62629139c82 Mario oud txt 1093
# ../results/kim-full-data-update1/output-60076986348bb62629139c82 Mario oud txt_LS-id1093.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# 60076986348bb62629139c82 Techno oud txt 1094
# ../results/kim-full-data-update1/output-60076986348bb62629139c82 Techno oud txt_LS-id1094.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# 60076986348bb62629139c82 MAX oud txt 1095
# ../results/kim-full-data-update1/output-60076986348bb62629139c82 MAX oud txt_LS-id1095.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# 60076986348bb62629139c82 Bingo oud txt 1096
# ../results/kim-full-data-update1/output-60076986348bb62629139c82 Bingo oud txt_LS-id1096.csv
# relation has labels
# ['behav-span']
#
# relation has labels
# ['behav-span']
#
# 5cda5b38480d7d00196cd9c0 Bridge oud txt 1097
# ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Bridge oud txt_LS-id1097.csv
# 5cda5b38480d7d00196cd9c0 Klassiek oud txt 1098
# ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Klassiek oud txt_LS-id1098.csv
# relation has labels
# ['behav-span']
#
# 5cda5b38480d7d00196cd9c0 Ex oud txt 1099
# ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Ex oud txt_LS-id1099.csv
# 5cda5b38480d7d00196cd9c0 Huisfeest oud txt 1100
# ../results/kim-full-data-update1/output-5cda5b38480d7d00196cd9c0 Huisfeest oud txt_LS-id1100.csv
# pinl4253902185-1366118be5a2 Bingo jong txt.1 1101
# ../results/kim-full-data-update1/output-pinl4253902185-1366118be5a2 Bingo jong txt.1_LS-id1101.csv
csv
# no start key but choices
# {'choices': ['ChatGPT: punctution', 'ChatGPT: structure']}
# 5995b8a6bf8bcf0001ab6aed Bingo oud txt.1 1137
# ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed Bingo oud txt.1_LS-id1137.csv
# 5995b8a6bf8bcf0001ab6aed MAX oud txt.1 1138
# ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed MAX oud txt.1_LS-id1138.csv
# 5995b8a6bf8bcf0001ab6aed Techno oud txt.1 1139
# ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed Techno oud txt.1_LS-id1139.csv
# relation has labels
# ['ref-span']
#
# 5995b8a6bf8bcf0001ab6aed Mario oud txt.1 1140
# ../results/kim-full-data-update1/output-5995b8a6bf8bcf0001ab6aed Mario oud txt.1_LS-id1140.csv
# 5d641f290540c40015e74213 Mario jong txt 1141
# ../results/kim-full-data-update1/output-5d641f290540c40015e74213 Mario jong txt_LS-id1141.csv
# 5d641f290540c40015e74213 Techno jong txt 1142
# ../results/kim-full-data-update1/output-5d641f290540c40015e74213 Techno jong txt_LS-id1142.csv
# 5d641f290540c40015e74213 MAX jong txt 1143
# ../results/kim-full-data-update1/output-5d641f290540c40015e74213 MAX jong txt_LS-id1143.csv
# 5d641f290540c40015e74213 Bingo jong txt 1144
# ../results/kim-full-data-update1/output-5d641f290540c40015e74213 Bingo jong txt_LS-id1144.csv
# 640550f7006e663f75ca4379 Bingo oud txt.1 1145
# ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 Bingo oud txt.1_LS-id1145.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# relation has labels
# ['behav-span']
#
# 640550f7006e663f75ca4379 MAX oud txt.1 1146
# ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 MAX oud txt.1_LS-id1146.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# 640550f7006e663f75ca4379 Techno oud txt.1 1147
# ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 Techno oud txt.1_LS-id1147.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# relation has labels
# ['behav-span']
#
# 640550f7006e663f75ca4379 Mario oud txt.1 1148
# ../results/kim-full-data-update1/output-640550f7006e663f75ca4379 Mario oud txt.1_LS-id1148.csv
# no start key but choices
# {'choices': ['ChatGPT: structure']}
# 635279674095bcdfa5a55fd5 Huisfeest jong txt.1 1149
# ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Huisfeest jong txt.1_LS-id1149.csv
# no start key but choices
# {'choices': ['WPM']}
# 635279674095bcdfa5a55fd5 Ex jong txt.1 1150
# ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Ex jong txt.1_LS-id1150.csv
# no start key but choices
# {'choices': ['WPM']}
# 635279674095bcdfa5a55fd5 Klassiek jong txt.1 1151
# ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Klassiek jong txt.1_LS-id1151.csv
# no start key but choices
# {'choices': ['WPM']}
# 635279674095bcdfa5a55fd5 Bridge jong txt.1 1152
# ../results/kim-full-data-update1/output-635279674095bcdfa5a55fd5 Bridge jong txt.1_LS-id1152.csv
# no start key but choices
# {'choices': ['WPM']}
# pinl2697881468e7-1367827835db Huisfeest oud txt.1 1153
# ../results/kim-full-data-update1/output-pinl2697881468e7-1367827835db Huisfeest oud txt.1_LS-id1153.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# pinl2697881468e7-1367827835db Ex oud txt.1 1154
# ../results/kim-full-data-update1/output-pinl2697881468e7-1367827835db Ex oud txt.1_LS-id1154.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# pin
# ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Klassiek jong txt_LS-id1210.csv
# pinl3829781bb3ae-13678365c257 Ex jong txt 1211
# ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Ex jong txt_LS-id1211.csv
# pinl3829781bb3ae-13678365c257 Huisfeest jong txt 1212
# ../results/kim-full-data-update1/output-pinl3829781bb3ae-13678365c257 Huisfeest jong txt_LS-id1212.csv
# pinl552579036036-1373475d31ba Huisfeest jong txt.1 1213
# ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Huisfeest jong txt.1_LS-id1213.csv
# no start key but choices
# {'choices': ['WPM']}
# pinl552579036036-1373475d31ba Ex jong txt.1 1214
# ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Ex jong txt.1_LS-id1214.csv
# no start key but choices
# {'choices': ['WPM']}
# pinl552579036036-1373475d31ba Klassiek jong txt.1 1215
# ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Klassiek jong txt.1_LS-id1215.csv
# no start key but choices
# {'choices': ['WPM']}
# pinl552579036036-1373475d31ba Bridge jong txt.1 1216
# ../results/kim-full-data-update1/output-pinl552579036036-1373475d31ba Bridge jong txt.1_LS-id1216.csv
# no start key but choices
# {'choices': ['WPM']}
# 6116d3e040d816a2d509a28a Mario jong txt 1217
# ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a Mario jong txt_LS-id1217.csv
# 6116d3e040d816a2d509a28a Techno jong txt 1218
# ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a Techno jong txt_LS-id1218.csv
# 6116d3e040d816a2d509a28a MAX jong txt 1219
# ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a MAX jong txt_LS-id1219.csv
# 6116d3e040d816a2d509a28a Bingo jong txt 1220
# ../results/kim-full-data-update1/output-6116d3e040d816a2d509a28a Bingo jong txt_LS-id1220.csv
# 63f0c1057f083573d83a2d62 Bingo oud txt.1 1221
# ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 Bingo oud txt.1_LS-id1221.csv
# 63f0c1057f083573d83a2d62 MAX oud txt.1 1222
# ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 MAX oud txt.1_LS-id1222.csv
# 63f0c1057f083573d83a2d62 Techno oud txt.1 1223
# ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 Techno oud txt.1_LS-id1223.csv
# 63f0c1057f083573d83a2d62 Mario oud txt.1 1224
# ../results/kim-full-data-update1/output-63f0c1057f083573d83a2d62 Mario oud txt.1_LS-id1224.csv
# pinl54925326d645-136782792445 Mario jong txt 1225
# ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 Mario jong txt_LS-id1225.csv
# pinl54925326d645-136782792445 Techno jong txt 1226
# ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 Techno jong txt_LS-id1226.csv
# pinl54925326d645-136782792445 MAX jong txt 1227
# ../results/kim-full-data-update1/output-pinl54925326d645-136782792445 MAX jong txt_LS-id1227.csv
# pinl549672429394-1367836a1f68 Bingo oud txt 1320
# ../results/kim-full-data-update1/output-pinl549672429394-1367836a1f68 Bingo oud txt_LS-id1320.csv
# 6110d75f4cfd0b62e7d2e13c Huisfeest oud txt.1 1321
# ../results/kim-full-data-update1/output-6110d75f4cfd0b62e7d2e13c Huisfeest oud txt.1_LS-id1321.csv
# 6110d75f4cfd0b62e7d2e13c Ex oud txt.1 1322
# ../results/kim-full-data-update1/output-6110d75f4cfd0b62e7d2e13c Ex oud txt.1_LS-id1322.csv
# 6110d75f4cfd0b62e7d2e13c Klassiek oud txt.1 1323
# ../results/kim-full-data-update1/output-6110d75f4cfd0b62e7d2e13c Klassiek oud txt.1_LS-id1323.csv
# 6110d75f4cfd0b62e7d2e13c Bridge oud txt.1 1324
# ../results/kim-full-data-update1/output-6110d75f4cfd0b62e7d2e13c Bridge oud txt.1_LS-id1324.csv
# pinl2932406c5ae5-1373475d13e4 Huisfeest oud txt.1 1325
# ../results/kim-full-data-update1/output-pinl2932406c5ae5-1373475d13e4 Huisfeest oud txt.1_LS-id1325.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# pinl2932406c5ae5-1373475d13e4 Ex oud txt.1 1326
# ../results/kim-full-data-update1/output-pinl2932406c5ae5-1373475d13e4 Ex oud txt.1_LS-id1326.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# pinl2932406c5ae5-1373475d13e4 Klassiek oud txt.1 1327
# ../results/kim-full-data-update1/output-pinl2932406c5ae5-1373475d13e4 Klassiek oud txt.1_LS-id1327.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# pinl2932406c5ae5-1373475d13e4 Bridge oud txt.1 1328
# ../results/kim-full-data-update1/output-pinl2932406c5ae5-1373475d13e4 Bridge oud txt.1_LS-id1328.csv
# no start key but choices
# {'choices': ['Misunderstood task']}
# 59f4c1d805d1d60001f1429e Bingo oud txt.1 1329
# ../results/kim-full-data-update1/output-59f4c1d805d1d60001f1429e Bingo oud txt.1_LS-id1329.csv
# 59f4c1d805d1d60001f1429e MAX oud txt.1 1330
# ../results/kim-full-data-update1/output-59f4c1d805d1d60001f1429e MAX oud txt.1_LS-id1330.csv
# 59f4c1d805d1d60001f1429e Techno oud txt.1 1331
# ../results/kim-full-data-update1/output-59f4c1d805d1d60001f1429e Techno oud txt.1_LS-id1331.csv
# relation has labels
# ['ref-span']
#
# 59f4c1d805d1d60001f1429e Mario oud txt.1 1332
# ../results/kim-full-data-update1/output-59f4c1d805d1d60001f1429e Mario oud txt.1_LS-id1332.csv
# 5751477b947a3d0007b53c2c Bridge jong txt 1333
# ../results/kim-full-data-update1/output-5751477b947a3d0007b53c2c Bridge jong txt_LS-id1333.csv
# 5751477b947a3d0007b53c2c Klassiek jong txt 1334
# ../results/kim-full-data-update1/output-5751477b947a3d0007b53c2c Klassiek jong txt_LS-id1334.csv
# relation has labels
# ['ref-span']
#
# 5751477b947a3d0007b53c2c Ex jong txt 1335
# ../results/kim-full-data-update1/output-5751477b947a3d0007b53c2c Ex jong txt_LS-id1335.csv
# 5751477b947a3d0007b53c2c Huisfeest jong txt 1336
# ../results/kim-full-data-update1/output-5751477b947a3d0007b53c2c Huisfeest jong txt_LS-id1336.csv
# 5c4325e45aca820001f72601 Bridge jong txt 1337
# pinl5485795b02f1-13658560daaa Klassiek oud txt.1 2347
# ../results/kim-full-data-update1/output-pinl5485795b02f1-13658560daaa Klassiek oud txt.1_LS-id2347.csv
# pinl5485795b02f1-13658560daaa Bridge oud txt.1 2348
# ../results/kim-full-data-update1/output-pinl5485795b02f1-13658560daaa Bridge oud txt.1_LS-id2348.csv
# 633b071944af879cb95cd6ca Mario oud txt 2349
# ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca Mario oud txt_LS-id2349.csv
# 633b071944af879cb95cd6ca Techno oud txt 2350
# ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca Techno oud txt_LS-id2350.csv
# 633b071944af879cb95cd6ca MAX oud txt 2351
# ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca MAX oud txt_LS-id2351.csv
# 633b071944af879cb95cd6ca Bingo oud txt 2352
# ../results/kim-full-data-update1/output-633b071944af879cb95cd6ca Bingo oud txt_LS-id2352.csv
# pinl552445246839-1373475b7c4e Mario oud txt 2353
# ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e Mario oud txt_LS-id2353.csv
# pinl552445246839-1373475b7c4e Techno oud txt 2354
# ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e Techno oud txt_LS-id2354.csv
# pinl552445246839-1373475b7c4e MAX oud txt 2355
# ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e MAX oud txt_LS-id2355.csv
# pinl552445246839-1373475b7c4e Bingo oud txt 2356
# ../results/kim-full-data-update1/output-pinl552445246839-1373475b7c4e Bingo oud txt_LS-id2356.csv
# pinl5503236a6d6b-1367827b5b1d Huisfeest oud txt.1 2357
# ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Huisfeest oud txt.1_LS-id2357.csv
# pinl5503236a6d6b-1367827b5b1d Ex oud txt.1 2358
# ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Ex oud txt.1_LS-id2358.csv
# pinl5503236a6d6b-1367827b5b1d Klassiek oud txt.1 2359
# ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Klassiek oud txt.1_LS-id2359.csv
# pinl5503236a6d6b-1367827b5b1d Bridge oud txt.1 2360
# ../results/kim-full-data-update1/output-pinl5503236a6d6b-1367827b5b1d Bridge oud txt.1_LS-id2360.csv
# pinl5526801ce01f-1366482f36ca Huisfeest oud txt.1 2361
# ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Huisfeest oud txt.1_LS-id2361.csv
# pinl5526801ce01f-1366482f36ca Ex oud txt.1 2362
# ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Ex oud txt.1_LS-id2362.csv
# pinl5526801ce01f-1366482f36ca Klassiek oud txt.1 2363
# ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Klassiek oud txt.1_LS-id2363.csv
# pinl5526801ce01f-1366482f36ca Bridge oud txt.1 2364
# ../results/kim-full-data-update1/output-pinl5526801ce01f-1366482f36ca Bridge oud txt.1_LS-id2364.csv

# %%
# tok_starts
