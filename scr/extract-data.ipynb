# %% [markdown]
# # Analyze LS output - Dataset Kim

# %%
import json
import csv
from collections import defaultdict
import spacy
import pandas as pd
import os

# %%
nlp = spacy.load("nl_core_news_sm")

# %%
# labels

labels = [
    # "TC-reference",
    # "Behav-predicate",
    # "individual-TG-levels",
    # "middle-TG-levels",
    # "high-TG-levels",
    # "supra-TG-levels",
    # 'OPP-TC-reference',
    # "Exclude", 
    # "ChatGPT: punctution",
    # "ChatGPT: emoji",
    # "Misunderstood task",
    # "No consent",
    # "Less than 20 words",
    # "No consent",
    # "Did not finish the study",
    # "WPM"
    
"OPP-TC-reference",
"HN-pronoun-LCM-ref",
"supra-OPP-TG-levels",
"Negate-Negate OPP-Target-Behavior",
"TC-reference",
"OPP-Behav-predicate",
"supra-TG-levels",
"high-TG-levels",
"Behav-predicate",
"speech",
"Negate-Negate Target-Behavior",
"Negate-Negate TC-reference",
"individual-TG-levels",
"HN-empty-LCM-ref",
"middle-TG-levels",
"MENT-ST-LCM-behavior",
    "Exclude", 
    "ChatGPT: punctution",
    "ChatGPT: emoji",
    "Misunderstood task",
    "No consent",
    "Less than 20 words",
    "No consent",
    "Did not finish the study",
    "WPM"

]

# %%
def get_labels(annotations):
    offset_label_dict = defaultdict(list)
    id_relation_dict = defaultdict(list)
    # sort_annotations_by_id
    id_ann_dict = defaultdict(list)
    id_name_dict = dict()
    span_relations_dict = dict()
    text_level = []

    for an in annotations:
        labels_relations = an['result']
        for la in labels_relations:
            # check if label:
            # print(la)
            # print()
            if 'value' in la:
                target_an = la['value']
                if "start" in target_an:
                    start = target_an['start']
                    end = target_an['end']
                    ann_id = la['id']
                    id_ann_dict[ann_id].append(la)
                    for i in range(start, end):
                        offset_label_dict[i].append(la)
                    if 'labels' in target_an:
                        id_name_dict[ann_id] = target_an['labels'][0]
                elif "choices" in target_an:
                    # print("no start key but choices")
                    # print(target_an)
                    text_level = target_an['choices']
                
                
                # print('offsets')
                # print(start, la, type(start))
                

            elif 'from_id' in la:
                from_id = la['from_id']
                to_id = la['to_id']
                id_relation_dict[(from_id, to_id)].append(la)
                if 'labels' in la:
                    # print('relation has labels')
                    # print(la['labels'])
                    # print()
                    span_relations_dict[(from_id, to_id)] = la['labels']
                
                    
            else:
                print(la)
    return offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict, text_level




def get_chains(id_relations_dict):
    chains = defaultdict(set)
    coref_id = dict()
    n = 0
    for rel_pair, relations in id_relations_dict.items():
        rel1, rel2 = rel_pair

        if n == 0:
            chains[0].add(rel1)
            chains[0].add(rel2)
            n+=1 

        else:
            added = False
            for pair_n, chain in chains.items():
                if rel1 in chain:
                    chain.add(rel2)
                    added = True
                if rel2 in chain:
                    chain.add(rel1)
                    added = True
            if added == False:
                chains[n].add(rel1)
                chains[n].add(rel2)
                n+=1

    for chain_id, chain in chains.items():
        for label_id in chain:
            coref_id[label_id] = chain_id

    return chains, coref_id

#separate_chains(token_data)

def filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2=None):
 # Filter relations on labels
    id_rel_dict_target = dict()
    if target_label2 is None:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
            
                    
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
                    all_labels = [l for l in l['value']['labels']]
                    if len(all_labels) > 1:
                        print('found more labels:', len(all_labels))
            if l1_name == l2_name:
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
    else:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
        
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
            if ((l1_name == target_label1) and (l2_name == target_label2) 
            or (l1_name == target_label2) and (l2_name == target_label1)):
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
        
    return id_rel_dict_target

        
    
def add_singletons(token_data):
    
    coref_ids = []
    for d in token_data:
        if d['ref-relations'] != []:
            coref_ids.extend(d['ref-relations'])
    # [d['ref-relations'] for d in token_data if d['ref-relations'] != '']
    if len(coref_ids) > 0:
        max_coref_id = max(coref_ids)
    
        single_ent_id = max_coref_id +1 
    else:
        single_ent_id = 0
        
    token_data_by_cat = defaultdict(list)
    for d in token_data:
        tcs = d['TC-reference']
        opp = d['OPP-TC-reference']
        for t in tcs:
            token_data_by_cat[t].append(d)
        for t in opp:
            token_data_by_cat[t].append(d)
        
        
    
    for t, ds in token_data_by_cat.items():
        added_single_ent = False
        for d in ds:
            #rels = d['ref-relations']
            tcs = d['TC-reference']
            opp = d['OPP-TC-reference']
            ref_id_rels = d['ref-id-relations']

           
            if tcs != [] and  ref_id_rels == []:
                # singleton!
                d['ref-relations'] = [single_ent_id]
                d['ref-id-relations'] = [f'{single_ent_id}-_-{t}']
                added_single_ent = True
            elif opp != [] and  ref_id_rels == []:
                # singleton!
                d['ref-relations'] = [single_ent_id]
                d['ref-id-relations'] = [f'{single_ent_id}-_-{t}']
                added_single_ent = True
            elif len(tcs) != len(ref_id_rels):
                rels_no_coref = [r.split('-_-')[1] for r in ref_id_rels]
                for t in tcs:
                    if t not in rels_no_coref:
                        d['ref-relations'].append(single_ent_id)
                        d['ref-id-relations'].append(f'{single_ent_id}-_-{t}')
                        added_single_ent = True
            elif len(opp) != len(ref_id_rels):
                rels_no_coref = [r.split('-_-')[1] for r in ref_id_rels]
                for t in opp:
                    if t not in rels_no_coref:
                        d['ref-relations'].append(single_ent_id)
                        d['ref-id-relations'].append(f'{single_ent_id}-_-{t}')
                        added_single_ent = True
            else:
                continue
        
        if added_single_ent:
            single_ent_id += 1
            
            
def make_relation_mappings(id_relation_dict, id_name_dict):
    
    coref_mappings = dict()
    behav_mappings = defaultdict(list)
    
    for id_pair, d_list in id_relation_dict.items():
        id1, id2 = id_pair
        label1 = id_name_dict[id1]
        label2 = id_name_dict[id2]

   
        
        #if rel_type == 'ref-behav
        if label1 == label2 == 'TC-reference':
            # print('coref', label1, label2)
            coref_mappings[id1] = id2
            coref_mappings[id2] = id1
        # elif label1 == label2 == 'Behavior-predicate':
        #     pass
        elif label1 == 'Behav-predicate' and label2 == 'TC-reference':
            # 
            behav_mappings[id2].append(id1)
        elif label1 == 'TC-reference' and label2 == 'Behav-predicate':
            behav_mappings[id1].append(id2)

        #elif label1 
            
    return coref_mappings, behav_mappings

# %%
## Get all labels:

### TEST COREF CHAIN CODE

# name = 'kim-full-data-update1'
name = 'AnnaIAABehav'
output = 'data'
path = f'../{output}/{name}.json'

dir_out = f'../results/{name}'
if not os.path.isdir(dir_out):
    os.mkdir(dir_out)

with open(path, encoding = 'utf-8') as infile:
    annotation_data = json.load(infile)

# %%
print(len(annotation_data))
# Out:
# 112

# %%
all_labels = set()

for n, data in enumerate(annotation_data):
    ls_id = data['id']
    annotations = data['annotations']
    offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict, text_level= get_labels(annotations) 
    for ann_id, anns in id_ann_dict.items():
        for ann in anns:
            if 'labels' in ann['value']:
                ann_labels = ann['value']['labels']
                all_labels.update(ann_labels)
            elif 'choices' in ann['value']:
                # print(ann['value'])
                source = ann['from_name']
                # print(source)
                ann_label = f"{ann['value']['choices'][0]}-{source}"
                # print(ann_label)
                all_labels.add(ann_label)

# %%
for l in all_labels:
    print(l)
# Out:
# Behav-predicate
# TC-reference

# %%
### TEST COREF CHAIN CODE

name = 'AnnaIAABehav'
output = 'data'
path = f'../{output}/{name}.json'

dir_out = f'../results/{name}'
if not os.path.isdir(dir_out):
    os.mkdir(dir_out)

with open(path, encoding = 'utf-8') as infile:
    annotation_data = json.load(infile)
    
for n, data in enumerate(annotation_data):
    ls_id = data['id']
    annotations = data['annotations']

    
    text = data['data']['text']
    text_id = text.split('\n', 1)[0].split(': ')[-1]
    part_id = text_id.split(' ')[0]
    path_out = f'{dir_out}/output-{text_id}_LS-id{ls_id}.csv'
    print('path out', path_out)
    
    if name.startswith('Anna'):
        print('Anna!')
        text = text.split(text_id+'\n')[1].lstrip('Text:')
    
    print(text[:100])
    
    offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict, span_relations_dict, text_level = get_labels(annotations)
    coref_mappings, behav_mappings = make_relation_mappings(id_relation_dict, id_name_dict)
    
    # if part_id in missing_texts:
    #     print(offset_label_dict)
    

    target_label = 'TC-reference'
    id_relations_ref = filter_relations(id_relation_dict, id_ann_dict, target_label)
    
    target_label1 = 'TC-reference'
    target_label2 =  "Behavior-predicate"
    id_relations_behav = filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2)

    span_dict_end = dict()
    # span_dict_start = dict()
    
    for (l1, l2), la in span_relations_dict.items():
        # span_dict_start[l1] = l2
        span_dict_end[l2] = l1
        
        
    coref_chains_ref, coref_dict_ref = get_chains(id_relations_ref)
    coref_chains_behav, coref_dict_behav = get_chains(id_relations_behav)
    
      
    
    doc = nlp(text)

    tok_id_ann_id_dict = defaultdict(set)
  
    
    for tok in doc:
        tok_start = tok.idx

        for i in range(tok.idx, tok.idx+len(tok)):
            if i in offset_label_dict:
                anns = offset_label_dict[i]
                for an in anns:
                    an_id = an['id']
                    tok_id_ann_id_dict[tok.i].add(an_id)

    token_data = []
    for tok in doc:
        
        tok_id = tok.i
        tok_dict = defaultdict(list)
        tok_dict['tok-id'] = tok_id
        tok_dict['token'] = tok.text
        tok_dict['ref-relations'] = []
        tok_dict['ref-behav-relations'] = []
        tok_dict['ref-id-relations'] = []
        tok_dict['coref-id-mapping'] = []
        tok_dict['behav-id-mapping'] = []
        tok_dict['ref-span'] = ''
                 
        # tok_dict['ref-behav-relations-new'] = ''

        #tok_dict['TC-COREF'] = ''
        for l in labels:
            tok_dict[l] = []
            if l in text_level:
                tok_dict[l] = True
            
        
        an_ids = tok_id_ann_id_dict[tok_id]
        # print(tok_id, an_ids)
        
        for an_id in an_ids:        
            anns = id_ann_dict[an_id]
    
            
     
            #rels = an_rel_dict[an_id]
            for an in anns:
                add_label = ''

                if 'from_name' in an:
                    add_label = an['from_name']
                    
                if 'labels' in an['value']:
                    label = an['value']['labels'][0]
                    if an_id in span_dict_end:
                        an_id_new = span_dict_end[an_id]
                        tok_dict[f'{label}'].append(an_id_new)
                    else:
                        tok_dict[f'{label}'].append(an_id)
                if 'choices' in an['value']:
                    for choice in an['value']['choices']:
                        if add_label != '':
                            if an_id in span_dict_end:
                                an_id_new = span_dict_end[an_id]
                                tok_dict[f'{choice}-{add_label}'].append(an_id_new)
                            else:
                                tok_dict[f'{choice}-{add_label}'].append(an_id)
                        else:
                            if an_id in span_dict_end:
                                an_id_new = span_dict_end[an_id]
                                tok_dict[choice].append(an_id_new)
                            else:
                                tok_dict[choice].append(an_id)


            if an_id in coref_dict_ref:
                
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                    tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id_new}')
                else:
                    tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                    tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id}')
            
            if an_id in coref_mappings:
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    coref_id = coref_mappings[an_id]
                    if coref_id in span_dict_end:
                        coref_id = span_dict_end[coref_id]
                
                    tok_dict['coref-id-mapping'].append(f'{an_id_new}-_-{coref_id}')
                else:
                    coref_id = coref_mappings[an_id]
                    if coref_id in span_dict_end:
                        coref_id = span_dict_end[coref_id]
                    tok_dict['coref-id-mapping'].append(f'{an_id}-_-{coref_id}')
                
            if an_id in behav_mappings:
                if an_id in span_dict_end:
                    an_id_new = span_dict_end[an_id]
                    for behav_id in behav_mappings[an_id_new]:
                        tok_dict['behav-id-mapping'].append(f'{an_id_new}-_-{behav_id}')
                else:
                    for behav_id in behav_mappings[an_id]:
                        tok_dict['behav-id-mapping'].append(f'{an_id}-_-{behav_id}')
          
  
        token_data.append(tok_dict)


    add_singletons(token_data)
    

    for tok_dict in token_data:

        for k, v in tok_dict.items():
            if type(v) == list:
                v = [str(i) for i in v]
                tok_dict[k] = ' '.join(v)
            else:
                tok_dict[k] = v
                
                
    if name.startswith('Anna'):
        new_tok_dicts = []
        #text = text.split(text_id+'\n')[1].lstrip('Text:')
        beg_text = text_id+'\nText:' 
        
        # tokenize_beginning
        doc = nlp(beg_text)
        
        all_keys = token_data[0].keys()
        for tok in doc:
            tok_id = tok.i
            tok_dict = dict()
            tok_dict['tok-id'] = tok_id
            tok_dict['token'] = tok.text
            
            for k in all_keys:
                if k not in ['tok-id', 'token']:
                    tok_dict[k] = ''
          
    
            new_tok_dicts.append(tok_dict)
        
        last_id = tok_id
        for d in token_data[1:]:
            d['tok-id'] = str(int(d['tok-id']) +last_id)
            new_tok_dicts.append(d)
        token_data = new_tok_dicts
                
                
    # apply span information - same id 
    df = pd.DataFrame(token_data)
    df.to_csv(path_out, index=False)
# Out:
# path out ../results/AnnaIAABehav/output-pinl909067dd848-1371258d9295 Klassiek jong txt_LS-id401.csv
# Anna!
#  Klassieke muziek zal lichtjes op de achtergrond aanstaan terwijl de mensen in de gezamelijke ruimte
# path out ../results/AnnaIAABehav/output-5edab253669692706f731c3d MAX jong txt.1_LS-id402.csv
# Anna!
#  Elke ochtend om half tien verzamelt een groep bewoners zich in de gezamenlijke huiskamer van het ap
# path out ../results/AnnaIAABehav/output-60076986348bb62629139c82 Mario oud txt_LS-id403.csv
# Anna!
#  In een bejaard appartementencomplex gaat Mario Kart spelen totaal niet zoals gepland. Eerst zitten
# path out ../results/AnnaIAABehav/output-5cda5b38480d7d00196cd9c0 Bridge oud txt_LS-id404.csv
# Anna!
#  Op woensdagmiddag wordt er een bridge middag georganiseerd in het appartementencomplex. Een aantal
# path out ../results/AnnaIAABehav/output-pinl55238677a141-13678361098b Bingo jong txt_LS-id405.csv
# Anna!
#  Het is een beetje spannend, want bingo associëren ze vooral met oudere mensen, maar de groep heeft
# path out ../results/AnnaIAABehav/output-5995b8a6bf8bcf0001ab6aed MAX oud txt.1_LS-id406.csv
# Anna!
#  Het programma MAX Geheugentrainer zal waarschijnlijk niet door veel mensen bekeken worden, maar de
# path out ../results/AnnaIAABehav/output-5e853ff6367050000b3520d1 Bridge oud txt_LS-id407.csv
# Anna!
#  Daar de gemiddelde leeftijd hoog ligt ga ik er vanuit dat veel van deze bewoners wel bekend zijn me
# path out ../results/AnnaIAABehav/output-61070b2f6fa9910dfa491e50 Klassiek jong txt.1_LS-id408.csv
# Anna!
#  In dit complex is er één persoon die houdt van klassieke muziek. Dit is ook de persoon die niet van
# path out ../results/AnnaIAABehav/output-pinl4745293429bb-13673344bce6 Mario jong txt.1_LS-id409.csv
# Anna!
#  Sommigen spelen met elkaar het Nintendospel Mario Kart. Het doet ze denken aan hun kindertijd. Het
# path out ../results/AnnaIAABehav/output-6310c693809cf6f3f1180f09 Huisfeest oud txt.1_LS-id410.csv
# Anna!
#  Een huisfeest geven met DJ in het appartementencomplex zal op 2 verschillende manieren kunnen gaan.
# path out ../results/AnnaIAABehav/output-6310c693809cf6f3f1180f09 Bridge oud txt.1_LS-id411.csv
# Anna!
#  Net zoals het vorige verhaal is het kaartspel bridge ook iets wat de doelgroep zou kunnen stereroty
# path out ../results/AnnaIAABehav/output-pinl5247036c38bf-13673346b27e Mario oud txt_LS-id412.csv
# Anna!
#  Op een dag gingen de bewoners van het appartementencomplex iets nieuws uitproberen, het spelen van
# path out ../results/AnnaIAABehav/output-pinl5247036c38bf-13673346b27e MAX oud txt_LS-id413.csv
# Anna!
#  Het favoriete programma kwam op tv, MAX geheugentrainer. Iedereen zat er klaar voor. De een deed no
# path out ../results/AnnaIAABehav/output-608956a7cb0f370f25ec12a0 Ex oud txt_LS-id414.csv
# Anna!
#  Er zal maar een héél klein deel zijn dat er echt voor gaat zitten. Het is natuurlijk totaal niet de
# path out ../results/AnnaIAABehav/output-pinl3829781bb3ae-13678365c257 Huisfeest jong txt_LS-id415.csv
# Anna!
#  ze doen veel moeite om het met veel vrienden te vieren. iedereen brengt wat mee en ze infomeren de
# path out ../results/AnnaIAABehav/output-pinl6623026d5e1-1371258a84f6 Klassiek jong txt_LS-id416.csv
# Anna!
#  Degenen die naar klassieke muziek zullen luisteren zullen dit in alle rust doen. Het is niet het so
# path out ../results/AnnaIAABehav/output-5e679c9105af6e041cc7ec36 MAX oud txt.1_LS-id417.csv
# Anna!
#  Annechien keek er elke dag naar. Ze spendeerde sowieso veel tijd voor de televisie, want wat moest
# path out ../results/AnnaIAABehav/output-pinl2744460641de-1367836f353e Bingo jong txt_LS-id418.csv
# Anna!
#  Jongeren tussen de 25 en 35 organiseren een bingoavond.  Meer iets voor ouderen zou je denken. Maar
# path out ../results/AnnaIAABehav/output-605741ea8c4c8aa92716892f Klassiek oud txt_LS-id419.csv
# Anna!
#  In de middag kunnen de bewoners een leuk muziekje opzetten terwijl ze gezellig gaan kletsen, lezen
# path out ../results/AnnaIAABehav/output-605741ea8c4c8aa92716892f Huisfeest oud txt_LS-id420.csv
# Anna!
#  De bewoners van dit appartementencomplex kunnen wel een feestje gebruiken. Het heeft de afgelopen t
# path out ../results/AnnaIAABehav/output-6110feef74be159b1e98aff8 MAX jong txt_LS-id421.csv
# Anna!
#  Op zondagochtend zit iemand in de gezamenlijke woonkamer ruimte TV te kijken en zapt toevallig lang
# path out ../results/AnnaIAABehav/output-6082996ef873543f5755401d MAX oud txt.1_LS-id422.csv
# Anna!
#  Ze zullen met zijn allen rondom de televisie klaar zitten met een hapje en een drankje. Ook doen ze
# path out ../results/AnnaIAABehav/output-6082996ef873543f5755401d Mario oud txt.1_LS-id423.csv
# Anna!
#  Dit zal een grote chaos zijn. Ze vinden het moeilijk om naar het beeldscherm dat snel beweegt te ki
# path out ../results/AnnaIAABehav/output-pinl549672429394-1367836a1f68 Mario oud txt_LS-id424.csv
# Anna!
#  In het appartementencomplex is de gemiddelde leeftijd vrij hoog, verboven de zeventig. Desalniettem
# path out ../results/AnnaIAABehav/output-pinl549672429394-1367836a1f68 Bingo oud txt_LS-id425.csv
# Anna!
#  De bingoavond wordt gehouden in de gezamenlijke ruimte. Een groepje bewoners organiseert de avond e
# path out ../results/AnnaIAABehav/output-631a045a66454f2681295678 Huisfeest oud txt.1_LS-id426.csv
# Anna!
#  De bewoners willen een huisfeest geven. Ze huren een DJ in om hun jonge jaren over te doen met echt
# path out ../results/AnnaIAABehav/output-631a045a66454f2681295678 Klassiek oud txt.1_LS-id427.csv
# Anna!
#  Vorige week hadden ze een huisfeest met DJ en gisteren keken ze gezamenlijk tv naar Ex on the beach
# path out ../results/AnnaIAABehav/output-pinl5374857a1459-1367334744ee Mario jong txt.1_LS-id428.csv
# Anna!
#  Naar mijn inschatting zijn deze bewoners totaal niet geinteresseerd in het spel en zullen zij dan o
# path out ../results/AnnaIAABehav/output-63617608e80e627568c61969 Klassiek oud txt.1_LS-id429.csv
# Anna!
#  De meeste bewoners van het appartementencomplex vinden klassieke muziek erg fijn, ze luisteren daar
# path out ../results/AnnaIAABehav/output-pinl5459946a1f53-1371258753a5 Mario oud txt_LS-id430.csv
# Anna!
#  er zijn een aantal spelers en een aantal toeschouwers somige alert andere voor het socialisen de ga
# path out ../results/AnnaIAABehav/output-6133afaf107354582557d6ca Bridge jong txt_LS-id431.csv
# Anna!
#  In het appartementencomplex is het weer tijd om bridge te spelen. De bewoners komen bijeen en Anne
# path out ../results/AnnaIAABehav/output-pinl5525703fd202-13684448b3f8 Klassiek jong txt_LS-id432.csv
# Anna!
#  in het appartementencomplex zit een ieder met zijn earbuds in te luisteren naar muziek. Tidal en Qo
# path out ../results/AnnaIAABehav/output-61269959239167c3e612bc52 Techno oud txt_LS-id433.csv
# Anna!
#  In de gezamenlijke ruimte van het appartementencomplex wordt soms nieuwe muziek afgespeeld om de se
# path out ../results/AnnaIAABehav/output-61269959239167c3e612bc52 Bingo oud txt_LS-id434.csv
# Anna!
#  Eens in de twee weken wordt er een bingoavond georganiseerd in het appartementencomplex. De seniore
# path out ../results/AnnaIAABehav/output-pinl55165479a8de-1366482ec325 Mario jong txt_LS-id435.csv
# Anna!
#  het spel mario kart zal zeer verschillend zijn omdat er personen zijn die het spelletje zien als ee
# path out ../results/AnnaIAABehav/output-60a18b77106fd129331fdc42 Mario oud txt.1_LS-id436.csv
# Anna!
#  Wanneer de kleinkinderen langs komen met de switch bij oma, zijn ze enorm enthousiast om met haar t
# path out ../results/AnnaIAABehav/output-pinl55219987f777-1367334bcc5a Ex oud txt_LS-id437.csv
# Anna!
#  Er is werkelijk niemand in het complex die kijkt naar het programma Ex on the beach. Dat zijn progr
# path out ../results/AnnaIAABehav/output-pinl52474476f68b-1367836d6384 Techno jong txt_LS-id438.csv
# Anna!
#  Twee van de mannen houden ook erg van het luisteren naar Technomuziek. De vrouwen hebben hier niets
# path out ../results/AnnaIAABehav/output-5e9ec5c73090e70009de98e7 Ex oud txt.1_LS-id439.csv
# Anna!
#  Omdat sommige bewoners hebben aangegeven het leuk te vinden om naar Ex on the Beach te kijken, word
# path out ../results/AnnaIAABehav/output-5e9ec5c73090e70009de98e7 Klassiek oud txt.1_LS-id440.csv
# Anna!
#  Er wordt een middag georganiseerd waarbij de liefhebbers van klassieke muziek rustig kunnen geniete
# path out ../results/AnnaIAABehav/output-63cfe685d8548330c904f7ac Techno jong txt.1_LS-id441.csv
# Anna!
#  Op vrijdagavond verandert de sfeer in ons appartementencomplex drastisch. Waar doordeweeks de rust
# path out ../results/AnnaIAABehav/output-pinl49897800b97a-1367827f91cf Bingo oud txt_LS-id442.csv
# Anna!
#  Elke twee weken organiseren wij een bingo-avond in ons appartementencomplex. De buren van het naast
# path out ../results/AnnaIAABehav/output-6315d7a20c6f7715242b7392 Techno jong txt.1_LS-id443.csv
# Anna!
#  Er is een spontaan feestje bezig in de woonkamer - een paar bewoners zaten in de woonkamer te luist
# path out ../results/AnnaIAABehav/output-60f844d45031151cf3278d51 Huisfeest oud txt_LS-id444.csv
# Anna!
#  Beneden is een nieuwe bewoner ingetrokken in het appartementencomplex. Alle ouderen zijn al de hele
# path out ../results/AnnaIAABehav/output-634dc1827697018f28061c87 Techno jong txt_LS-id445.csv
# Anna!
#  Megan schrikt wakker van een ritmisch gebonk. Wat zou dat zijn? Langzaam ontwaakt ze uit haar droom
# path out ../results/AnnaIAABehav/output-610785e5040bd3bff2030a1f MAX oud txt.1_LS-id446.csv
# Anna!
#  Het is donderdagavond, TV-avond. Vanavond kijken de bewoners MAX geheugentrainer. De bewoners gaan
# path out ../results/AnnaIAABehav/output-pinl3919259fe025-136560758566 Huisfeest oud txt_LS-id447.csv
# Anna!
#  De bewoners van het appartementencomplex zijn allemaal op leeftijd. De verjaardagen worden normaal
# path out ../results/AnnaIAABehav/output-pinl53651373f757-1367836974eb Techno oud txt.1_LS-id448.csv
# Anna!
#  we hebben ooit een DJ in huis gehad met technomuziek. Het was de kleinzoon van een van de bewoners.
# path out ../results/AnnaIAABehav/output-pinl5133198b4724-1371564c1265 Bingo jong txt.1_LS-id449.csv
# Anna!
#  Enkele bewoners zullen het initiatief nemen en de bingoavond organiseren. Zij zullen voor de spulle
# path out ../results/AnnaIAABehav/output-pinl5133198b4724-1371564c1265 MAX jong txt.1_LS-id450.csv
# Anna!
#  Van de 12 personen zal ongeveer de helft het programma willen zien; de andere helft toont weinig in
# path out ../results/AnnaIAABehav/output-pinl5133198b4724-1371564c1265 Mario jong txt.1_LS-id451.csv
# Anna!
#  Dat wordt een saaie avond waarop slechts enkelen fanatiek aan de slag gaan en de rest verveeld op h
# path out ../results/AnnaIAABehav/output-pinl4886495ae99f-13664821bbd1 Mario oud txt.1_LS-id452.csv
# Anna!
#  He, wat is dat nu voor poppetje? Is dat nu Mario? En hoe kan ik hem nu verplaatsen? Ik begrijp er n
# path out ../results/AnnaIAABehav/output-pinl439017705cc8-1367334e7123 Techno jong txt.1_LS-id453.csv
# Anna!
#  In de gangen van het appartamentencomplex zijn geregeld de klanen van techno te komen. Tijdens het
# path out ../results/AnnaIAABehav/output-pinl52955311e0de-1371564ca809 Klassiek jong txt.1_LS-id454.csv
# Anna!
#  Anneke, een jonge vrouw met een passie voor klassieke muziek, zet voorzichtig de grammofoonplaat va
# path out ../results/AnnaIAABehav/output-pinl1865650fbb61-1366482a6b55 Ex jong txt_LS-id455.csv
# Anna!
#  Door de groep wordt er hevig gediscussieerd over hetgeen er te zien is en of de persoon in kwestie
# path out ../results/AnnaIAABehav/output-60da0ddab8df563703646d29 Mario oud txt_LS-id456.csv
# Anna!
#  Vier bewoners zitten op de banken in de gemeenschappelijke woonkamer. Sindskort is Mario Kart aange
# path out ../results/AnnaIAABehav/output-60da0ddab8df563703646d29 Bingo oud txt_LS-id457.csv
# Anna!
#  Het is de wekelijkse bingo avond! Voor vele bewoners de favoriete avond. Na het avondeten zitten ze
# path out ../results/AnnaIAABehav/output-61013f9bee8a164bc16b75e1 Ex jong txt_LS-id458.csv
# Anna!
#  Niet iedereen kijk naar Ex on the beach zij mengen zich daarom ook niet in deze gesprekken. De gene
# path out ../results/AnnaIAABehav/output-pinl172753c93bd-13684441ccdc Mario jong txt_LS-id459.csv
# Anna!
#  de meiden wilden eigenlijk af van het samen mario kart spelen met de jongens, omdat zij heel fanati
# path out ../results/AnnaIAABehav/output-pinl53657556bccc-13661181d172 Techno jong txt_LS-id460.csv
# Anna!
#  Een zo op het oog jeugdige groep mensen zal wel van deze muziek houden. Het zal dan voor hen wel ee
# path out ../results/AnnaIAABehav/output-6315fd96abc9880cddac4b59 Mario oud txt_LS-id461.csv
# Anna!
#  in het ouderen appartementencomplex hebben ze wekelijks iets bedacht om de ouderen uit hun comfort
# path out ../results/AnnaIAABehav/output-6361608b3e692030546056bc Bingo jong txt_LS-id462.csv
# Anna!
#  Het houden van een bingoavond zal een moeilijke activiteit zijn voor het appartementencomplex. Een
# path out ../results/AnnaIAABehav/output-5bb202b18aba5700017f36f6 Ex jong txt.1_LS-id463.csv
# Anna!
#  Een keer per week komen de meeste bewoners samen om tv te kijken. Momenteel kijken ze met z'n allen
# path out ../results/AnnaIAABehav/output-pinl3135565d26b6-136783676952 Klassiek jong txt.1_LS-id464.csv
# Anna!
#  Men is serieus en er staan nette loungebanken, en er worden ook koptelefoons uitgedeeld zodat er go
# path out ../results/AnnaIAABehav/output-pinl5512462e8b56-1367836b6287 Klassiek jong txt.1_LS-id465.csv
# Anna!
#  Walter speelt viool en wil graag dat huisgenoten weten dat hij dit doet om meer begrip te krijgen v
# path out ../results/AnnaIAABehav/output-6325f78e2449742833a90778 Mario oud txt_LS-id466.csv
# Anna!
#  De kleinzoon van Henriëtte is op bezoek. "Wat heb je nu weer meegebracht, Pietertje?" vraagt ze aan
# path out ../results/AnnaIAABehav/output-6311a97bf8a1e247b984633e Bingo oud txt.1_LS-id467.csv
# Anna!
#  De zaal gaat een kwartier voor de start van de bingoavond open. Een paar bewoners van het complex s
# path out ../results/AnnaIAABehav/output-5efa01ad8e02ad091eef6594 Techno jong txt_LS-id468.csv
# Anna!
#  Er werd een huisfeestje georganiseerd in het appartementencomplex. Er werden vrienden en kennissen
# path out ../results/AnnaIAABehav/output-5efa01ad8e02ad091eef6594 MAX jong txt_LS-id469.csv
# Anna!
#  Tijdens een zappen op de tv was er helemaal niets interessants meer. Toen kwam MAX geheugentrainer
# path out ../results/AnnaIAABehav/output-pinl5526252ef54a-13673341c052 Techno oud txt_LS-id470.csv
# Anna!
#  Iedere week wordt er in het ouderen appartementencomplex ook samen geluisterd naar diverse muziek i
# path out ../results/AnnaIAABehav/output-5f4bc28f5a01ee78b64e2bfb Klassiek jong txt_LS-id471.csv
# Anna!
#  Ik denk dat ze doen aan muziek avonden. Deze avonden zijn jam sessies waarbij iedereen zijn eigen i
# path out ../results/AnnaIAABehav/output-631a0053107a6fba11a0b90a Bingo oud txt.1_LS-id472.csv
# Anna!
#  Het houden van een bingoavond in het appartementencomplex is de favoriete avond van de meeste bewon
# path out ../results/AnnaIAABehav/output-pinl55022096b86b-1366482946c0 MAX oud txt_LS-id473.csv
# Anna!
#  Max geheugentrainer is wat meer afgestemd op deze doelgroep en zal iets minder uitleg behoeven voor
# path out ../results/AnnaIAABehav/output-pinl17813625fb16-13734752ebd3 MAX jong txt_LS-id474.csv
# Anna!
#  Marieke , Karin en Theo zitten in de woonkamer Max geheugentrainer te kijken, hun favoriete program
# path out ../results/AnnaIAABehav/output-5b210161cfbf200001cfb0f9 Huisfeest jong txt.1_LS-id475.csv
# Anna!
#  Het is een rustige periode, examens zijn net voorbij en de mensen die in het apparementencomplex wo
# path out ../results/AnnaIAABehav/output-5b210161cfbf200001cfb0f9 Ex jong txt.1_LS-id476.csv
# Anna!
#  "Ex on the Beach? Serieus?" vraagt Sam als hij binnen komt in de gedeelde woonkamer. Drie meiden en
# path out ../results/AnnaIAABehav/output-60983635d36d430583b64fbc Techno jong txt_LS-id477.csv
# Anna!
#  "ARE YOU READY?!" klonk het vanuit de kamer van Peter. De andere bewoners wisten maar al te goed da
# path out ../results/AnnaIAABehav/output-60983635d36d430583b64fbc MAX jong txt_LS-id478.csv
# Anna!
#  Stella, Kevin en Patrick zaten in de woonkamer gezamenlijk naar het programma 'MAX Geheugentrainer'
# path out ../results/AnnaIAABehav/output-pinl5068062c6245-1366118ebc41 Bridge jong txt_LS-id479.csv
# Anna!
#  wij wonen met zijn 12en in een appartementen complex, en wonen gezellig met elkaar. het was een rus
# path out ../results/AnnaIAABehav/output-pinl5068062c6245-1366118ebc41 Klassiek jong txt_LS-id480.csv
# Anna!
#  1 van de bewoners opperde om een keer klassieke muziek te luisteren ipv het levenslied of rap of da
# path out ../results/AnnaIAABehav/output-pinl433668835c-13673347afec Bridge oud txt_LS-id481.csv
# Anna!
#  Eens per week komen de mensen van het appartementencomplex bijeen in de gemeenschappelijke ruimte d
# path out ../results/AnnaIAABehav/output-5c52b337a20b0b0001e5b7ad Klassiek oud txt_LS-id482.csv
# Anna!
#  Klassieke muziek vinden veel van de bewoners van het verzorgingstehuis erg mooi. Sommige bewoners l
# path out ../results/AnnaIAABehav/output-5c52b337a20b0b0001e5b7ad Ex oud txt_LS-id483.csv
# Anna!
#  In de late avonduren wordt de tv ook aangezet. Als Jack, de kleinzoon van Karin, op bezoek komt wor
# path out ../results/AnnaIAABehav/output-pinl533998125e3d-136648263d66 Bridge jong txt.1_LS-id484.csv
# Anna!
#  Voor bridge nodigen de bewoners hun ouders uit zodat ze de hele zondag kaart kunnen spelen. De span
# path out ../results/AnnaIAABehav/output-pinl5151474c06d2-1368444918c6 Bridge oud txt.1_LS-id485.csv
# Anna!
#  De wekelijkse bridgeavond. Iedereen kijkt er al naar uit. Spannend want welke koppels zullen er gev
# path out ../results/AnnaIAABehav/output-pinl5509337592e5-136783670a20 Ex jong txt_LS-id486.csv
# Anna!
#  Nu en dan komen enkele bewoners samen om samen te eten en daarna TV, Netflix of Videoland te kijken
# path out ../results/AnnaIAABehav/output-6310ad7d6fc3ea60975edd08 MAX jong txt_LS-id487.csv
# Anna!
#  Iemand van het appartementencomplex had bedacht om met een aantal bewoners afleveringen van MAX Geh
# path out ../results/AnnaIAABehav/output-63234a652006b650d19d13b3 Mario jong txt_LS-id488.csv
# Anna!
#  Het is woensdagavond in het grote huis aan de Waalstraat in Arnhem.
# Wat is begonnen als een studen
# path out ../results/AnnaIAABehav/output-601014bd40ea8525fe14c464 Klassiek jong txt_LS-id489.csv
# Anna!
#  Feline komt met het idee voor een schermloze avond: geen tv, telefoon of tablets in de gemeenschapp
# path out ../results/AnnaIAABehav/output-6138fc6df08e00e96682f9ee Bridge oud txt_LS-id490.csv
# Anna!
#  In de gemeenschappelijke woonkamer is het wekelijkse bridgetoernooi bezig. De ouderen zitten in gro
# path out ../results/AnnaIAABehav/output-pinl5446938d8081-136783680e2b Ex jong txt.1_LS-id491.csv
# Anna!
#  Het is weer dinsdagavond, tijd voor Ex on the beach! Drie meiden hebben dan een vaste afspraak, ze
# path out ../results/AnnaIAABehav/output-pinl39373533757f-1371258a5248 Ex oud txt.1_LS-id492.csv
# Anna!
#  In het appartementen complex werd regelmatig gezamenlijk TV gekeken. Vandaag werd er veel gezapt to
# path out ../results/AnnaIAABehav/output-pinl2798391f5e9f-13673345cf66 Bingo oud txt_LS-id493.csv
# Anna!
#  De wekelijkse bingo wordt steevast in de leeszaal gehouden .
# Diverse bewoners wilden de bingo graa
# path out ../results/AnnaIAABehav/output-pinl5365260afba5-1365856b4659 Ex jong txt_LS-id494.csv
# Anna!
#  In het appartementencomplex is er maar één bewoner die zo diep gezonken is dat zij soms naar het ba
# path out ../results/AnnaIAABehav/output-pinl50267135aa82-13661186a241 Techno oud txt.1_LS-id495.csv
# Anna!
#  Technomuziek
#
# De oudjes zitten bij elkaar in de koffiekamer de radio staat aan.
# Er is technomuziek
# path out ../results/AnnaIAABehav/output-pinl5467047f4604-13715641fcb3 Huisfeest oud txt.1_LS-id496.csv
# Anna!
#  Vrijdag avond 20.00 uur, DJ Bas begint zijn eerste plaat.
# Tragedy van de BeeGee's.
# Afgesproken was
# path out ../results/AnnaIAABehav/output-pinl178178697748-13684447fade Techno oud txt.1_LS-id497.csv
# Anna!
#  het luisteren van technomuziek in dit appartementencomplex zal zeker niet door alle bewoners gedaan
# path out ../results/AnnaIAABehav/output-5e0f5a17d62abe65e0a613ad Ex jong txt.1_LS-id498.csv
# Anna!
#  Het was een gewone avond in het appartementencomplex. Een groep vrienden had zich verzameld in een
# path out ../results/AnnaIAABehav/output-pinl432258f455-13673348da59 Huisfeest jong txt.1_LS-id499.csv
# Anna!
#  Het lijkt me erg lawaaïïg worden in het appartementencomplex als er een DJ zal komen die harde muzi
# path out ../results/AnnaIAABehav/output-pinl432258f455-13673348da59 Bridge jong txt.1_LS-id500.csv
# Anna!
#  Het doel van Bridge is in elk potje de meeste punten te verdienen. Klinkt eenvoudig maar is het ech
# path out ../results/AnnaIAABehav/output-pinl530924846aa4-1365856ed716 Huisfeest oud txt_LS-id501.csv
# Anna!
#  Anja zet de laatste hapjes op tafel voor het jaarlijkse zomerfeest.
# Alles is tot in de puntjes verz
# path out ../results/AnnaIAABehav/output-pinl5476578eb2e6-13656072110e MAX oud txt.1_LS-id502.csv
# Anna!
#  Alle bewoners zijn inmiddels in de gezamenlijke televisiekamer aangekomen en de televisie wordt op
# path out ../results/AnnaIAABehav/output-pinl645148657a3-1367836aead2 Huisfeest oud txt.1_LS-id503.csv
# Anna!
#  Het was een uitdaging om een feest te organiseren met een DJ voor een bewonersgroep waar de gemidde
# path out ../results/AnnaIAABehav/output-pinl645148657a3-1367836aead2 Ex oud txt.1_LS-id504.csv
# Anna!
#  Als activiteit stond voor deze zondag een gezamenlijke TV avond op het programma. Voor onze groep v
# path out ../results/AnnaIAABehav/output-5ef1dbc85d116903bed6b77b MAX oud txt.1_LS-id505.csv
# Anna!
#  De kamer is warm, denkt Anne, als ze binnenkomt. 'Kan er een raam open?' vraagt ze, maar niemand ze
# path out ../results/AnnaIAABehav/output-5fc936373927163c9889422d Bridge oud txt_LS-id506.csv
# Anna!
#  Gonnie, Hans, Bep en Bertus zitten met zijn vieren rond hun gebruikelijke tafel. Het is al even gel
# path out ../results/AnnaIAABehav/output-pinl242023641094-1367334b0e77 MAX oud txt.1_LS-id507.csv
# Anna!
#  Er zijn wat vriendengroepjes ontstaan die gezamenlijk naar het programma kijken. Ze vinden het best
# path out ../results/AnnaIAABehav/output-pinl4947260d03e8-1368444b2d6a Mario oud txt.1_LS-id508.csv
# Anna!
#  "Ik heb het!" roept Harold triomfantelijk uit, "Ik. Heb. Het!" Verbaasd kijken de andere bewoners h
# path out ../results/AnnaIAABehav/output-pinl174532f7f93-136648263810 Mario oud txt.1_LS-id509.csv
# Anna!
#  "Het Verloop"
# En dan is het een gezellige avond en dan opeens is er een oudere meneer uit de flat e
# path out ../results/AnnaIAABehav/output-pinl53850574cb6e-1367836dff01 MAX jong txt.1_LS-id510.csv
# Anna!
#  Een avondje tv met 'n allen, leuk met wat drank en knabbels. Op Tom na was iedereen er, we waren al
# path out ../results/AnnaIAABehav/output-pinl5503236a6d6b-1367827b5b1d Huisfeest oud txt.1_LS-id511.csv
# Anna!
#  Mies maakte zich zorgen over het huisfeest van morgen. Ze had immers totaal geen zin om Karel tegen
# path out ../results/AnnaIAABehav/output-pinl5526801ce01f-1366482f36ca Klassiek oud txt.1_LS-id512.csv
# Anna!
#  Tja, klassieke muziek. Daarover zijn de meningen al snel verdeeld. Er zijn fanaten die erbij zweren
