# %% [markdown]
# # Aggregate Data
#
# Dataset_CHECK, containing data from two articles (both at the intermediate level and also at the final one), so we cah double check if everything worked correctly.
#
# Articles to start with (Label-Studio identifier):
#
# * 15: output-RdC_01mar2023_Bo_LS-id15
# * 250: output-RdC_16feb2023_Bo_LS-id250

# %%
import csv
from collections import defaultdict
import pandas as pd
from collections import Counter

# %%
#RdC_16feb2023_Bo

# %%
ref_levels = ['high-TC-TG-levels', 
              'middle-TC-TG-levels', 
              'individual-TC-TG-levels']

lcm_level = ['OBS-BH-LCM-behavior', 
             "CAT-BH-LCM-behavior", 
             "MENT-ST-LCM-behavior",
             "TRAIT-LCM-behavior", ]

valence_beh = ['Positive-LCM-behavior',
               'Neutral-LCM-behavior', 
               'Negative-LCM-behavior']

valence_ref = ['Positive-TG-levels', 
               'Neutral-TG-levels', 
               'Negative-TG-levels',]


group_beh = ['Ingroup-LCM-behavior', 
             "Outgroup-LCM-behavior"]
group_ref = ['Outgroup-TG-levels', 
             'Ingroup-TG-levels']


roles = [
    'Perpetrator-TG-levels',
    "Victim-TG-levels",
    "Prosocial behavior-TG-levels",
    "Other-TG-levels",
    "Istitutional actor-TG-levels"]


ref_dem = ['Age-TG-levels', 
       'Residency-TG-levels', 
       'Gender-TG-levels', 
       'Origin - TC-TG-levels',
       'Education-TG-levels', 
       'Family role-TG-levels',
       'Profession-TG-levels', 
       'Other category-TG-levels'
      ]
des_dem = ['Age-LCM-behavior', 
       'Residency-LCM-behavior', 
       'Gender-LCM-behavior', 
       'Origin - TC-LCM-behavior',
       'Education-LCM-behavior', 
       'Family role-LCM-behavior',
       'Profession-LCM-behavior', 
       'Origin - TC-LCM-behavior',
       'Other category-LCM-behavior'
      ]

# %%
# data[0]

# %%
def get_cat_info(target_category_dicts, target_labels, label_id):
    
    d = target_category_dicts[0]
    
    labels = []
    for l in target_labels:
        val = d[l].split(' ')
        for v in val:
            if v == label_id:
                labels.append(l)
    return ' '.join(labels)




def load_data(test_path):
    
    try:
        with open(test_path) as infile:
            data_original = list(csv.DictReader(infile, delimiter = ','))
    except FileNotFoundError:
        print('file not found')
        data_original = []
    return data_original
    
    

def process_file(test_path, topic, news_id, valence_ref, ref_levels, 
                 roles, group_ref, ref_dem, lcm_level, valence_beh, group_beh, des_dem):

    data_out = []
    
    data_original = load_data(test_path)
    
    label_token_dicts = defaultdict(list)
    label_coref_dict = dict()
    label_behav_mapping = defaultdict(set)
        

    for d in data_original:
        if d['Target-category-reference'] != '':
            for label_id in d['Target-category-reference'].split(' '):
                label_token_dicts[label_id].append(d)
        if d['Behavior-predicate'] != '':
            for label_id in d['Behavior-predicate'].split(' '):
                if 'IkD2_fEYyH' == label_id:
                    print('Found problematic label')
                label_token_dicts[label_id].append(d)


        if d['ref-id-relations'] != '':
            coref_ids = d['ref-id-relations'].split(' ')
            for coref_id in coref_ids:
                coref_list = coref_id.split('-_-')
                if len(coref_list) == 2:
                    coref_chain, label_id = coref_list
                    label_coref_dict[label_id] = coref_chain
                else:
                    print('problem')
                    print(coref_id)
                    print(coref_list)
            #     print(coref_chain, label_id)
            # print()

        # get mappings ref behav
        if d['behav-id-mapping'] != '':
            for ref_behav_mapping in d['behav-id-mapping'].split(' '):
                label_id1, label_id2 = ref_behav_mapping.split('-_-')
                label_behav_mapping[label_id1].add(label_id2)
                label_behav_mapping[label_id2].add(label_id1)
        
        
    for label, token_dicts in label_token_dicts.items():
        tokens = ' '.join([d['token'] for d in token_dicts])
        if label in label_coref_dict:
            # print(token_dicts[0].keys())
            

            if label in label_behav_mapping:
                # print('Description found')
                behav_labels = label_behav_mapping[label]
                for behav_label in behav_labels:
                    
                    behav_token_dicts = label_token_dicts[behav_label]
                    if len(behav_token_dicts) == 0:
                        print('Problem')
                        print(behav_label)
                        print(behav_token_dicts)
                    tokens_behav = ' '.join([d['token'] for d in behav_token_dicts])
                    
                    d_out = dict()
                    coref = label_coref_dict[label]
                    # d_out['Reference'] = tokens
                    # d_out['coref'] = coref

                    d_out['Newspaper_id'] = news_id
                    d_out['Lstudio_id'] = ls_id
                    d_out['Article_id'] = article_id
                    d_out['Topic'] = topic

                    d_out['Referent_id'] = coref
                    d_out['Reference_text'] = tokens
                    #get_cat_info(target_category_dicts, target_labels, label_id)
                    d_out['Reference_level'] = get_cat_info(token_dicts, ref_levels, label)
                    d_out['Reference_valence'] =  get_cat_info(token_dicts, valence_ref, label)
                    d_out["Target's_role"] = get_cat_info(token_dicts, roles, label )
                    d_out['Group_membership'] = get_cat_info(token_dicts, group_ref, label)
                    d_out['Reference_demographics'] = get_cat_info(token_dicts, ref_dem, label)
                    # print('Description', tokens_behav)
                    d_out['Description_text'] = tokens_behav
                    d_out['Description_level'] = get_cat_info(behav_token_dicts, lcm_level, behav_label)
                    d_out['Description_valence'] = get_cat_info(behav_token_dicts, valence_beh, behav_label)
                    d_out['Description_group'] = get_cat_info(behav_token_dicts, group_beh, behav_label)
                    d_out['Description_demographics'] = get_cat_info(behav_token_dicts, des_dem, behav_label)
                    data_out.append(d_out)
            elif label not in label_behav_mapping:
                d_out = dict()
                coref = label_coref_dict[label]
                # d_out['Reference'] = tokens
                # d_out['coref'] = coref

                d_out['Newspaper_id'] = news_id
                d_out['Lstudio_id'] = ls_id
                d_out['Article_id'] = article_id
                d_out['Topic'] = topic

                d_out['Referent_id'] = coref
                d_out['Reference_text'] = tokens
                d_out['Reference_level'] = get_cat_info(token_dicts, ref_levels, label)
                d_out['Reference_valence'] =  get_cat_info(token_dicts, valence_ref, label)
                d_out["Target's_role"] = get_cat_info(token_dicts, roles, label)
                d_out['Group_membership'] = get_cat_info(token_dicts, group_ref, label)
                d_out['Reference_demographics'] = get_cat_info(token_dicts, ref_dem, label)
                d_out['Description_text'] = ''
                d_out['Description_level'] = ''
                d_out['Description_valence'] = ''
                d_out['Description_group'] = ''
                d_out['Description_demographics'] = '' 
                data_out.append(d_out)
                
                
               

        elif label not in label_coref_dict and label not in label_behav_mapping:
            print('found label not in coref dict', label)
            # print('Description only')
            d_out = dict()
            d_out['Newspaper_id'] = news_id
            d_out['Lstudio_id'] = ls_id
            d_out['Article_id'] = article_id
            d_out['Topic'] = topic

            d_out['Referent_id'] = ''
            d_out['Reference_text'] = ''
            d_out['Reference_level'] = ''
            d_out['Reference_valence'] = ''
            d_out["Target's_role"] = ''
            d_out['Group_membership'] = ''
            d_out['Reference_demographics'] = ''

            d_out['Description_text'] = tokens
            d_out['Description_level'] = get_cat_info(token_dicts, lcm_level, label)
            d_out['Description_valence'] = get_cat_info(token_dicts, valence_beh, label)
            d_out['Description_group'] = get_cat_info(token_dicts, group_beh, label)
            d_out['Description_demographics'] = get_cat_info(token_dicts, des_dem, label)

            data_out.append(d_out)
#                 d_out = dict()
#                 coref = label_coref_dict[label]
#                 # d_out['Reference'] = tokens
#                 # d_out['coref'] = coref

#                 d_out['Newspaper_id'] = news_id
#                 d_out['Lstudio_id'] = ls_id
#                 d_out['Article_id'] = article_id
#                 d_out['Topic'] = topic

#                 d_out['Referent_id'] = coref
#                 d_out['Reference_text'] = tokens
#                 d_out['Reference_level'] = get_cat_info(token_dicts, ref_levels, label)
#                 d_out['Reference_valence'] =  get_cat_info(token_dicts, valence_ref, label)
#                 d_out["Target's_role"] = get_cat_info(token_dicts, roles, label)
#                 d_out['Group_membership'] = get_cat_info(token_dicts, group_ref, label)
#                 d_out['Reference_demographics'] = get_cat_info(token_dicts, ref_dem, label)
#                 d_out['Description_text'] = ''
#                 d_out['Description_level'] = ''
#                 d_out['Description_valence'] = ''
#                 d_out['Description_group'] = ''
#                 d_out['Description_demographics'] = '' 
#                 data_out.append(d_out)
            # print()
        


    return data_out

# %%
article_id = 'Co_12feb2023_P.21' #RdC_16feb2023_Bo
ls_id = 'id137'
text_id = f'{article_id}_LS-{ls_id}'
test_path = f'Chiara_full_dataset/chiara/output-{text_id}.csv'
#test_path = f'Chiara_full_dataset/chiara/test-morph.csv'
topic = 'test'
news_id = 'test'

data_out = []

data_original = load_data(test_path)


data_out = process_file(test_path, topic, news_id, valence_ref, ref_levels, 
                 roles, group_ref, ref_dem, lcm_level, valence_beh, group_beh, des_dem)

df = pd.DataFrame(data_out)

df[:30]
# Out:
# found label not in coref dict SjbFv3v8v8
#    Newspaper_id Lstudio_id         Article_id Topic Referent_id  \
# 0          test      id137  Co_12feb2023_P.21  test           5
# 1          test      id137  Co_12feb2023_P.21  test           5
# 2          test      id137  Co_12feb2023_P.21  test           5
# 3          test      id137  Co_12feb2023_P.21  test           5
# 4          test      id137  Co_12feb2023_P.21  test           1
# 5          test      id137  Co_12feb2023_P.21  test           1
# 6          test      id137  Co_12feb2023_P.21  test           1
# 7          test      id137  Co_12feb2023_P.21  test           1
# 8          test      id137  Co_12feb2023_P.21  test           3
# 9          test      id137  Co_12feb2023_P.21  test           2
# 10         test      id137  Co_12feb2023_P.21  test           0
# 11         test      id137  Co_12feb2023_P.21  test           0
# 12         test      id137  Co_12feb2023_P.21  test           1
# 13         test      id137  Co_12feb2023_P.21  test           6
# 14         test      id137  Co_12feb2023_P.21  test           7
# 15         test      id137  Co_12feb2023_P.21  test           7
# 16         test      id137  Co_12feb2023_P.21  test           7
# 17         test      id137  Co_12feb2023_P.21  test           2
# 18         test      id137  Co_12feb2023_P.21  test           2
# 19         test      id137  Co_12feb2023_P.21  test           2
# 20         test      id137  Co_12feb2023_P.21  test           2
# 21         test      id137  Co_12feb2023_P.21  test           8
# 22         test      id137  Co_12feb2023_P.21  test
# 23         test      id137  Co_12feb2023_P.21  test           3
# 24         test      id137  Co_12feb2023_P.21  test           1
# 25         test      id137  Co_12feb2023_P.21  test           1
# 26         test      id137  Co_12feb2023_P.21  test           1
# 27         test      id137  Co_12feb2023_P.21  test           1
# 28         test      id137  Co_12feb2023_P.21  test           1
# 29         test      id137  Co_12feb2023_P.21  test           1
#
#                                        Reference_text  \
# 0                                       medico legale
# 1                                       medico legale
# 2                                       medico legale
# 3                                       medico legale
# 4   sottufficiale dei carabinieri cinquantenne , i...
# 5   sottufficiale dei carabinieri cinquantenne , i...
# 6   sottufficiale dei carabinieri cinquantenne , i...
# 7   sottufficiale dei carabinieri cinquantenne , i...
# 8   immigrato che , si presume , spacciava nei bos...
# 9   Cupola nordafricana della droga e delle sangui...
# 10  propria catena di comando , l’ autorità giudiz...
# 11                                            i quali
# 12                                diretto interessato
# 13                                   duemila abitanti
# 14                 i vertici della Compagnia di Luino
# 15                 i vertici della Compagnia di Luino
# 16                 i vertici della Compagnia di Luino
# 17  spacciatori , muniti anche di kalashnikov , ch...
# 18  spacciatori , muniti anche di kalashnikov , ch...
# 19  spacciatori , muniti anche di kalashnikov , ch...
# 20  spacciatori , muniti anche di kalashnikov , ch...
# 21  tossicodipendenti , sovente giovani , non di r...
# 22
# 23  La persona uccisa , secondo la versione del so...
# 24  sottufficiale — del quale i colleghi negano og...
# 25  sottufficiale — del quale i colleghi negano og...
# 26  sottufficiale — del quale i colleghi negano og...
# 27  sottufficiale — del quale i colleghi negano og...
# 28  sottufficiale — del quale i colleghi negano og...
# 29  sottufficiale — del quale i colleghi negano og...
#
#             Reference_level   Reference_valence                 Target's_role  \
# 0   individual-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 1   individual-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 2   individual-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 3   individual-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 4   individual-TC-TG-levels   Neutral-TG-levels         Perpetrator-TG-levels
# 5   individual-TC-TG-levels   Neutral-TG-levels         Perpetrator-TG-levels
# 6   individual-TC-TG-levels   Neutral-TG-levels         Perpetrator-TG-levels
# 7   individual-TC-TG-levels   Neutral-TG-levels         Perpetrator-TG-levels
# 8   individual-TC-TG-levels   Neutral-TG-levels              Victim-TG-levels
# 9       middle-TC-TG-levels  Negative-TG-levels         Perpetrator-TG-levels
# 10      middle-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 11      middle-TC-TG-levels   Neutral-TG-levels
# 12  individual-TC-TG-levels   Neutral-TG-levels
# 13      middle-TC-TG-levels   Neutral-TG-levels               Other-TG-levels
# 14      middle-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 15      middle-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 16      middle-TC-TG-levels   Neutral-TG-levels  Istitutional actor-TG-levels
# 17      middle-TC-TG-levels  Negative-TG-levels
# 18      middle-TC-TG-levels  Negative-TG-levels
# 19      middle-TC-TG-levels  Negative-TG-levels
# 20      middle-TC-TG-levels  Negative-TG-levels
# 21      middle-TC-TG-levels   Neutral-TG-levels              Victim-TG-levels
# 22
# 23  individual-TC-TG-levels   Neutral-TG-levels
# 24  individual-TC-TG-levels   Neutral-TG-levels
# 25  individual-TC-TG-levels   Neutral-TG-levels
# 26  individual-TC-TG-levels   Neutral-TG-levels
# 27  individual-TC-TG-levels   Neutral-TG-levels
# 28  individual-TC-TG-levels   Neutral-TG-levels
# 29  individual-TC-TG-levels   Neutral-TG-levels
#
#       Group_membership                             Reference_demographics  \
# 0    Ingroup-TG-levels                               Profession-TG-levels
# 1    Ingroup-TG-levels                               Profession-TG-levels
# 2    Ingroup-TG-levels                               Profession-TG-levels
# 3    Ingroup-TG-levels                               Profession-TG-levels
# 4    Ingroup-TG-levels                 Age-TG-levels Profession-TG-levels
# 5    Ingroup-TG-levels                 Age-TG-levels Profession-TG-levels
# 6    Ingroup-TG-levels                 Age-TG-levels Profession-TG-levels
# 7    Ingroup-TG-levels                 Age-TG-levels Profession-TG-levels
# 8   Outgroup-TG-levels
# 9                                                   Origin - TC-TG-levels
# 10   Ingroup-TG-levels                               Profession-TG-levels
# 11
# 12
# 13   Ingroup-TG-levels                                Residency-TG-levels
# 14   Ingroup-TG-levels                               Profession-TG-levels
# 15   Ingroup-TG-levels                               Profession-TG-levels
# 16   Ingroup-TG-levels                               Profession-TG-levels
# 17                                                   Profession-TG-levels
# 18                                                   Profession-TG-levels
# 19                                                   Profession-TG-levels
# 20                                                   Profession-TG-levels
# 21   Ingroup-TG-levels  Age-TG-levels Origin - TC-TG-levels Family rol...
# 22
# 23
# 24                                                   Profession-TG-levels
# 25                                                   Profession-TG-levels
# 26                                                   Profession-TG-levels
# 27                                                   Profession-TG-levels
# 28                                                   Profession-TG-levels
# 29                                                   Profession-TG-levels
#
#    Description_text     Description_level    Description_valence  \
# 0          appurare   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 1          autopsia   OBS-BH-LCM-behavior   Neutral-LCM-behavior
# 2          autopsia   OBS-BH-LCM-behavior   Neutral-LCM-behavior
# 3        risolutiva   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 4            azione   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 5          omicidio   CAT-BH-LCM-behavior  Negative-LCM-behavior
# 6         informato   CAT-BH-LCM-behavior  Negative-LCM-behavior
# 7         decisioni  MENT-ST-LCM-behavior  Negative-LCM-behavior
# 8         spacciava   OBS-BH-LCM-behavior  Negative-LCM-behavior
# 9             faide   CAT-BH-LCM-behavior  Negative-LCM-behavior
# 10
# 11          appreso  MENT-ST-LCM-behavior   Neutral-LCM-behavior
# 12
# 13
# 14        ricordati  MENT-ST-LCM-behavior   Neutral-LCM-behavior
# 15        impegnati   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 16      posizionato  MENT-ST-LCM-behavior   Neutral-LCM-behavior
# 17        controllo   CAT-BH-LCM-behavior  Negative-LCM-behavior
# 18       contendono   CAT-BH-LCM-behavior  Negative-LCM-behavior
# 19      asfissiante   CAT-BH-LCM-behavior  Negative-LCM-behavior
# 20           muniti   OBS-BH-LCM-behavior  Negative-LCM-behavior
# 21
# 22         affamati  MENT-ST-LCM-behavior   Neutral-LCM-behavior
# 23
# 24      aspirazione  MENT-ST-LCM-behavior   Neutral-LCM-behavior
# 25  farsi giustizia   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 26             solo   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 27        l’ onesta    TRAIT-LCM-behavior  Positive-LCM-behavior
# 28         carriera   CAT-BH-LCM-behavior   Neutral-LCM-behavior
# 29           deriva   CAT-BH-LCM-behavior   Neutral-LCM-behavior
#
#         Description_group Description_demographics
# 0    Ingroup-LCM-behavior
# 1    Ingroup-LCM-behavior
# 2    Ingroup-LCM-behavior
# 3    Ingroup-LCM-behavior
# 4    Ingroup-LCM-behavior
# 5    Ingroup-LCM-behavior
# 6    Ingroup-LCM-behavior
# 7    Ingroup-LCM-behavior
# 8   Outgroup-LCM-behavior
# 9   Outgroup-LCM-behavior
# 10
# 11   Ingroup-LCM-behavior
# 12
# 13
# 14   Ingroup-LCM-behavior
# 15   Ingroup-LCM-behavior
# 16   Ingroup-LCM-behavior
# 17  Outgroup-LCM-behavior
# 18  Outgroup-LCM-behavior
# 19  Outgroup-LCM-behavior
# 20  Outgroup-LCM-behavior
# 21
# 22
# 23
# 24   Ingroup-LCM-behavior
# 25   Ingroup-LCM-behavior
# 26   Ingroup-LCM-behavior
# 27   Ingroup-LCM-behavior
# 28   Ingroup-LCM-behavior
# 29   Ingroup-LCM-behavior

# %%
with open('Chiara_full_dataset/Dataset_Pia.csv') as infile:
    data = list(csv.DictReader(infile, delimiter=';'))

# %%
data[0]
# Out:
# {'\ufeffArticle_id': 'RdC_18gen2023_Fc',
#  'Lstudio_id': '74,00',
#  'News_id': 'Il Resto del Carlino',
#  'Topic': 'Current_news'}

# %%
full_id_data = []
for d in data:
    ls_id = d['Lstudio_id'].split(',')[0]
    article_id = d['\ufeffArticle_id'] 
    news_id = d['News_id']
    topic = d['Topic']
    text_id = f'{article_id}_LS-id{ls_id}'
    test_path = f'Chiara_full_dataset/chiara/output-{text_id}.csv'
    print(test_path)
    id_data = process_file(test_path, topic, news_id, valence_ref, ref_levels, roles, group_ref, 
                       ref_dem, lcm_level, valence_beh, group_beh, des_dem)
    full_id_data.extend(id_data)
# Out:
# Chiara_full_dataset/chiara/output-RdC_18gen2023_Fc_LS-id74.csv
# Chiara_full_dataset/chiara/output-RdC_03feb2023_Fc_LS-id19.csv
# Chiara_full_dataset/chiara/output-RdC_17feb2023_Fc_LS-id65.csv
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Fc_LS-id78.csv
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Fc_b_LS-id79.csv
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Fc_c_LS-id80.csv
# Chiara_full_dataset/chiara/output-RdC_24gen2023_Fc_LS-id97.csv
# Chiara_full_dataset/chiara/output-RdC_14feb2023_Fc_LS-id46.csv
# Chiara_full_dataset/chiara/output-RdC_07feb2023_Im_LS-id21.csv
# found label not in coref dict IhiZS96693
# Chiara_full_dataset/chiara/output-RdC_10feb2023_Im_LS-id23.csv
# Chiara_full_dataset/chiara/output-RdC_17feb2023_Im_b_LS-id66.csv
# found label not in coref dict brRVMOhK2Y
# found label not in coref dict TqHgnaGwMq
# Chiara_full_dataset/chiara/output-RdC_17feb2023_Im_c_LS-id67.csv
# Chiara_full_dataset/chiara/output-RdC_25feb2023_Im_LS-id99.csv
# found label not in coref dict 6y8qDQP8H4
# Chiara_full_dataset/chiara/output-RdC_02feb2023_Pr_LS-id17.csv
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Ri_LS-id30.csv
# found label not in coref dict zd-V3wsT86
# found label not in coref dict XczJmbUknF
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Ri_b_LS-id31.csv
# Chiara_full_dataset/chiara/output-RdC_11gen2023_Ri_LS-id35.csv
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Ri_LS-id57.csv
# Chiara_full_dataset/chiara/output-RdC_17gen2023_Ri_b_LS-id251.csv
# Chiara_full_dataset/chiara/output-RdC_01mar2023_Bo_LS-id15.csv
# Chiara_full_dataset/chiara/output-RdC_07feb2023_Bo_LS-id248.csv
# Chiara_full_dataset/chiara/output-RdC_09feb2023_Bo_LS-id22.csv
# found label not in coref dict L7W3L1Rlp7
# found label not in coref dict C2kpSURqNg
# Chiara_full_dataset/chiara/output-RdC_14feb2023_Bo_LS-id45.csv
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Bo_LS-id250.csv
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Bo_b_LS-id60.csv
# Chiara_full_dataset/chiara/output-RdC_18feb2023_Bo_b_LS-id73.csv
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Bo_LS-id75.csv
# found label not in coref dict NUNoPKq1-1
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Bo_e_LS-id76.csv
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Bo_f_LS-id77.csv
# Chiara_full_dataset/chiara/output-RdC_20feb2023_Bo_b_LS-id87.csv
# found label not in coref dict wkhpgODY2e
# Chiara_full_dataset/chiara/output-RdC_22feb2023_Bo_b_LS-id90.csv
# Chiara_full_dataset/chiara/output-RdC_23feb2023_Bo_LS-id93.csv
# found label not in coref dict 5UVYF5AuCw
# found label not in coref dict byfI0oakSj
# found label not in coref dict JnlTIKSQjb
# Chiara_full_dataset/chiara/output-RdC_23feb2023_Bo_b_LS-id94.csv
# Chiara_full_dataset/chiara/output-RdC_23feb2023_Bo_c_LS-id95.csv
# Chiara_full_dataset/chiara/output-RdC_26feb2023_Bo_LS-id103.csv
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Fe_LS-id24.csv
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Fe_b_LS-id25.csv
# Chiara_full_dataset/chiara/output-RdC_11gen2023_Fe_c_LS-id32.csv
# found label not in coref dict nrIKzNCUgg
# Chiara_full_dataset/chiara/output-RdC_11gen2023_Fe_d_LS-id33.csv
# found label not in coref dict L3meZ1dg11
# found label not in coref dict PtBTgVMVk4
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Fe_LS-id52.csv
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Fe_c_LS-id54.csv
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Fe_LS-id104.csv
# found label not in coref dict WDHkijktXS
# found label not in coref dict QThnBFvE3b
# Chiara_full_dataset/chiara/output-RdC_01feb2023_Fe_LS-id13.csv
# Chiara_full_dataset/chiara/output-RdC_02feb2023_Fe_LS-id16.csv
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Ra_b_LS-id106.csv
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Ra_c_LS-id107.csv
# found label not in coref dict pn_HZvulJ6
# found label not in coref dict Rv1Qoo5FfA
# found label not in coref dict uAWUCHcDSx
# Chiara_full_dataset/chiara/output-RdC_28gen2023_Ra_LS-id109.csv
# Chiara_full_dataset/chiara/output-RdC_02feb2023_Ra_LS-id18.csv
# Chiara_full_dataset/chiara/output-RdC_12gen2023_Mo_LS-id36.csv
# Chiara_full_dataset/chiara/output-RdC_13gen2023_Mo_b_LS-id40.csv
# Chiara_full_dataset/chiara/output-RdC_13gen2023_Mo_c_LS-id41.csv
# Chiara_full_dataset/chiara/output-RdC_14gen2023_Mo_LS-id47.csv
# found label not in coref dict PpE6q1lqW3
# Chiara_full_dataset/chiara/output-RdC_14gen2023_Mo_b_LS-id48.csv
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Mo_LS-id55.csv
# Chiara_full_dataset/chiara/output-RdC_17gen2023_Mo_LS-id70.csv
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Mo_LS-id105.csv
# Chiara_full_dataset/chiara/output-RdC_28gen2023_Mo_LS-id252.csv
# Chiara_full_dataset/chiara/output-RdC_31gen2023_Mo_b_LS-id110.csv
# Chiara_full_dataset/chiara/output-RdC_01feb2023_Mo_LS-id14.csv
# Chiara_full_dataset/chiara/output-RdC_13feb2023_Mo_LS-id37.csv
# Chiara_full_dataset/chiara/output-RdC_13feb2023_Mo_d_LS-id39.csv
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Mo_LS-id62.csv
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Mo_b_LS-id63.csv
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Mo_c_LS-id82.csv
# Chiara_full_dataset/chiara/output-RdC_10gen2023_R.em_LS-id27.csv
# Chiara_full_dataset/chiara/output-RdC_10gen2023_R.em_d_LS-id28.csv
# Chiara_full_dataset/chiara/output-RdC_13gen2023_R.em_LS-id42.csv
# Chiara_full_dataset/chiara/output-RdC_13gen2023_R.em_b_LS-id43.csv
# found label not in coref dict yfXVGyzyrp
# found label not in coref dict gWWS1GsucB
# Chiara_full_dataset/chiara/output-RdC_13gen2023_R.em_e_LS-id44.csv
# Chiara_full_dataset/chiara/output-RdC_14gen2023_R.em_LS-id249.csv
# Chiara_full_dataset/chiara/output-RdC_16gen2023_R.em_b_LS-id64.csv
# Chiara_full_dataset/chiara/output-RdC_19gen2023_R.em_b_LS-id84.csv
# Chiara_full_dataset/chiara/output-RdC_20gen2023_R.em_LS-id88.csv
# Chiara_full_dataset/chiara/output-RdC_22gen2023_R.em_LS-id91.csv
# found label not in coref dict DmdCc4WnvZ
# found label not in coref dict QPybAAXyq_
# found label not in coref dict sNNI9No70s
# found label not in coref dict G-JxcQzaAA
# Chiara_full_dataset/chiara/output-RdC_22gen2023_R.em_b_LS-id92.csv
# found label not in coref dict 5red5mGFMD
# found label not in coref dict 4Cott5qH4Q
# Chiara_full_dataset/chiara/output-RdC_24gen2023_R.em_LS-id98.csv
# found label not in coref dict 5Tz4jlOibJ
# found label not in coref dict IUHYZdwlFq
# Chiara_full_dataset/chiara/output-RdC_25gen2023_R.em_b_LS-id101.csv
# found label not in coref dict TA-_4VcN8L
# Chiara_full_dataset/chiara/output-RdC_25gen2023_R.em_c_LS-id102.csv
# found label not in coref dict OUe6GQdDlO
# Chiara_full_dataset/chiara/output-Co_10gen2023_P.3_LS-id132.csv
# Chiara_full_dataset/chiara/output-Co_10gen2023_P.6_LS-id133.csv
# found label not in coref dict ZAsgq4lUmU
# Chiara_full_dataset/chiara/output-Co_11gen2023_P.4_LS-id136.csv
# Chiara_full_dataset/chiara/output-Co_11gen2023_P.11_LS-id134.csv
# Chiara_full_dataset/chiara/output-Co_12gen2023_P.17_LS-id139.csv
# Chiara_full_dataset/chiara/output-Co_14gen2023_P.8_LS-id140.csv
# Chiara_full_dataset/chiara/output-Co_14gen2023_P.9_LS-id141.csv
# Chiara_full_dataset/chiara/output-Co_18gen2023_P.15_LS-id145.csv
# Chiara_full_dataset/chiara/output-Co_23gen2023_P.16_LS-id151.csv
# Chiara_full_dataset/chiara/output-Co_24gen2023_P.15_LS-id153.csv
# Chiara_full_dataset/chiara/output-Co_24gen2023_P.19_LS-id154.csv
# found label not in coref dict qA5yJcMbZ7
# Chiara_full_dataset/chiara/output-Co_25gen2023_P.11_LS-id156.csv
# Chiara_full_dataset/chiara/output-Co_25gen2023_P.18_LS-id157.csv
# Chiara_full_dataset/chiara/output-Co_25gen2023_P.27_LS-id158.csv
# Chiara_full_dataset/chiara/output-Co_26gen2023_P.14_LS-id161.csv
# Chiara_full_dataset/chiara/output-Co_26gen2023_P.14_b_LS-id162.csv
# Chiara_full_dataset/chiara/output-Co_27gen2023_P.10_LS-id169.csv
# found label not in coref dict -gqmcrTRD9
# Chiara_full_dataset/chiara/output-Co_27gen2023_P.18_LS-id170.csv
# Chiara_full_dataset/chiara/output-Co_29gen2023_P.5_LS-id177.csv
# Chiara_full_dataset/chiara/output-Co_29gen2023_P.7_LS-id178.csv
# Chiara_full_dataset/chiara/output-Co_29gen2023_P.18_LS-id176.csv
# Chiara_full_dataset/chiara/output-Co_31gen2023_P.5_LS-id179.csv
# Chiara_full_dataset/chiara/output-Co_31gen2023_P.5_b_LS-id180.csv
# Chiara_full_dataset/chiara/output-Co_31gen2023_P.5_c_LS-id181.csv
# Chiara_full_dataset/chiara/output-Co_01feb2023_P.12_LS-id111.csv
# Chiara_full_dataset/chiara/output-Co_02feb2023_P.17_LS-id119.csv
# Chiara_full_dataset/chiara/output-Co_02feb2023_P.17_b_LS-id120.csv
# Chiara_full_dataset/chiara/output-Co_03feb2023_P.9_LS-id128.csv
# Chiara_full_dataset/chiara/output-Co_04feb2023_P.6_LS-id130.csv
# Chiara_full_dataset/chiara/output-Co_04feb2023_P.15_LS-id129.csv
# Chiara_full_dataset/chiara/output-Co_08feb2023_P.18_LS-id131.csv
# Chiara_full_dataset/chiara/output-Co_11gen2023_P.16_LS-id135.csv
# found label not in coref dict wnZfK9eq3T
# Chiara_full_dataset/chiara/output-Co_12feb2023_P.21_LS-id137.csv
# found label not in coref dict SjbFv3v8v8
# Chiara_full_dataset/chiara/output-Co_12feb2023_P.45_LS-id138.csv
# found label not in coref dict U_DdtFLpJY
# Chiara_full_dataset/chiara/output-Co_16feb2023_P.14_LS-id142.csv
# Chiara_full_dataset/chiara/output-Co_16feb2023_P.14_b_LS-id143.csv
# found label not in coref dict WFvTzNgAHl
# Chiara_full_dataset/chiara/output-Co_16feb2023_P.20_LS-id144.csv
# found label not in coref dict gDjLJsVSHa
# Chiara_full_dataset/chiara/output-Co_19feb2023_P.14_LS-id146.csv
# Chiara_full_dataset/chiara/output-Co_20feb2023_P.16_LS-id147.csv
# Chiara_full_dataset/chiara/output-Co_22feb2023_P.20_LS-id148.csv
# Chiara_full_dataset/chiara/output-Co_22feb2023_P.21_LS-id149.csv
# Chiara_full_dataset/chiara/output-Co_23feb2023_P.19_LS-id150.csv
# Chiara_full_dataset/chiara/output-Co_24feb2023_P.20_LS-id152.csv
# Chiara_full_dataset/chiara/output-Co_25feb2023_P.27_LS-id155.csv
# Chiara_full_dataset/chiara/output-Co_26feb2023_P.15_LS-id159.csv
# Chiara_full_dataset/chiara/output-Co_26feb2023_P.16_LS-id160.csv
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.2_LS-id163.csv
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.2_b_LS-id164.csv
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.3_LS-id165.csv
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.3_b_LS-id166.csv
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.5_LS-id167.csv
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.5_b_LS-id168.csv
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.2_LS-id171.csv
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.2_b_LS-id172.csv
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.3_LS-id173.csv
# found label not in coref dict cFGHn83Dod
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.5_LS-id174.csv
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.5_b_LS-id175.csv
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.1_LS-id112.csv
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.1_b_LS-id113.csv
# found label not in coref dict a0WQWPV--e
# found label not in coref dict bArCV5COkg
# found label not in coref dict r4LTmM1phP
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.1_c_LS-id114.csv
# found label not in coref dict dFEVo_WREj
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.4_LS-id115.csv
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.5_LS-id116.csv
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.6_LS-id117.csv
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.7_LS-id118.csv
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.5_LS-id121.csv
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.5_b_LS-id122.csv
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.6_LS-id123.csv
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.8_LS-id124.csv
# found label not in coref dict qjuMFat92m
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.8_b_LS-id125.csv
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.9_LS-id126.csv
# found label not in coref dict ktZsTlhDOU
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.9_b_LS-id127.csv
# Chiara_full_dataset/chiara/output-Re_10gen2023_P.12_LS-id206.csv
# Chiara_full_dataset/chiara/output-Re_10gen2023_P.13_LS-id207.csv
# found label not in coref dict E-mIb0RNDC
# Chiara_full_dataset/chiara/output-Re_11gen2023_P.25_LS-id210.csv
# Chiara_full_dataset/chiara/output-Re_11gen2023_P.26_LS-id211.csv
# Chiara_full_dataset/chiara/output-Re_12gen2023_P.23_LS-id213.csv
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.6_LS-id217.csv
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.7_LS-id218.csv
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.7_b_LS-id219.csv
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.28_LS-id216.csv
# Chiara_full_dataset/chiara/output-Re_15gen2023_P.7_LS-id222.csv
# Chiara_full_dataset/chiara/output-Re_15gen2023_P.10_LS-id221.csv
# Chiara_full_dataset/chiara/output-Re_16gen2023_P.12_LS-id223.csv
# Chiara_full_dataset/chiara/output-Re_19gen2023_P.15_LS-id225.csv
# file not found
# Chiara_full_dataset/chiara/output-Re_25gen2023_P.11_LS-id230.csv
# Chiara_full_dataset/chiara/output-Re_26gen2023_P.16_LS-id231.csv
# Chiara_full_dataset/chiara/output-Re_26gen2023_P.16_b_LS-id232.csv
# Chiara_full_dataset/chiara/output-Re_27gen2023_P.4_LS-id239.csv
# found label not in coref dict lXY1sgSQ9u
# Chiara_full_dataset/chiara/output-Re_27gen2023_P.6_LS-id240.csv
# Chiara_full_dataset/chiara/output-Re_28gen2023_P.8_LS-id246.csv
# Chiara_full_dataset/chiara/output-Re_29gen2023_P.12_LS-id247.csv
# Chiara_full_dataset/chiara/output-Re_02feb2023_P.18_LS-id189.csv
# Chiara_full_dataset/chiara/output-Re_02feb2023_P.18_b_LS-id190.csv
# Chiara_full_dataset/chiara/output-Re_04feb2023_P.19_LS-id199.csv
# Chiara_full_dataset/chiara/output-Re_05feb2023_P.13_LS-id200.csv
# Chiara_full_dataset/chiara/output-Re_06feb2023_P.20_LS-id201.csv
# Chiara_full_dataset/chiara/output-Re_07feb2023_P.18_LS-id202.csv
# Chiara_full_dataset/chiara/output-Re_08feb2023_P.5_LS-id203.csv
# Chiara_full_dataset/chiara/output-Re_10feb2023_P.7_LS-id204.csv
# Chiara_full_dataset/chiara/output-Re_10feb2023_P.7_b_LS-id205.csv
# Chiara_full_dataset/chiara/output-Re_11feb2023_P.2_LS-id208.csv
# Chiara_full_dataset/chiara/output-Re_11feb2023_P.5_LS-id209.csv
# Chiara_full_dataset/chiara/output-Re_12feb2023_P.9_LS-id212.csv
# Chiara_full_dataset/chiara/output-Re_13feb2023_P.21_LS-id214.csv
# Chiara_full_dataset/chiara/output-Re_13feb2023_P.21_b_LS-id215.csv
# Chiara_full_dataset/chiara/output-Re_15feb2023_P.31_LS-id220.csv
# Chiara_full_dataset/chiara/output-Re_19feb2023_P.14_LS-id224.csv
# found label not in coref dict AVj9KPwiiB
# Chiara_full_dataset/chiara/output-Re_20feb2023_P.26_LS-id226.csv
# Chiara_full_dataset/chiara/output-Re_22feb2023_P.20_LS-id227.csv
# Chiara_full_dataset/chiara/output-Re_23feb2023_P.17_LS-id228.csv
# Chiara_full_dataset/chiara/output-Re_25feb2023_P.38_LS-id229.csv
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.2_LS-id233.csv
# found label not in coref dict 3Jqa2ERmYp
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.3_LS-id235.csv
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.5_LS-id236.csv
# found label not in coref dict ZMJLImNooD
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.6_LS-id237.csv
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.7_LS-id238.csv
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.26_LS-id234.csv
# found label not in coref dict 7J68HLXfjQ
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.12_LS-id241.csv
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.12_b_LS-id242.csv
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.13_LS-id243.csv
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.15_LS-id244.csv
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.26_LS-id245.csv
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.2_LS-id182.csv
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.3_LS-id183.csv
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.4_LS-id184.csv
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.4_b_LS-id185.csv
# found label not in coref dict 6_u2YKpKiN
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.6_LS-id186.csv
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.6_b_LS-id187.csv
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.7_LS-id188.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.2_LS-id191.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.3_LS-id193.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.3_b_LS-id194.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.4_LS-id195.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.4_b_LS-id196.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.5_LS-id197.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.7_LS-id198.csv
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.23_LS-id192.csv

# %%
df = pd.DataFrame(full_id_data)
test_out = 'Chiara_full_dataset/intermediate_out/full-intermediate.xlsx'
df.to_excel(test_out, sheet_name='Sheet1', na_rep='', float_format=None, 
            columns=None, header=True, index=False)
# Out:
# /var/folders/y9/gpzq16dd7sd129brk7fnpzn00000gn/T/ipykernel_18908/3089930484.py:3: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   df.to_excel(test_out, sheet_name='Sheet1', na_rep='', float_format=None,

# %%
#df[:10]
#Co_12feb2023_P.21

# %%
df.loc[df['Article_id'] == 'Co_12feb2023_P.21'][:30]
# Out:
#      Newspaper_id Lstudio_id         Article_id         Topic Referent_id  \
# 4627  Il Corriere        137  Co_12feb2023_P.21  Current_news           5
# 4628  Il Corriere        137  Co_12feb2023_P.21  Current_news           5
# 4629  Il Corriere        137  Co_12feb2023_P.21  Current_news           5
# 4630  Il Corriere        137  Co_12feb2023_P.21  Current_news           5
# 4631  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4632  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4633  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4634  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4635  Il Corriere        137  Co_12feb2023_P.21  Current_news           3
# 4636  Il Corriere        137  Co_12feb2023_P.21  Current_news           2
# 4637  Il Corriere        137  Co_12feb2023_P.21  Current_news           0
# 4638  Il Corriere        137  Co_12feb2023_P.21  Current_news           0
# 4639  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4640  Il Corriere        137  Co_12feb2023_P.21  Current_news           6
# 4641  Il Corriere        137  Co_12feb2023_P.21  Current_news           7
# 4642  Il Corriere        137  Co_12feb2023_P.21  Current_news           7
# 4643  Il Corriere        137  Co_12feb2023_P.21  Current_news           7
# 4644  Il Corriere        137  Co_12feb2023_P.21  Current_news           2
# 4645  Il Corriere        137  Co_12feb2023_P.21  Current_news           2
# 4646  Il Corriere        137  Co_12feb2023_P.21  Current_news           2
# 4647  Il Corriere        137  Co_12feb2023_P.21  Current_news           2
# 4648  Il Corriere        137  Co_12feb2023_P.21  Current_news           8
# 4649  Il Corriere        137  Co_12feb2023_P.21  Current_news
# 4650  Il Corriere        137  Co_12feb2023_P.21  Current_news           3
# 4651  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4652  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4653  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4654  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4655  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
# 4656  Il Corriere        137  Co_12feb2023_P.21  Current_news           1
#
#                                          Reference_text  \
# 4627                                      medico legale
# 4628                                      medico legale
# 4629                                      medico legale
# 4630                                      medico legale
# 4631  sottufficiale dei carabinieri cinquantenne , i...
# 4632  sottufficiale dei carabinieri cinquantenne , i...
# 4633  sottufficiale dei carabinieri cinquantenne , i...
# 4634  sottufficiale dei carabinieri cinquantenne , i...
# 4635  immigrato che , si presume , spacciava nei bos...
# 4636  Cupola nordafricana della droga e delle sangui...
# 4637  propria catena di comando , l’ autorità giudiz...
# 4638                                            i quali
# 4639                                diretto interessato
# 4640                                   duemila abitanti
# 4641                 i vertici della Compagnia di Luino
# 4642                 i vertici della Compagnia di Luino
# 4643                 i vertici della Compagnia di Luino
# 4644  spacciatori , muniti anche di kalashnikov , ch...
# 4645  spacciatori , muniti anche di kalashnikov , ch...
# 4646  spacciatori , muniti anche di kalashnikov , ch...
# 4647  spacciatori , muniti anche di kalashnikov , ch...
# 4648  tossicodipendenti , sovente giovani , non di r...
# 4649
# 4650  La persona uccisa , secondo la versione del so...
# 4651  sottufficiale — del quale i colleghi negano og...
# 4652  sottufficiale — del quale i colleghi negano og...
# 4653  sottufficiale — del quale i colleghi negano og...
# 4654  sottufficiale — del quale i colleghi negano og...
# 4655  sottufficiale — del quale i colleghi negano og...
# 4656  sottufficiale — del quale i colleghi negano og...
#
#               Reference_level   Reference_valence  \
# 4627  individual-TC-TG-levels   Neutral-TG-levels
# 4628  individual-TC-TG-levels   Neutral-TG-levels
# 4629  individual-TC-TG-levels   Neutral-TG-levels
# 4630  individual-TC-TG-levels   Neutral-TG-levels
# 4631  individual-TC-TG-levels   Neutral-TG-levels
# 4632  individual-TC-TG-levels   Neutral-TG-levels
# 4633  individual-TC-TG-levels   Neutral-TG-levels
# 4634  individual-TC-TG-levels   Neutral-TG-levels
# 4635  individual-TC-TG-levels   Neutral-TG-levels
# 4636      middle-TC-TG-levels  Negative-TG-levels
# 4637      middle-TC-TG-levels   Neutral-TG-levels
# 4638      middle-TC-TG-levels   Neutral-TG-levels
# 4639  individual-TC-TG-levels   Neutral-TG-levels
# 4640      middle-TC-TG-levels   Neutral-TG-levels
# 4641      middle-TC-TG-levels   Neutral-TG-levels
# 4642      middle-TC-TG-levels   Neutral-TG-levels
# 4643      middle-TC-TG-levels   Neutral-TG-levels
# 4644      middle-TC-TG-levels  Negative-TG-levels
# 4645      middle-TC-TG-levels  Negative-TG-levels
# 4646      middle-TC-TG-levels  Negative-TG-levels
# 4647      middle-TC-TG-levels  Negative-TG-levels
# 4648      middle-TC-TG-levels   Neutral-TG-levels
# 4649
# 4650  individual-TC-TG-levels   Neutral-TG-levels
# 4651  individual-TC-TG-levels   Neutral-TG-levels
# 4652  individual-TC-TG-levels   Neutral-TG-levels
# 4653  individual-TC-TG-levels   Neutral-TG-levels
# 4654  individual-TC-TG-levels   Neutral-TG-levels
# 4655  individual-TC-TG-levels   Neutral-TG-levels
# 4656  individual-TC-TG-levels   Neutral-TG-levels
#
#                      Target's_role    Group_membership  \
# 4627  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4628  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4629  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4630  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4631         Perpetrator-TG-levels   Ingroup-TG-levels
# 4632         Perpetrator-TG-levels   Ingroup-TG-levels
# 4633         Perpetrator-TG-levels   Ingroup-TG-levels
# 4634         Perpetrator-TG-levels   Ingroup-TG-levels
# 4635              Victim-TG-levels  Outgroup-TG-levels
# 4636         Perpetrator-TG-levels
# 4637  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4638
# 4639
# 4640               Other-TG-levels   Ingroup-TG-levels
# 4641  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4642  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4643  Istitutional actor-TG-levels   Ingroup-TG-levels
# 4644
# 4645
# 4646
# 4647
# 4648              Victim-TG-levels   Ingroup-TG-levels
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656
#
#                                  Reference_demographics Description_text  \
# 4627                               Profession-TG-levels         appurare
# 4628                               Profession-TG-levels         autopsia
# 4629                               Profession-TG-levels         autopsia
# 4630                               Profession-TG-levels       risolutiva
# 4631                 Age-TG-levels Profession-TG-levels           azione
# 4632                 Age-TG-levels Profession-TG-levels         omicidio
# 4633                 Age-TG-levels Profession-TG-levels        informato
# 4634                 Age-TG-levels Profession-TG-levels        decisioni
# 4635                                                           spacciava
# 4636                              Origin - TC-TG-levels            faide
# 4637                               Profession-TG-levels
# 4638                                                             appreso
# 4639
# 4640                                Residency-TG-levels
# 4641                               Profession-TG-levels        ricordati
# 4642                               Profession-TG-levels        impegnati
# 4643                               Profession-TG-levels      posizionato
# 4644                               Profession-TG-levels        controllo
# 4645                               Profession-TG-levels       contendono
# 4646                               Profession-TG-levels      asfissiante
# 4647                               Profession-TG-levels           muniti
# 4648  Age-TG-levels Origin - TC-TG-levels Family rol...
# 4649                                                            affamati
# 4650
# 4651                               Profession-TG-levels      aspirazione
# 4652                               Profession-TG-levels  farsi giustizia
# 4653                               Profession-TG-levels             solo
# 4654                               Profession-TG-levels        l’ onesta
# 4655                               Profession-TG-levels         carriera
# 4656                               Profession-TG-levels           deriva
#
#          Description_level    Description_valence      Description_group  \
# 4627   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4628   OBS-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4629   OBS-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4630   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4631   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4632   CAT-BH-LCM-behavior  Negative-LCM-behavior   Ingroup-LCM-behavior
# 4633   CAT-BH-LCM-behavior  Negative-LCM-behavior   Ingroup-LCM-behavior
# 4634  MENT-ST-LCM-behavior  Negative-LCM-behavior   Ingroup-LCM-behavior
# 4635   OBS-BH-LCM-behavior  Negative-LCM-behavior  Outgroup-LCM-behavior
# 4636   CAT-BH-LCM-behavior  Negative-LCM-behavior  Outgroup-LCM-behavior
# 4637
# 4638  MENT-ST-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4639
# 4640
# 4641  MENT-ST-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4642   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4643  MENT-ST-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4644   CAT-BH-LCM-behavior  Negative-LCM-behavior  Outgroup-LCM-behavior
# 4645   CAT-BH-LCM-behavior  Negative-LCM-behavior  Outgroup-LCM-behavior
# 4646   CAT-BH-LCM-behavior  Negative-LCM-behavior  Outgroup-LCM-behavior
# 4647   OBS-BH-LCM-behavior  Negative-LCM-behavior  Outgroup-LCM-behavior
# 4648
# 4649  MENT-ST-LCM-behavior   Neutral-LCM-behavior
# 4650
# 4651  MENT-ST-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4652   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4653   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4654    TRAIT-LCM-behavior  Positive-LCM-behavior   Ingroup-LCM-behavior
# 4655   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
# 4656   CAT-BH-LCM-behavior   Neutral-LCM-behavior   Ingroup-LCM-behavior
#
#      Description_demographics
# 4627
# 4628
# 4629
# 4630
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# 4639
# 4640
# 4641
# 4642
# 4643
# 4644
# 4645
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656

# %%
#         predicates = defaultdict(list)
#         for d in ds_unfolded:
#             pred = d['behav_chain_ids'].strip()
#             if pred != '':
#                 predicates[pred].append(d)
#         # print(predicates.keys())
                
#         refs = defaultdict(list)
#         for d in ds_unfolded:
#             ref = d['coref_chain_ids']
#             if ref != '':
#                 refs[ref].append(d)
#         # print(predicates.keys())
#         for pred, pred_ds in predicates.items():
#             pred_tokens = ' '.join([d['token'] for d in pred_ds])
#             # print(pred)
#             # print(pred_tokens)
#             if len(refs) > 0:
#                 for ref, coref_ds in refs.items():
                    
#                     pred_ids = [d['Behavior-predicate'] for d in coref_ds]

#                     # if pred in pred_ids:
#                     #     continue
#                     # else:
                    
#                      # check if valid span
                
#                     ref_tokens = ' '.join([d['token'] for d in coref_ds])
#                     target_ref_ids = set()
#                     for d in coref_ds:
#                         ref_ids = d['coref_chain_ids'].split(' ')
#                         for ref_id in ref_ids:
#                             coref_id, ref_id = ref_id.split('__')
#                             target_ref_ids.add(ref_id)
                        
#                     valid = False
#                     for ref_id in target_ref_ids:
#                         official_tokens = all_ref_tokens[ref_id]
#                         if ref_tokens == official_tokens:
#                             valid = True

#                     if valid:
                        
                        
                 
#                         # print('\t', coref_tokens)
#                         coref = [d['coref-relation']for d in coref_ds]

#                         d_out = dict()
#                         d_out['Newspaper_id'] = news_id
#                         d_out['Lstudio_id'] = ls_id
#                         d_out['Article_id'] = article_id
#                         d_out['Topic'] = topic

#                         d_out['Referent_id'] = coref
#                         d_out['Reference_text'] = ref_tokens
#                         d_out['Reference_level'] = get_cat_info(coref_ds, ref_levels)
#                         d_out['Reference_valence'] =  get_cat_info(coref_ds, valence_ref)
#                         d_out["Target's_role"] = get_cat_info(coref_ds, roles)
#                         d_out['Group_membership'] = get_cat_info(coref_ds, group_ref)
#                         d_out['Reference_demographics'] = get_cat_info(coref_ds, ref_dem)

#                         d_out['Description_text'] = pred_tokens
#                         d_out['Description_level'] = get_cat_info(pred_ds, lcm_level)
#                         d_out['Description_valence'] = get_cat_info(pred_ds, valence_beh)
#                         d_out['Description_group'] = get_cat_info(pred_ds,group_beh)
#                         d_out['Description_demographics'] = get_cat_info(pred_ds, des_dem)
#                         if d_out not in data_out:
#                             data_out.append(d_out)
#             else:
#                 d_out = dict()
#                 d_out['Newspaper_id'] = news_id
#                 d_out['Lstudio_id'] = ls_id
#                 d_out['Article_id'] = article_id
#                 d_out['Topic'] = topic
         
#                 d_out['Referent_id'] = ''
#                 d_out['Reference_text'] = ''
#                 d_out['Reference_level'] = ''
#                 d_out['Reference_valence'] =  ''
#                 d_out["Target's_role"] = ''
#                 d_out['Group_membership'] = ''
#                 d_out['Reference_demographics'] = ''
     
#                 d_out['Description_text'] = pred_tokens
#                 d_out['Description_level'] = get_cat_info(pred_ds, lcm_level)
#                 d_out['Description_valence'] = get_cat_info(pred_ds, valence_beh)
#                 d_out['Description_group'] = get_cat_info(pred_ds,group_beh)
#                 d_out['Description_demographics'] = get_cat_info(pred_ds, des_dem)
#                 data_out.append(d_out)
                
    
    
#     for coref, coref_ds in ref_only_dict.items():
        
#         coref_tokens = ' '.join([d['token'] for d in coref_ds])
                
#         d_out = dict()
#         d_out['Newspaper_id'] = news_id
#         d_out['Lstudio_id'] = ls_id
#         d_out['Article_id'] = article_id
#         d_out['Topic'] = topic
        
#         d_out['Referent_id'] = coref
#         d_out['Reference_text'] = coref_tokens
#         d_out['Reference_level'] = get_cat_info(coref_ds, ref_levels)
#         d_out['Reference_valence'] =  get_cat_info(coref_ds, valence_ref)
#         d_out["Target's_role"] = get_cat_info(coref_ds, roles)
#         d_out['Group_membership'] = get_cat_info(coref_ds, group_ref)
#         d_out['Reference_demographics'] = get_cat_info(coref_ds, ref_dem)
        
        
#         d_out['Description_text'] = ''
#         d_out['Description_level'] = ''
#         d_out['Description_valence'] = ''
#         d_out['Description_group'] = ''
#         d_out['Description_demographics'] = ''
#         data_out.append(d_out)

# %%
# ## BACKUP


# def get_cat_info(target_category_dicts, target_labels):
    
#     d = target_category_dicts[0]
    
#     labels = []
#     for l in target_labels:
#         val = d[l]
#         if val != '':
#             labels.append(l)
#     return ' '.join(labels)



# def unfold_data(data):

        
#     data_unfolded = []
#     data_unfolded_preds = []
    
#     for d in data:
        
#         ref_ids = d['coref-relation']
#         if ref_ids != '':
#             ref_ids = ref_ids.split(' ')
            
#             for rid in ref_ids:
#                 d_new = dict()
#                 d_new.update(d)
#                 d_new['coref-relation'] = rid
#                 data_unfolded.append(d_new)
#         else:
#             data_unfolded.append(d)
            
    
#     for d in data_unfolded:
#         pred_ids = d['behav-relation']
#         if pred_ids != '':
#             pred_ids = pred_ids.split(' ')
            
#             for prid in pred_ids:
#                 d_new = dict()
#                 d_new.update(d)
#                 d_new['behav-relation'] = prid
#                 data_unfolded_preds.append(d_new)
#         else:
#             data_unfolded_preds.append(d)
        
#     return data_unfolded_preds
    
    

# def process_file(test_path, topic, news_id, valence_ref, ref_levels, 
#                  roles, group_ref, ref_dem, lcm_level, valence_beh, group_beh, des_dem,):

#     id_data = []
    
#     try:
#         with open(test_path) as infile:
#             data = list(csv.DictReader(infile, delimiter = ','))
#     except FileNotFoundError:
#         print('file not found')
#         data = []
        
#     print(len(data))
#     data = unfold_data(data)
#     print(len(data))
        
          
#     ref_behav_dict = defaultdict(list)
#     coref_dict = defaultdict(list)
#     ref_only_dict = defaultdict(list)
    
#     for d in data:
#         rel_ref_behav = d['behav-relation']
#         rel_ref = d['coref-relation']
#         if rel_ref_behav != '':
#             for r in rel_ref_behav.split(' '):
#                 ref_behav_dict[r].append(d)
#         if rel_ref != '':
#             for r in rel_ref.split(' '):
#                 coref_dict[r].append(d)
                
#         if rel_ref != '' and rel_ref_behav == '':
#             for r in rel_ref.split(' '):
#                 ref_behav_dict[r].append(d)
        
    
#     data_out = []
#     for rel, ds in ref_behav_dict.items():
        
#         predicates = defaultdict(list)
#         target_categories = defaultdict(list)
#         for d in ds:
#             tcs = [i for i in d['Target-category-reference'].strip().split(' ') if i != '']
#             preds = [i for i in d['Behavior-predicate'].strip().split(' ') if i != '']
#             if tcs != []:
#                 for tc in tcs:
#                     target_categories[tc].append(d)
#             if preds != []:
#                 for pred in preds:
#                     if pred in predicates:
#                         if d not in predicates[pred]:
#                             predicates[pred].append(d)
#                     else:
#                         predicates[pred].append(d)

#         for tc, tc_ds in target_categories.items():
#             target_tokens = ' '.join([d['token'] for d in tc_ds])
#             ref_ids =  set()
#             if len(tc_ds) != 0:
#                 for tc in tc_ds:
#                     ref_ids.update([ref_id for ref_id in tc['coref-relation'].split(' ') if ref_id!= ''])
#             # print('target references')
#             # print(target_tokens, ref_ids)

#             if len(predicates) != 0:
#                 for pred_id, pred_ds in predicates.items():
#                     d_out = dict()
#                     d_out['Newspaper_id'] = news_id
#                     d_out['Lstudio_id'] = ls_id
#                     d_out['Article_id'] = article_id
#                     d_out['Topic'] = topic
#                     tokens = ' '.join([d['token'] for d in pred_ds])
#                     # print('\tpredicate')
#                     # print('\t', tokens)
#                     if len(target_categories) != 0:
#                         print(ref_ids)
#                         print(tokens)
#                         print(target_tokens)
#                         print()
#                         for ref_id in ref_ids:
#                             d_out['Referent_id'] = ref_id
#                             d_out['Reference_text'] = target_tokens
#                             d_out['Reference_level'] = get_cat_info(tc_ds, ref_levels)
#                             d_out['Reference_valence'] =  get_cat_info(tc_ds, valence_ref)
#                             d_out["Target's_role"] = get_cat_info(tc_ds, roles)
#                             d_out['Group_membership'] = get_cat_info(tc_ds, group_ref)
#                             d_out['Reference_demographics'] = get_cat_info(tc_ds, ref_dem)
#                             # ... 
#                             d_out['Description_text'] = tokens
#                             d_out['Description_level'] = get_cat_info(pred_ds, lcm_level)
#                             d_out['Description_valence'] = get_cat_info(pred_ds, valence_beh)
#                             d_out['Description_group'] = get_cat_info(pred_ds,group_beh)
#                             d_out['Description_demographics'] = get_cat_info(pred_ds, des_dem)
#                             data_out.append(d_out)

#                     else:
#                         d_out['Referent_id'] = ''
#                         d_out['Reference_text'] = ''
#                         d_out['Reference_level'] = ''
#                         d_out['Reference_valence'] =  ''
#                         d_out["Target's_role"] = ''
#                         d_out['Group_membership'] = ''
#                         d_out['Reference_demographics'] = ''
#                         # ... 
#                         d_out['Description_text'] = tokens
#                         d_out['Description_level'] = get_cat_info(pred_ds, lcm_level)
#                         d_out['Description_valence'] = get_cat_info(pred_ds, valence_beh)
#                         d_out['Description_group'] = get_cat_info(pred_ds,group_beh)
#                         d_out['Description_demographics'] = get_cat_info(pred_ds, des_dem)
#                         data_out.append(d_out)
#             else:
#                 # print(len(predicates), len(target_categories))
#                 ref_ids = set(ref_ids)
#                 # print(ref_ids)
#                 if len(target_categories) != 0:
#                     for ref_id in ref_ids:
#                         d_out = dict()
#                         d_out['Newspaper_id'] = news_id
#                         d_out['Lstudio_id'] = ls_id
#                         d_out['Article_id'] = article_id
#                         d_out['Topic'] = topic
#                         # print(tc_ds)
#                         d_out['Referent_id'] = ref_id
#                         d_out['Reference_text'] = target_tokens
#                         d_out['Reference_level'] = get_cat_info(tc_ds, ref_levels)
#                         d_out['Reference_valence'] =  get_cat_info(tc_ds, valence_ref)
#                         d_out["Target's_role"] = get_cat_info(tc_ds, roles)
#                         d_out['Group_membership'] = get_cat_info(tc_ds, group_ref)
#                         d_out['Reference_demographics'] = get_cat_info(tc_ds, ref_dem)
#                         # ... 
#                         d_out['Description_text'] = ''
#                         d_out['Description_level'] = ''
#                         d_out['Description_valence'] = ''
#                         d_out['Description_group'] = ''
#                         d_out['Description_demographics'] = ''
#                         data_out.append(d_out)

            
#     return data_out
