# %% [markdown]
# # Analyze LS output - Dataset Chiara

# %%
import json
import csv
from collections import defaultdict
import spacy
import pandas as pd
import os

# %%
nlp = spacy.load("it_core_news_sm")

# %%
# labels = [
#     "Target-category-reference",
#     "Behavior-predicate",
#     "Common sup ingroup",
#     "Prosocial behavior",
#     "Other",
#     "Istitutional actor",
#     "Singular pronoun",
#     "Plural pronoun",
#     "Proper noun",
#     "Activity",
#     "Empty",
#     # LEVELS
#     'high-TC-TG-levels', 
#     'middle-TC-TG-levels', 
#     'individual-TC-TG-levels',
#     #LCM
#     'OBS-BH-LCM-behavior', 
#      "CAT-BH-LCM-behavior", 
#      "MENT-ST-LCM-behavior",
#      "TRAIT-LCM-behavior",
#     # Valence ref
#     'Positive-TG-levels', 
#    'Neutral-TG-levels', 
#    'Negative-TG-levels',
#     # Valence behav
#     'Positive-LCM-behavior',
#    'Neutral-LCM-behavior', 
#    'Negative-LCM-behavior',
#     # IN-OUT-REF
#     'Outgroup-TG-levels', 
#     'Ingroup-TG-levels',
#     # In-OUT-BEHAV
#     'Ingroup-LCM-behavior', 
#     "Outgroup-LCM-behavior",
#     # Roles
#     'Perpetrator-TG-levels',
#     "Victim-TG-levels",
#     "Prosocial behavior-TG-levels",
#     "Other-TG-levels",
#     "Istitutional actor-TG-levels",
#     # DEM
#     'Age-TG-levels', 
#    'Residency-TG-levels', 
#    'Gender-TG-levels', 
#    'Origin - TC-TG-levels',
#    'Education-TG-levels', 
#    'Family role-TG-levels',
#    'Profession-TG-levels', 
#    'Origin - TC-TG-levels',
#    'Other category-TG-levels',
#     # DEM behav
#     'Age-LCM-behavior', 
#    'Residency-LCM-behavior', 
#    'Gender-LCM-behavior', 
#    'Origin - TC-LCM-behavior',
#    'Education-LCM-behavior', 
#    'Family role-LCM-behavior',
#    'Profession-LCM-behavior', 
#    'Origin - TC-LCM-behavior',
#    'Other category-LCM-behavior',
# ]

with open('Chiara_full_dataset/labels-chiara.txt') as infile:
    labels = [l.strip().strip("'").strip('"') for l in infile.read().strip().split('\n')]
# labels

# %%
def get_labels(annotations):
    offset_label_dict = defaultdict(list)
    id_relation_dict = defaultdict(list)
    # sort_annotations_by_id
    id_ann_dict = defaultdict(list)
    id_name_dict = dict()

    for an in annotations:
        labels_relations = an['result']
        for la in labels_relations:
            # check if label:
            # print(la)
            # print()
            if 'value' in la:
                target_an = la['value']
                start = target_an['start']
                end = target_an['end']
                ann_id = la['id']
                id_ann_dict[ann_id].append(la)
                for i in range(start, end):
                    offset_label_dict[i].append(la)
                # print('offsets')
                # print(start, la, type(start))
                if 'labels' in target_an:
                    id_name_dict[ann_id] = target_an['labels'][0]

            elif 'from_id' in la:
                from_id = la['from_id']
                to_id = la['to_id']
                id_relation_dict[(from_id, to_id)].append(la)
            else:
                print(la)
    return offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict




def get_chains(id_relations_dict):
    chains = defaultdict(set)
    coref_id = dict()
    n = 0
    for rel_pair, relations in id_relations_dict.items():
        rel1, rel2 = rel_pair

        if n == 0:
            chains[0].add(rel1)
            chains[0].add(rel2)
            n+=1 

        else:
            added = False
            for pair_n, chain in chains.items():
                if rel1 in chain:
                    chain.add(rel2)
                    added = True
                if rel2 in chain:
                    chain.add(rel1)
                    added = True
            if added == False:
                chains[n].add(rel1)
                chains[n].add(rel2)
                n+=1

    for chain_id, chain in chains.items():
        for label_id in chain:
            coref_id[label_id] = chain_id

    return chains, coref_id

#separate_chains(token_data)

def filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2=None):
 # Filter relations on labels
    id_rel_dict_target = dict()
    if target_label2 is None:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]   
                    
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
                    all_labels = [l for l in l['value']['labels']]
                    if len(all_labels) > 1:
                        print('found more labels:', len(all_labels))
            if l1_name == l2_name:
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
    else:
        for lid1, lid2 in id_relation_dict.keys():
            l1 = id_ann_dict[lid1]
            l2 = id_ann_dict[lid2]
            for l in l1:
                if 'labels' in l['value']:
                    l1_name = l['value']['labels'][0]
            for l in l2:
                if 'labels' in l['value']:
                    l2_name = l['value']['labels'][0]
            if ((l1_name == target_label1) and (l2_name == target_label2) 
            or (l1_name == target_label2) and (l2_name == target_label1)):
                rel = id_relation_dict[(lid1, lid2)]
                id_rel_dict_target[(lid1, lid2)] = rel
        
    return id_rel_dict_target



        
    
def add_singletons(token_data):
    
    coref_ids = []
    for d in token_data:
        if d['ref-relations'] != []:
            coref_ids.extend(d['ref-relations'])
    # [d['ref-relations'] for d in token_data if d['ref-relations'] != '']
    if len(coref_ids) > 0:
        max_coref_id = max(coref_ids)
    
        single_ent_id = max_coref_id +1 
    else:
        single_ent_id = 0
        
    token_data_by_cat = defaultdict(list)
    for d in token_data:
        tcs = d['Target-category-reference']
        for t in tcs:
            token_data_by_cat[t].append(d)
        
    
    for t, ds in token_data_by_cat.items():
        added_single_ent = False
        for d in ds:
            #rels = d['ref-relations']
            tcs = d['Target-category-reference']
            ref_id_rels = d['ref-id-relations']

           
            if tcs != [] and  ref_id_rels == []:
                # singleton!
                d['ref-relations'] = [single_ent_id]
                d['ref-id-relations'] = [f'{single_ent_id}-_-{t}']
                added_single_ent = True
            elif len(tcs) != len(ref_id_rels):
                rels_no_coref = [r.split('-_-')[1] for r in ref_id_rels]
                for t in tcs:
                    if t not in rels_no_coref:
                        d['ref-relations'].append(single_ent_id)
                        d['ref-id-relations'].append(f'{single_ent_id}-_-{t}')
                        added_single_ent = True
            else:
                continue
        
        if added_single_ent:
            single_ent_id += 1
            
            
def make_relation_mappings(id_relation_dict, id_name_dict):
    
    coref_mappings = dict()
    behav_mappings = defaultdict(list)
    
    for id_pair, d_list in id_relation_dict.items():
        id1, id2 = id_pair
        label1 = id_name_dict[id1]
        label2 = id_name_dict[id2]

   
        
        #if rel_type == 'ref-behav
        if label1 == label2 == 'Target-category-reference':
            # print('coref', label1, label2)
            coref_mappings[id1] = id2
            coref_mappings[id2] = id1
        # elif label1 == label2 == 'Behavior-predicate':
        #     pass
        elif label1 == 'Behavior-predicate' and label2 == 'Target-category-reference':
            # 
            behav_mappings[id2].append(id1)
        elif label1 == 'Target-category-reference' and label2 == 'Behavior-predicate':
            behav_mappings[id1].append(id2)

        #elif label1 
            
    return coref_mappings, behav_mappings

# %%
### TEST COREF CHAIN CODE

name = 'chiara'
output = 'Chiara_full_dataset'
#path = f'output-comparison-v2/{name}.json'
path = f'{output}/{name}.json'

dir_out = f'{output}/{name}'
if not os.path.isdir(dir_out):
    os.mkdir(dir_out)

with open(path) as infile:
    annotation_data = json.load(infile)
    
for n, data in enumerate(annotation_data):
    ls_id = data['id']
    annotations = data['annotations']
    text = data['data']['text']
    text_id = text.split('\n', 1)[0].split(': ')[-1]
    print(text_id, ls_id)
    path_out = f'{dir_out}/output-{text_id}_LS-id{ls_id}.csv'
    print(path_out)
    
    offset_label_dict, id_relation_dict, id_ann_dict, id_name_dict = get_labels(annotations)
    coref_mappings, behav_mappings = make_relation_mappings(id_relation_dict, id_name_dict)
    

    target_label = 'Target-category-reference'
    id_relations_ref = filter_relations(id_relation_dict, id_ann_dict, target_label)
    
    target_label1 = 'Target-category-reference'
    target_label2 =  "Behavior-predicate"
    id_relations_behav = filter_relations(id_relation_dict, id_ann_dict, target_label1, target_label2)
    
    if 'JUuhN06Sm_' in id_ann_dict:
        print(id_ann_dict['JUuhN06Sm_'])
    
    
        
    coref_chains_ref, coref_dict_ref = get_chains(id_relations_ref)
    coref_chains_behav, coref_dict_behav = get_chains(id_relations_behav)
    
    
    doc = nlp(text)

    
    tok_id_ann_id_dict = defaultdict(set)
    
    if 322 in offset_label_dict:
        print('found 322')
        print(offset_label_dict[322])
    
    for tok in doc:
        tok_start = tok.idx

        for i in range(tok.idx, tok.idx+len(tok)):
            if i in offset_label_dict:
                anns = offset_label_dict[i]
                for an in anns:
                    an_id = an['id']
                    tok_id_ann_id_dict[tok.i].add(an_id)
                    
    
                



    token_data = []
    for tok in doc:
        
        tok_id = tok.i
        tok_dict = defaultdict(list)
        tok_dict['tok-id'] = tok_id
        tok_dict['token'] = tok.text
        tok_dict['ref-relations'] = []
        tok_dict['ref-behav-relations'] = []
        tok_dict['ref-id-relations'] = []
        tok_dict['coref-id-mapping'] = []
        tok_dict['behav-id-mapping'] = []
                 
        # tok_dict['ref-behav-relations-new'] = ''

        #tok_dict['TC-COREF'] = ''
        for l in labels:
            tok_dict[l] = []
            
        
        an_ids = tok_id_ann_id_dict[tok_id]
        # print(tok_id, an_ids)

        for an_id in an_ids:        
            anns = id_ann_dict[an_id]
     
            #rels = an_rel_dict[an_id]
            for an in anns:
                add_label = ''

                if 'from_name' in an:
                    add_label = an['from_name']
                    
                if 'labels' in an['value']:
                    label = an['value']['labels'][0]
                    tok_dict[f'{label}'].append(an_id)
                if 'choices' in an['value']:
                    for choice in an['value']['choices']:
                        if add_label != '':
                            tok_dict[f'{choice}-{add_label}'].append(an_id)
                        else:
                            tok_dict[choice].append(an_id)

             # coref:
            if an_id in coref_dict_behav:
                # if tok_dict['relations'] == '':
                #tok_dict['ref-behav-relations'] = coref_dict[an_id]
                tok_dict['ref-behav-relations'].append(coref_dict_behav[an_id])
                #tok_dict['ref-relations'] = coref_dict_ref[an_id]

            if an_id in coref_dict_ref:
                # if tok_dict['relations'] == '':
                #tok_dict['ref-behav-relations'] = coref_dict[an_id]
               
                tok_dict['ref-relations'].append(coref_dict_ref[an_id])
                tok_dict['ref-id-relations'].append(f'{coref_dict_ref[an_id]}-_-{an_id}')
            
            if an_id in coref_mappings:
                tok_dict['coref-id-mapping'].append(f'{an_id}-_-{coref_mappings[an_id]}')
            if an_id in behav_mappings:
                for behav_id in behav_mappings[an_id]:
                    tok_dict['behav-id-mapping'].append(f'{an_id}-_-{behav_id}')
          
  
        token_data.append(tok_dict)

    #interpret_relations(token_data)
    # full_coref_ids(token_data)
    #separate_chains(token_data)
    # map_relations(token_data)
    add_singletons(token_data)
    for tok_dict in token_data:

        for k, v in tok_dict.items():
            if type(v) == list:
                v = [str(i) for i in v]
                tok_dict[k] = ' '.join(v)
            else:
                tok_dict[k] = v
        
    df = pd.DataFrame(token_data)
    df.to_csv(path_out, index=False)
# Out:
# RdC_01feb2023_Fe 13
# Chiara_full_dataset/chiara/output-RdC_01feb2023_Fe_LS-id13.csv
# found 322
# [{'value': {'start': 322, 'end': 339, 'text': 'diciotto indagati', 'labels': ['Target-category-reference']}, 'id': 'ZCHA_Pxqf8', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 322, 'end': 339, 'text': 'diciotto indagati', 'choices': ['middle-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Activity']}, 'id': 'ZCHA_Pxqf8', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_01feb2023_Mo 14
# Chiara_full_dataset/chiara/output-RdC_01feb2023_Mo_LS-id14.csv
# RdC_01mar2023_Bo 15
# Chiara_full_dataset/chiara/output-RdC_01mar2023_Bo_LS-id15.csv
# RdC_02feb2023_Fe 16
# Chiara_full_dataset/chiara/output-RdC_02feb2023_Fe_LS-id16.csv
# found 322
# [{'value': {'start': 308, 'end': 343, 'text': 'ex moglie, una trentenne pachistana', 'labels': ['Target-category-reference']}, 'id': 'uMy8w-Nhp0', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 308, 'end': 343, 'text': 'ex moglie, una trentenne pachistana', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Victim', 'Origin - TC', 'Age', 'Family role']}, 'id': 'uMy8w-Nhp0', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_02feb2023_Pr 17
# Chiara_full_dataset/chiara/output-RdC_02feb2023_Pr_LS-id17.csv
# found 322
# [{'value': {'start': 320, 'end': 327, 'text': 'ubriaco', 'labels': ['Behavior-predicate']}, 'id': 'r3sb4ldnEp', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 320, 'end': 327, 'text': 'ubriaco', 'choices': ['MENT-ST', 'Neutral', 'Outgroup']}, 'id': 'r3sb4ldnEp', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_02feb2023_Ra 18
# Chiara_full_dataset/chiara/output-RdC_02feb2023_Ra_LS-id18.csv
# RdC_03feb2023_Fc 19
# Chiara_full_dataset/chiara/output-RdC_03feb2023_Fc_LS-id19.csv
# [{'value': {'start': 2514, 'end': 2525, 'text': 'aggressione', 'labels': ['Behavior-predicate']}, 'id': 'JUuhN06Sm_', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 2514, 'end': 2525, 'text': 'aggressione', 'choices': ['CAT-BH', 'Negative', 'Outgroup']}, 'id': 'JUuhN06Sm_', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# found 322
# [{'value': {'start': 315, 'end': 323, 'text': 'episodio', 'labels': ['Behavior-predicate']}, 'id': 'V4baxRtCsb', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 315, 'end': 323, 'text': 'episodio', 'choices': ['CAT-BH', 'Negative', 'Outgroup']}, 'id': 'V4baxRtCsb', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_07feb2023_Im 21
# Chiara_full_dataset/chiara/output-RdC_07feb2023_Im_LS-id21.csv
# RdC_09feb2023_Bo 22
# Chiara_full_dataset/chiara/output-RdC_09feb2023_Bo_LS-id22.csv
# found 322
# [{'value': {'start': 321, 'end': 327, 'text': ' pugni', 'labels': ['Behavior-predicate']}, 'id': 'L7W3L1Rlp7', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 327, 'text': ' pugni', 'choices': ['OBS-BH', 'Negative', 'Outgroup']}, 'id': 'L7W3L1Rlp7', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_10feb2023_Im 23
# Chiara_full_dataset/chiara/output-RdC_10feb2023_Im_LS-id23.csv
# RdC_10gen2023_Fe 24
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Fe_LS-id24.csv
# RdC_10gen2023_Fe_b 25
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Fe_b_LS-id25.csv
# RdC_10gen2023_R.em 27
# Chiara_full_dataset/chiara/output-RdC_10gen2023_R.em_LS-id27.csv
# RdC_10gen2023_R.em_d 28
# Chiara_full_dataset/chiara/output-RdC_10gen2023_R.em_d_LS-id28.csv
# found 322
# [{'value': {'start': 305, 'end': 371, 'text': 'della donna che vanterebbe parentele di peso nella polizia locale', 'labels': ['Target-category-reference']}, 'id': 'h7RQUtf6n3', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 305, 'end': 371, 'text': 'della donna che vanterebbe parentele di peso nella polizia locale', 'choices': ['individual-TC', 'Neutral', 'Singular pronoun', 'Gender', 'Family role']}, 'id': 'h7RQUtf6n3', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_10gen2023_Ri 30
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Ri_LS-id30.csv
# RdC_10gen2023_Ri_b 31
# Chiara_full_dataset/chiara/output-RdC_10gen2023_Ri_b_LS-id31.csv
# RdC_11gen2023_Fe_c 32
# Chiara_full_dataset/chiara/output-RdC_11gen2023_Fe_c_LS-id32.csv
# RdC_11gen2023_Fe_d 33
# Chiara_full_dataset/chiara/output-RdC_11gen2023_Fe_d_LS-id33.csv
# found 322
# [{'value': {'start': 317, 'end': 364, 'text': 'Ministro irpino dellInterno prefetto Piantedosi', 'labels': ['Target-category-reference']}, 'id': 'KKcDOL8lo0', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 317, 'end': 364, 'text': 'Ministro irpino dellInterno prefetto Piantedosi', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Origin - TC', 'Profession', 'Proper noun']}, 'id': 'KKcDOL8lo0', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_11gen2023_Ri 35
# Chiara_full_dataset/chiara/output-RdC_11gen2023_Ri_LS-id35.csv
# found 322
# [{'value': {'start': 301, 'end': 337, 'text': 'i due, gi noti alle forze dellordine', 'labels': ['Target-category-reference']}, 'id': '6GMt_7zRAH', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 301, 'end': 337, 'text': 'i due, gi noti alle forze dellordine', 'choices': ['middle-TC', 'Neutral', 'Plural pronoun']}, 'id': '6GMt_7zRAH', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}, {'value': {'start': 321, 'end': 337, 'text': 'forze dellordine', 'labels': ['Target-category-reference']}, 'id': 'tEAcKn7cuc', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 337, 'text': 'forze dellordine', 'choices': ['middle-TC', 'Neutral', 'Profession']}, 'id': 'tEAcKn7cuc', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_12gen2023_Mo 36
# Chiara_full_dataset/chiara/output-RdC_12gen2023_Mo_LS-id36.csv
# found 322
# [{'value': {'start': 278, 'end': 325, 'text': 'I tre, tutti cittadini cinesi residenti a Carpi', 'labels': ['Target-category-reference']}, 'id': 'je9fyJ7QJM', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 278, 'end': 325, 'text': 'I tre, tutti cittadini cinesi residenti a Carpi', 'choices': ['middle-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Origin - TC', 'Residency']}, 'id': 'je9fyJ7QJM', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_13feb2023_Mo 37
# Chiara_full_dataset/chiara/output-RdC_13feb2023_Mo_LS-id37.csv
# found 322
# [{'value': {'start': 314, 'end': 329, 'text': 'le associazioni', 'labels': ['Target-category-reference']}, 'id': '7bO5UZ9bqR', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 314, 'end': 329, 'text': 'le associazioni', 'choices': ['middle-TC', 'Neutral', 'Outgroup', 'Istitutional actor', 'Empty']}, 'id': '7bO5UZ9bqR', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_13feb2023_Mo_d 39
# Chiara_full_dataset/chiara/output-RdC_13feb2023_Mo_d_LS-id39.csv
# RdC_13gen2023_Mo_b 40
# Chiara_full_dataset/chiara/output-RdC_13gen2023_Mo_b_LS-id40.csv
# RdC_13gen2023_Mo_c 41
# Chiara_full_dataset/chiara/output-RdC_13gen2023_Mo_c_LS-id41.csv
# found 322
# [{'value': {'start': 302, 'end': 327, 'text': 'La moglie e le due figlie', 'labels': ['Target-category-reference']}, 'id': '6per3QL4v5', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 302, 'end': 327, 'text': 'La moglie e le due figlie', 'choices': ['individual-TC', 'Neutral', 'Family role']}, 'id': '6per3QL4v5', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_13gen2023_R.em 42
# Chiara_full_dataset/chiara/output-RdC_13gen2023_R.em_LS-id42.csv
# RdC_13gen2023_R.em_b 43
# Chiara_full_dataset/chiara/output-RdC_13gen2023_R.em_b_LS-id43.csv
# found 322
# [{'value': {'start': 283, 'end': 341, 'text': 'un giovane straniero sorpreso mentre rubava in un negozio', 'labels': ['Target-category-reference']}, 'meta': {'text': ['Outgroup categorization: age + gender + origin                                                                      Outgroup origin: not specified ']}, 'id': 'fM1Q1cq3xO', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 283, 'end': 341, 'text': 'un giovane straniero sorpreso mentre rubava in un negozio', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Age']}, 'meta': {'text': ['Outgroup categorization: age + gender + origin                                                                      Outgroup origin: not specified ']}, 'id': 'fM1Q1cq3xO', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}, {'value': {'start': 321, 'end': 327, 'text': 'rubava', 'labels': ['Behavior-predicate']}, 'id': 'OikBDeS6lW', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 327, 'text': 'rubava', 'choices': ['OBS-BH', 'Negative', 'Outgroup']}, 'id': 'OikBDeS6lW', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_13gen2023_R.em_e 44
# Chiara_full_dataset/chiara/output-RdC_13gen2023_R.em_e_LS-id44.csv
# RdC_14feb2023_Bo 45
# Chiara_full_dataset/chiara/output-RdC_14feb2023_Bo_LS-id45.csv
# found 322
# [{'value': {'start': 316, 'end': 328, 'text': 'rintracciato', 'labels': ['Behavior-predicate']}, 'id': 'UIu84akupG', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 316, 'end': 328, 'text': 'rintracciato', 'choices': ['CAT-BH', 'Neutral', 'Ingroup']}, 'id': 'UIu84akupG', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_14feb2023_Fc 46
# Chiara_full_dataset/chiara/output-RdC_14feb2023_Fc_LS-id46.csv
# found 322
# [{'value': {'start': 318, 'end': 326, 'text': 'sospetto', 'labels': ['Behavior-predicate']}, 'id': 'csj1vcfMbD', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 326, 'text': 'sospetto', 'choices': ['CAT-BH', 'Negative', 'Outgroup']}, 'id': 'csj1vcfMbD', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_14gen2023_Mo 47
# Chiara_full_dataset/chiara/output-RdC_14gen2023_Mo_LS-id47.csv
# RdC_14gen2023_Mo_b 48
# Chiara_full_dataset/chiara/output-RdC_14gen2023_Mo_b_LS-id48.csv
# RdC_15gen2023_Fe 52
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Fe_LS-id52.csv
# RdC_15gen2023_Fe_c 54
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Fe_c_LS-id54.csv
# RdC_15gen2023_Mo 55
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Mo_LS-id55.csv
# RdC_15gen2023_Ri 57
# Chiara_full_dataset/chiara/output-RdC_15gen2023_Ri_LS-id57.csv
# found 322
# [{'value': {'start': 321, 'end': 327, 'text': 'attesa', 'labels': ['Behavior-predicate']}, 'id': 'VMKPQYXI9w', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 327, 'text': 'attesa', 'choices': ['CAT-BH', 'Neutral', 'Outgroup']}, 'id': 'VMKPQYXI9w', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_16feb2023_Bo_b 60
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Bo_b_LS-id60.csv
# RdC_16feb2023_Mo 62
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Mo_LS-id62.csv
# RdC_16feb2023_Mo_b 63
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Mo_b_LS-id63.csv
# RdC_16gen2023_R.em_b 64
# Chiara_full_dataset/chiara/output-RdC_16gen2023_R.em_b_LS-id64.csv
# RdC_17feb2023_Fc 65
# Chiara_full_dataset/chiara/output-RdC_17feb2023_Fc_LS-id65.csv
# RdC_17feb2023_Im_b 66
# Chiara_full_dataset/chiara/output-RdC_17feb2023_Im_b_LS-id66.csv
# RdC_17feb2023_Im_c 67
# Chiara_full_dataset/chiara/output-RdC_17feb2023_Im_c_LS-id67.csv
# found 322
# [{'value': {'start': 256, 'end': 350, 'text': 'famiglie con bambini fino a sei anni delle pi numerose comunit straniere che risiedono in citt', 'labels': ['Target-category-reference']}, 'id': 'ojIhhj_aGI', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 256, 'end': 350, 'text': 'famiglie con bambini fino a sei anni delle pi numerose comunit straniere che risiedono in citt', 'choices': ['middle-TC', 'Neutral', 'Outgroup', 'Other', 'Residency', 'Age', 'Family role']}, 'id': 'ojIhhj_aGI', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_17gen2023_Mo 70
# Chiara_full_dataset/chiara/output-RdC_17gen2023_Mo_LS-id70.csv
# found 322
# [{'value': {'start': 318, 'end': 326, 'text': 'rapinare', 'labels': ['Behavior-predicate']}, 'id': '9uguJsYIkI', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 326, 'text': 'rapinare', 'choices': ['OBS-BH', 'Negative', 'Outgroup']}, 'id': '9uguJsYIkI', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_18feb2023_Bo_b 73
# Chiara_full_dataset/chiara/output-RdC_18feb2023_Bo_b_LS-id73.csv
# found 322
# [{'value': {'start': 314, 'end': 490, 'text': 'i due, rispettivamente un marocchino e un tunisino, entrambi con precedenti anche specifici (il tunisino aveva a proprio carico anche un provvedimento di espulsione dallItalia)', 'labels': ['Target-category-reference']}, 'id': 'ecKNwsF-IT', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 314, 'end': 490, 'text': 'i due, rispettivamente un marocchino e un tunisino, entrambi con precedenti anche specifici (il tunisino aveva a proprio carico anche un provvedimento di espulsione dallItalia)', 'choices': ['middle-TC', 'Neutral', 'Origin - TC', 'Activity']}, 'id': 'ecKNwsF-IT', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_18gen2023_Fc 74
# Chiara_full_dataset/chiara/output-RdC_18gen2023_Fc_LS-id74.csv
# RdC_19feb2023_Bo 75
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Bo_LS-id75.csv
# RdC_19feb2023_Bo_e 76
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Bo_e_LS-id76.csv
# RdC_19feb2023_Bo_f 77
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Bo_f_LS-id77.csv
# found 322
# [{'value': {'start': 320, 'end': 344, 'text': 'gli agenti della polizia', 'labels': ['Target-category-reference']}, 'id': 'K0h_SkuDoR', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 320, 'end': 344, 'text': 'gli agenti della polizia', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession']}, 'id': 'K0h_SkuDoR', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_19feb2023_Fc 78
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Fc_LS-id78.csv
# found 322
# [{'value': {'start': 305, 'end': 491, 'text': 'un cittadino tunisino di 29 anni, con diversi precedenti per spaccio di sostanze stupefacenti, gi colpito da un decreto di espulsione dal territorio nazionale a cui non aveva ottemperato', 'labels': ['Target-category-reference']}, 'id': 'Q6fjq7vyCb', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 305, 'end': 491, 'text': 'un cittadino tunisino di 29 anni, con diversi precedenti per spaccio di sostanze stupefacenti, gi colpito da un decreto di espulsione dal territorio nazionale a cui non aveva ottemperato', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Origin - TC', 'Age', 'Activity']}, 'id': 'Q6fjq7vyCb', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_19feb2023_Fc_b 79
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Fc_b_LS-id79.csv
# RdC_19feb2023_Fc_c 80
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Fc_c_LS-id80.csv
# RdC_19feb2023_Mo_c 82
# Chiara_full_dataset/chiara/output-RdC_19feb2023_Mo_c_LS-id82.csv
# found 322
# [{'value': {'start': 322, 'end': 330, 'text': 'arrivare', 'labels': ['Behavior-predicate']}, 'id': 'nmLL0vNBqc', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 322, 'end': 330, 'text': 'arrivare', 'choices': ['OBS-BH', 'Neutral', 'Outgroup']}, 'id': 'nmLL0vNBqc', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_19gen2023_R.em_b 84
# Chiara_full_dataset/chiara/output-RdC_19gen2023_R.em_b_LS-id84.csv
# RdC_20feb2023_Bo_b 87
# Chiara_full_dataset/chiara/output-RdC_20feb2023_Bo_b_LS-id87.csv
# RdC_20gen2023_R.em 88
# Chiara_full_dataset/chiara/output-RdC_20gen2023_R.em_LS-id88.csv
# RdC_22feb2023_Bo_b 90
# Chiara_full_dataset/chiara/output-RdC_22feb2023_Bo_b_LS-id90.csv
# found 322
# [{'value': {'start': 274, 'end': 333, 'text': 'un marocchino di 39 anni senza fissa dimora sul territorio,', 'labels': ['Target-category-reference']}, 'id': 'nrL5MEg3ix', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 274, 'end': 333, 'text': 'un marocchino di 39 anni senza fissa dimora sul territorio,', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Origin - TC', 'Age', 'Other category']}, 'id': 'nrL5MEg3ix', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_22gen2023_R.em 91
# Chiara_full_dataset/chiara/output-RdC_22gen2023_R.em_LS-id91.csv
# RdC_22gen2023_R.em_b 92
# Chiara_full_dataset/chiara/output-RdC_22gen2023_R.em_b_LS-id92.csv
# RdC_23feb2023_Bo 93
# Chiara_full_dataset/chiara/output-RdC_23feb2023_Bo_LS-id93.csv
# RdC_23feb2023_Bo_b 94
# Chiara_full_dataset/chiara/output-RdC_23feb2023_Bo_b_LS-id94.csv
# RdC_23feb2023_Bo_c 95
# Chiara_full_dataset/chiara/output-RdC_23feb2023_Bo_c_LS-id95.csv
# found 322
# [{'value': {'start': 315, 'end': 349, 'text': 'Gli operatori della squadra mobile', 'labels': ['Target-category-reference']}, 'id': 'wNTbszs752', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 315, 'end': 349, 'text': 'Gli operatori della squadra mobile', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Other']}, 'id': 'wNTbszs752', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_24gen2023_Fc 97
# Chiara_full_dataset/chiara/output-RdC_24gen2023_Fc_LS-id97.csv
# RdC_24gen2023_R.em 98
# Chiara_full_dataset/chiara/output-RdC_24gen2023_R.em_LS-id98.csv
# RdC_25feb2023_Im 99
# Chiara_full_dataset/chiara/output-RdC_25feb2023_Im_LS-id99.csv
# RdC_25gen2023_R.em_b 101
# Chiara_full_dataset/chiara/output-RdC_25gen2023_R.em_b_LS-id101.csv
# found 322
# [{'value': {'start': 297, 'end': 392, 'text': 'un 51enne originario della Repubblica Dominicana, denunciato per detenzione ai fini di spaccio.', 'labels': ['Target-category-reference']}, 'meta': {'text': ['Outgroup categorization: age + gender + origin + "profession" (4 categories)                     Outgroup origin: Repubblica Dominicana']}, 'id': 'Eli5yoZe4i', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 297, 'end': 392, 'text': 'un 51enne originario della Repubblica Dominicana, denunciato per detenzione ai fini di spaccio.', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Origin - TC', 'Age', 'Activity']}, 'meta': {'text': ['Outgroup categorization: age + gender + origin + "profession" (4 categories)                     Outgroup origin: Repubblica Dominicana']}, 'id': 'Eli5yoZe4i', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_25gen2023_R.em_c 102
# Chiara_full_dataset/chiara/output-RdC_25gen2023_R.em_c_LS-id102.csv
# RdC_26feb2023_Bo 103
# Chiara_full_dataset/chiara/output-RdC_26feb2023_Bo_LS-id103.csv
# RdC_27gen2023_Fe 104
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Fe_LS-id104.csv
# RdC_27gen2023_Mo 105
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Mo_LS-id105.csv
# RdC_27gen2023_Ra_b 106
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Ra_b_LS-id106.csv
# found 322
# [{'value': {'start': 312, 'end': 329, 'text': 'periodo di lavoro', 'labels': ['Behavior-predicate']}, 'id': 'MhnVAcmaD8', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 312, 'end': 329, 'text': 'periodo di lavoro', 'choices': ['Neutral', 'Outgroup', 'Profession']}, 'id': 'MhnVAcmaD8', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_27gen2023_Ra_c 107
# Chiara_full_dataset/chiara/output-RdC_27gen2023_Ra_c_LS-id107.csv
# found 322
# [{'value': {'start': 313, 'end': 323, 'text': 'presentano', 'labels': ['Behavior-predicate']}, 'id': '3wYqsbJRSL', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 313, 'end': 323, 'text': 'presentano', 'choices': ['OBS-BH', 'Neutral', 'Ingroup', 'Outgroup']}, 'id': '3wYqsbJRSL', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_28gen2023_Ra 109
# Chiara_full_dataset/chiara/output-RdC_28gen2023_Ra_LS-id109.csv
# RdC_31gen2023_Mo_b 110
# Chiara_full_dataset/chiara/output-RdC_31gen2023_Mo_b_LS-id110.csv
# Co_01feb2023_P.12 111
# Chiara_full_dataset/chiara/output-Co_01feb2023_P.12_LS-id111.csv
# Co_01mar2023_P.1 112
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.1_LS-id112.csv
# Co_01mar2023_P.1_b 113
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.1_b_LS-id113.csv
# Co_01mar2023_P.1_c 114
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.1_c_LS-id114.csv
# Co_01mar2023_P.4 115
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.4_LS-id115.csv
# Co_01mar2023_P.5 116
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.5_LS-id116.csv
# Co_01mar2023_P.6 117
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.6_LS-id117.csv
# found 322
# [{'value': {'start': 315, 'end': 332, 'text': 'Antonino Grazioso', 'labels': ['Target-category-reference']}, 'id': 'UOKwQD52Ig', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 315, 'end': 332, 'text': 'Antonino Grazioso', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Prosocial behavior', 'Proper noun']}, 'id': 'UOKwQD52Ig', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_01mar2023_P.7 118
# Chiara_full_dataset/chiara/output-Co_01mar2023_P.7_LS-id118.csv
# Co_02feb2023_P.17 119
# Chiara_full_dataset/chiara/output-Co_02feb2023_P.17_LS-id119.csv
# Co_02feb2023_P.17_b 120
# Chiara_full_dataset/chiara/output-Co_02feb2023_P.17_b_LS-id120.csv
# Co_02mar2023_P.5 121
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.5_LS-id121.csv
# found 322
# [{'value': {'start': 316, 'end': 324, 'text': 'quadrato', 'labels': ['Behavior-predicate']}, 'id': 'aB4FQfRf8A', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 316, 'end': 324, 'text': 'quadrato', 'choices': ['CAT-BH', 'Neutral', 'Ingroup']}, 'id': 'aB4FQfRf8A', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_02mar2023_P.5_b 122
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.5_b_LS-id122.csv
# found 322
# [{'value': {'start': 307, 'end': 372, 'text': 'governo e nei partiti di maggioranza, Fratelli d’Italia in primis', 'labels': ['Target-category-reference']}, 'id': 'BtC67II5ZC', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 307, 'end': 372, 'text': 'governo e nei partiti di maggioranza, Fratelli d’Italia in primis', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession']}, 'id': 'BtC67II5ZC', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_02mar2023_P.6 123
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.6_LS-id123.csv
# Co_02mar2023_P.8 124
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.8_LS-id124.csv
# Co_02mar2023_P.8_b 125
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.8_b_LS-id125.csv
# found 322
# [{'value': {'start': 233, 'end': 372, 'text': 'Il procuratore della Repubblica di Crotone, Giuseppe Capoccia, chiamato a dare risposte ai tanti perché sulla tragedia di Stoccato di Cutro', 'labels': ['Target-category-reference']}, 'id': 'n-MOK4cxy6', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 233, 'end': 372, 'text': 'Il procuratore della Repubblica di Crotone, Giuseppe Capoccia, chiamato a dare risposte ai tanti perché sulla tragedia di Stoccato di Cutro', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession', 'Proper noun']}, 'id': 'n-MOK4cxy6', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_02mar2023_P.9 126
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.9_LS-id126.csv
# Co_02mar2023_P.9_b 127
# Chiara_full_dataset/chiara/output-Co_02mar2023_P.9_b_LS-id127.csv
# found 322
# [{'value': {'start': 321, 'end': 323, 'text': 'ci', 'labels': ['Target-category-reference']}, 'id': '2k6PV8xKPF', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 323, 'text': 'ci', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Plural pronoun']}, 'id': '2k6PV8xKPF', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_03feb2023_P.9 128
# Chiara_full_dataset/chiara/output-Co_03feb2023_P.9_LS-id128.csv
# Co_04feb2023_P.15 129
# Chiara_full_dataset/chiara/output-Co_04feb2023_P.15_LS-id129.csv
# found 322
# [{'value': {'start': 320, 'end': 326, 'text': 'caduto', 'labels': ['Behavior-predicate']}, 'id': '_WI9C8VsPK', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 320, 'end': 326, 'text': 'caduto', 'choices': ['OBS-BH', 'Neutral', 'Outgroup']}, 'id': '_WI9C8VsPK', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_04feb2023_P.6 130
# Chiara_full_dataset/chiara/output-Co_04feb2023_P.6_LS-id130.csv
# found 322
# [{'value': {'start': 313, 'end': 327, 'text': 'Giorgia Meloni', 'labels': ['Target-category-reference']}, 'id': 'mRHgp27oxB', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 313, 'end': 327, 'text': 'Giorgia Meloni', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Proper noun']}, 'id': 'mRHgp27oxB', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_08feb2023_P.18 131
# Chiara_full_dataset/chiara/output-Co_08feb2023_P.18_LS-id131.csv
# found 322
# [{'value': {'start': 321, 'end': 327, 'text': 'uscire', 'labels': ['Behavior-predicate']}, 'id': 'W4JjsCiJU2', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 327, 'text': 'uscire', 'choices': ['OBS-BH', 'Neutral', 'Outgroup']}, 'id': 'W4JjsCiJU2', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_10gen2023_P.3 132
# Chiara_full_dataset/chiara/output-Co_10gen2023_P.3_LS-id132.csv
# Co_10gen2023_P.6 133
# Chiara_full_dataset/chiara/output-Co_10gen2023_P.6_LS-id133.csv
# Co_11gen2023_P.11 134
# Chiara_full_dataset/chiara/output-Co_11gen2023_P.11_LS-id134.csv
# Co_11gen2023_P.16 135
# Chiara_full_dataset/chiara/output-Co_11gen2023_P.16_LS-id135.csv
# Co_11gen2023_P.4 136
# Chiara_full_dataset/chiara/output-Co_11gen2023_P.4_LS-id136.csv
# found 322
# [{'value': {'start': 319, 'end': 327, 'text': 'sintonia', 'labels': ['Behavior-predicate']}, 'id': 'tq45n4LJNY', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 319, 'end': 327, 'text': 'sintonia', 'choices': ['MENT-ST', 'Neutral', 'Ingroup']}, 'id': 'tq45n4LJNY', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_12feb2023_P.21 137
# Chiara_full_dataset/chiara/output-Co_12feb2023_P.21_LS-id137.csv
# Co_12feb2023_P.45 138
# Chiara_full_dataset/chiara/output-Co_12feb2023_P.45_LS-id138.csv
# Co_12gen2023_P.17 139
# Chiara_full_dataset/chiara/output-Co_12gen2023_P.17_LS-id139.csv
# found 322
# [{'value': {'start': 311, 'end': 344, 'text': 'un tunisino con un figlio piccolo', 'labels': ['Behavior-predicate']}, 'id': 'AP5jBtLTyl', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 311, 'end': 344, 'text': 'un tunisino con un figlio piccolo', 'choices': ['Neutral', 'Outgroup', 'Origin - TC', 'Family role']}, 'id': 'AP5jBtLTyl', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_14gen2023_P.8 140
# Chiara_full_dataset/chiara/output-Co_14gen2023_P.8_LS-id140.csv
# found 322
# [{'value': {'start': 318, 'end': 326, 'text': 'migranti', 'labels': ['Target-category-reference']}, 'id': 'b3geuuaGyf', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 326, 'text': 'migranti', 'choices': ['high-TC', 'Neutral', 'Outgroup', 'Other']}, 'id': 'b3geuuaGyf', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_14gen2023_P.9 141
# Chiara_full_dataset/chiara/output-Co_14gen2023_P.9_LS-id141.csv
# found 322
# [{'value': {'start': 314, 'end': 323, 'text': 'ritrovano', 'labels': ['Behavior-predicate']}, 'id': 'p-_04Tqilp', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 314, 'end': 323, 'text': 'ritrovano', 'choices': ['OBS-BH', 'Neutral', 'Ingroup']}, 'id': 'p-_04Tqilp', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_16feb2023_P.14 142
# Chiara_full_dataset/chiara/output-Co_16feb2023_P.14_LS-id142.csv
# Co_16feb2023_P.14_b 143
# Chiara_full_dataset/chiara/output-Co_16feb2023_P.14_b_LS-id143.csv
# Co_16feb2023_P.20 144
# Chiara_full_dataset/chiara/output-Co_16feb2023_P.20_LS-id144.csv
# found 322
# [{'value': {'start': 313, 'end': 326, 'text': 'devastandogli', 'labels': ['Behavior-predicate']}, 'id': '0QJFu2vP5-', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 313, 'end': 326, 'text': 'devastandogli', 'choices': ['CAT-BH', 'Negative', 'Ingroup']}, 'id': '0QJFu2vP5-', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_18gen2023_P.15 145
# Chiara_full_dataset/chiara/output-Co_18gen2023_P.15_LS-id145.csv
# Co_19feb2023_P.14 146
# Chiara_full_dataset/chiara/output-Co_19feb2023_P.14_LS-id146.csv
# found 322
# [{'value': {'start': 313, 'end': 434, 'text': 'Ayman Serti, il sedicenne di origine marocchina morto carbonizzato giovedì a Merì, piccolo centro in provincia di Messina', 'labels': ['Target-category-reference']}, 'id': 'u_iP3R7wZ9', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 313, 'end': 434, 'text': 'Ayman Serti, il sedicenne di origine marocchina morto carbonizzato giovedì a Merì, piccolo centro in provincia di Messina', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Victim', 'Origin - TC', 'Age', 'Proper noun']}, 'id': 'u_iP3R7wZ9', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_20feb2023_P.16 147
# Chiara_full_dataset/chiara/output-Co_20feb2023_P.16_LS-id147.csv
# found 322
# [{'value': {'start': 318, 'end': 329, 'text': 'trattamento', 'labels': ['Behavior-predicate']}, 'id': 'MNrd2C-GFF', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 329, 'text': 'trattamento', 'choices': ['CAT-BH', 'Negative', 'Ingroup']}, 'id': 'MNrd2C-GFF', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_22feb2023_P.20 148
# Chiara_full_dataset/chiara/output-Co_22feb2023_P.20_LS-id148.csv
# Co_22feb2023_P.21 149
# Chiara_full_dataset/chiara/output-Co_22feb2023_P.21_LS-id149.csv
# Co_23feb2023_P.19 150
# Chiara_full_dataset/chiara/output-Co_23feb2023_P.19_LS-id150.csv
# found 322
# [{'value': {'start': 318, 'end': 326, 'text': 'tensione', 'labels': ['Behavior-predicate']}, 'id': 'zKLAsIIFmy', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 326, 'text': 'tensione', 'choices': ['MENT-ST', 'Neutral', 'Ingroup']}, 'id': 'zKLAsIIFmy', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_23gen2023_P.16 151
# Chiara_full_dataset/chiara/output-Co_23gen2023_P.16_LS-id151.csv
# Co_24feb2023_P.20 152
# Chiara_full_dataset/chiara/output-Co_24feb2023_P.20_LS-id152.csv
# Co_24gen2023_P.15 153
# Chiara_full_dataset/chiara/output-Co_24gen2023_P.15_LS-id153.csv
# Co_24gen2023_P.19 154
# Chiara_full_dataset/chiara/output-Co_24gen2023_P.19_LS-id154.csv
# found 322
# [{'value': {'start': 316, 'end': 326, 'text': 'far morire', 'labels': ['Behavior-predicate']}, 'id': 'j_Q_kwSDk6', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 316, 'end': 326, 'text': 'far morire', 'choices': ['CAT-BH', 'Neutral', 'Outgroup']}, 'id': 'j_Q_kwSDk6', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_25feb2023_P.27 155
# Chiara_full_dataset/chiara/output-Co_25feb2023_P.27_LS-id155.csv
# Co_25gen2023_P.11 156
# Chiara_full_dataset/chiara/output-Co_25gen2023_P.11_LS-id156.csv
# Co_25gen2023_P.18 157
# Chiara_full_dataset/chiara/output-Co_25gen2023_P.18_LS-id157.csv
# found 322
# [{'value': {'start': 322, 'end': 325, 'text': 'che', 'labels': ['Target-category-reference']}, 'id': 'PDgUTZ75U5', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 322, 'end': 325, 'text': 'che', 'choices': ['individual-TC', 'Neutral', 'Singular pronoun']}, 'id': 'PDgUTZ75U5', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_25gen2023_P.27 158
# Chiara_full_dataset/chiara/output-Co_25gen2023_P.27_LS-id158.csv
# Co_26feb2023_P.15 159
# Chiara_full_dataset/chiara/output-Co_26feb2023_P.15_LS-id159.csv
# found 322
# [{'value': {'start': 319, 'end': 326, 'text': 'vittima', 'labels': ['Target-category-reference']}, 'id': 'NCR9iFEUyi', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 319, 'end': 326, 'text': 'vittima', 'choices': ['individual-TC', 'Neutral', 'Activity']}, 'id': 'NCR9iFEUyi', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_26feb2023_P.16 160
# Chiara_full_dataset/chiara/output-Co_26feb2023_P.16_LS-id160.csv
# found 322
# [{'value': {'start': 319, 'end': 329, 'text': 'Alice Neri', 'labels': ['Target-category-reference']}, 'id': 'dY6IMlcgSh', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 319, 'end': 329, 'text': 'Alice Neri', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Victim', 'Proper noun']}, 'id': 'dY6IMlcgSh', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_26gen2023_P.14 161
# Chiara_full_dataset/chiara/output-Co_26gen2023_P.14_LS-id161.csv
# Co_26gen2023_P.14_b 162
# Chiara_full_dataset/chiara/output-Co_26gen2023_P.14_b_LS-id162.csv
# found 322
# [{'value': {'start': 313, 'end': 328, 'text': 'Dumitru Stratan', 'labels': ['Target-category-reference']}, 'id': 'qHFnVaeGf3', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 313, 'end': 328, 'text': 'Dumitru Stratan', 'choices': ['individual-TC', 'Neutral', 'Proper noun']}, 'id': 'qHFnVaeGf3', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_27feb2023_P.2 163
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.2_LS-id163.csv
# Co_27feb2023_P.2_b 164
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.2_b_LS-id164.csv
# found 322
# [{'value': {'start': 320, 'end': 349, 'text': 'i bambini morti nel naufragio', 'labels': ['Target-category-reference']}, 'id': 'C9eALhkwJv', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 320, 'end': 349, 'text': 'i bambini morti nel naufragio', 'choices': ['middle-TC', 'Neutral', 'Outgroup', 'Victim', 'Age']}, 'id': 'C9eALhkwJv', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_27feb2023_P.3 165
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.3_LS-id165.csv
# Co_27feb2023_P.3_b 166
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.3_b_LS-id166.csv
# found 322
# [{'value': {'start': 304, 'end': 325, 'text': 'Lei e suo marito Aziz', 'labels': ['Target-category-reference']}, 'id': 'V2EkfZ8El3', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 304, 'end': 325, 'text': 'Lei e suo marito Aziz', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Victim', 'Family role', 'Proper noun']}, 'id': 'V2EkfZ8El3', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_27feb2023_P.5 167
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.5_LS-id167.csv
# Co_27feb2023_P.5_b 168
# Chiara_full_dataset/chiara/output-Co_27feb2023_P.5_b_LS-id168.csv
# found 322
# [{'value': {'start': 321, 'end': 329, 'text': 'sbarcati', 'labels': ['Behavior-predicate']}, 'id': 'kImNgXJ4Ly', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 329, 'text': 'sbarcati', 'choices': ['OBS-BH', 'Neutral', 'Outgroup']}, 'id': 'kImNgXJ4Ly', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_27gen2023_P.10 169
# Chiara_full_dataset/chiara/output-Co_27gen2023_P.10_LS-id169.csv
# Co_27gen2023_P.18 170
# Chiara_full_dataset/chiara/output-Co_27gen2023_P.18_LS-id170.csv
# Co_28feb2023_P.2 171
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.2_LS-id171.csv
# Co_28feb2023_P.2_b 172
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.2_b_LS-id172.csv
# found 322
# [{'value': {'start': 295, 'end': 323, 'text': 'Javed, un afghano di 43 anni', 'labels': ['Target-category-reference']}, 'id': '6C8PjBuInN', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 295, 'end': 323, 'text': 'Javed, un afghano di 43 anni', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Victim', 'Origin - TC', 'Age', 'Proper noun']}, 'id': '6C8PjBuInN', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_28feb2023_P.3 173
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.3_LS-id173.csv
# Co_28feb2023_P.5 174
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.5_LS-id174.csv
# found 322
# [{'value': {'start': 321, 'end': 331, 'text': 'i capitani', 'labels': ['Behavior-predicate']}, 'id': 'e9RGryA9uj', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 331, 'text': 'i capitani', 'choices': ['Neutral', 'Outgroup', 'Profession']}, 'id': 'e9RGryA9uj', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Co_28feb2023_P.5_b 175
# Chiara_full_dataset/chiara/output-Co_28feb2023_P.5_b_LS-id175.csv
# Co_29gen2023_P.18 176
# Chiara_full_dataset/chiara/output-Co_29gen2023_P.18_LS-id176.csv
# Co_29gen2023_P.5 177
# Chiara_full_dataset/chiara/output-Co_29gen2023_P.5_LS-id177.csv
# Co_29gen2023_P.7 178
# Chiara_full_dataset/chiara/output-Co_29gen2023_P.7_LS-id178.csv
# Co_31gen2023_P.5 179
# Chiara_full_dataset/chiara/output-Co_31gen2023_P.5_LS-id179.csv
# Co_31gen2023_P.5_b 180
# Chiara_full_dataset/chiara/output-Co_31gen2023_P.5_b_LS-id180.csv
# Co_31gen2023_P.5_c 181
# Chiara_full_dataset/chiara/output-Co_31gen2023_P.5_c_LS-id181.csv
# Re_01mar2023_P.2 182
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.2_LS-id182.csv
# Re_01mar2023_P.3 183
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.3_LS-id183.csv
# Re_01mar2023_P.4 184
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.4_LS-id184.csv
# Re_01mar2023_P.4_b 185
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.4_b_LS-id185.csv
# Re_01mar2023_P.6 186
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.6_LS-id186.csv
# Re_01mar2023_P.6_b 187
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.6_b_LS-id187.csv
# found 322
# [{'value': {'start': 260, 'end': 368, 'text': "potente responsabile dell'Agricoltura Francesco Lollobrigida, forse il dirigente più vicino a Giorgia Meloni", 'labels': ['Target-category-reference']}, 'id': 'Q9u_aG3CO4', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 260, 'end': 368, 'text': "potente responsabile dell'Agricoltura Francesco Lollobrigida, forse il dirigente più vicino a Giorgia Meloni", 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession', 'Proper noun']}, 'id': 'Q9u_aG3CO4', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_01mar2023_P.7 188
# Chiara_full_dataset/chiara/output-Re_01mar2023_P.7_LS-id188.csv
# Re_02feb2023_P.18 189
# Chiara_full_dataset/chiara/output-Re_02feb2023_P.18_LS-id189.csv
# Re_02feb2023_P.18_b 190
# Chiara_full_dataset/chiara/output-Re_02feb2023_P.18_b_LS-id190.csv
# Re_02mar2023_P.2 191
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.2_LS-id191.csv
# Re_02mar2023_P.23 192
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.23_LS-id192.csv
# Re_02mar2023_P.3 193
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.3_LS-id193.csv
# Re_02mar2023_P.3_b 194
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.3_b_LS-id194.csv
# Re_02mar2023_P.4 195
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.4_LS-id195.csv
# Re_02mar2023_P.4_b 196
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.4_b_LS-id196.csv
# Re_02mar2023_P.5 197
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.5_LS-id197.csv
# found 322
# [{'value': {'start': 317, 'end': 331, 'text': 'Matteo Salvini', 'labels': ['Target-category-reference']}, 'id': 'JYUG65MP-y', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 317, 'end': 331, 'text': 'Matteo Salvini', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Proper noun']}, 'id': 'JYUG65MP-y', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_02mar2023_P.7 198
# Chiara_full_dataset/chiara/output-Re_02mar2023_P.7_LS-id198.csv
# Re_04feb2023_P.19 199
# Chiara_full_dataset/chiara/output-Re_04feb2023_P.19_LS-id199.csv
# Re_05feb2023_P.13 200
# Chiara_full_dataset/chiara/output-Re_05feb2023_P.13_LS-id200.csv
# Re_06feb2023_P.20 201
# Chiara_full_dataset/chiara/output-Re_06feb2023_P.20_LS-id201.csv
# found 322
# [{'value': {'start': 322, 'end': 342, 'text': 'sua (ignara) maestra', 'labels': ['Target-category-reference']}, 'id': 'tLsF1FcBvX', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 322, 'end': 342, 'text': 'sua (ignara) maestra', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession']}, 'id': 'tLsF1FcBvX', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_07feb2023_P.18 202
# Chiara_full_dataset/chiara/output-Re_07feb2023_P.18_LS-id202.csv
# Re_08feb2023_P.5 203
# Chiara_full_dataset/chiara/output-Re_08feb2023_P.5_LS-id203.csv
# Re_10feb2023_P.7 204
# Chiara_full_dataset/chiara/output-Re_10feb2023_P.7_LS-id204.csv
# Re_10feb2023_P.7_b 205
# Chiara_full_dataset/chiara/output-Re_10feb2023_P.7_b_LS-id205.csv
# found 322
# [{'value': {'start': 319, 'end': 328, 'text': 'richiesta', 'labels': ['Behavior-predicate']}, 'id': 'lRiaTGfcci', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 319, 'end': 328, 'text': 'richiesta', 'choices': ['CAT-BH', 'Neutral', 'Outgroup']}, 'id': 'lRiaTGfcci', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_10gen2023_P.12 206
# Chiara_full_dataset/chiara/output-Re_10gen2023_P.12_LS-id206.csv
# Re_10gen2023_P.13 207
# Chiara_full_dataset/chiara/output-Re_10gen2023_P.13_LS-id207.csv
# found 322
# [{'value': {'start': 306, 'end': 323, 'text': 'La bimba ivoriana', 'labels': ['Target-category-reference']}, 'id': 'h2jFFXfKvj', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 306, 'end': 323, 'text': 'La bimba ivoriana', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Victim', 'Origin - TC', 'Age']}, 'id': 'h2jFFXfKvj', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_11feb2023_P.2 208
# Chiara_full_dataset/chiara/output-Re_11feb2023_P.2_LS-id208.csv
# Re_11feb2023_P.5 209
# Chiara_full_dataset/chiara/output-Re_11feb2023_P.5_LS-id209.csv
# Re_11gen2023_P.25 210
# Chiara_full_dataset/chiara/output-Re_11gen2023_P.25_LS-id210.csv
# Re_11gen2023_P.26 211
# Chiara_full_dataset/chiara/output-Re_11gen2023_P.26_LS-id211.csv
# Re_12feb2023_P.9 212
# Chiara_full_dataset/chiara/output-Re_12feb2023_P.9_LS-id212.csv
# Re_12gen2023_P.23 213
# Chiara_full_dataset/chiara/output-Re_12gen2023_P.23_LS-id213.csv
# Re_13feb2023_P.21 214
# Chiara_full_dataset/chiara/output-Re_13feb2023_P.21_LS-id214.csv
# found 322
# [{'value': {'start': 321, 'end': 340, 'text': 'Valentin Fagarasian', 'labels': ['Target-category-reference']}, 'id': 'mtDMiX3NNg', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 340, 'text': 'Valentin Fagarasian', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Other', 'Profession', 'Proper noun']}, 'id': 'mtDMiX3NNg', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_13feb2023_P.21_b 215
# Chiara_full_dataset/chiara/output-Re_13feb2023_P.21_b_LS-id215.csv
# Re_14gen2023_P.28 216
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.28_LS-id216.csv
# Re_14gen2023_P.6 217
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.6_LS-id217.csv
# Re_14gen2023_P.7 218
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.7_LS-id218.csv
# Re_14gen2023_P.7_b 219
# Chiara_full_dataset/chiara/output-Re_14gen2023_P.7_b_LS-id219.csv
# found 322
# [{'value': {'start': 281, 'end': 325, 'text': "l'ex presidente del Consiglio Giuseppe Conte", 'labels': ['Target-category-reference']}, 'id': '2VOGO3TgE4', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 281, 'end': 325, 'text': "l'ex presidente del Consiglio Giuseppe Conte", 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession', 'Proper noun']}, 'id': '2VOGO3TgE4', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_15feb2023_P.31 220
# Chiara_full_dataset/chiara/output-Re_15feb2023_P.31_LS-id220.csv
# Re_15gen2023_P.10 221
# Chiara_full_dataset/chiara/output-Re_15gen2023_P.10_LS-id221.csv
# Re_15gen2023_P.7 222
# Chiara_full_dataset/chiara/output-Re_15gen2023_P.7_LS-id222.csv
# found 322
# [{'value': {'start': 316, 'end': 349, 'text': 'nostre ambasciate e dai consolati', 'labels': ['Target-category-reference']}, 'id': 'qmglWwLncL', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 316, 'end': 349, 'text': 'nostre ambasciate e dai consolati', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession']}, 'id': 'qmglWwLncL', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_16gen2023_P.12 223
# Chiara_full_dataset/chiara/output-Re_16gen2023_P.12_LS-id223.csv
# Re_19feb2023_P.14 224
# Chiara_full_dataset/chiara/output-Re_19feb2023_P.14_LS-id224.csv
# found 322
# [{'value': {'start': 317, 'end': 351, 'text': 'Antonio Tajani e Matteo Piantedosi', 'labels': ['Target-category-reference']}, 'id': 'RHzouPDroL', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 317, 'end': 351, 'text': 'Antonio Tajani e Matteo Piantedosi', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Proper noun']}, 'id': 'RHzouPDroL', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_19gen2023-P.15 225
# Chiara_full_dataset/chiara/output-Re_19gen2023-P.15_LS-id225.csv
# found 322
# [{'value': {'start': 286, 'end': 406, 'text': 'Antonio Tajani, ministro degli Esteri e vicepresidente del consiglio, e di Matteo Piantedosi, responsabile degli Interni', 'labels': ['Target-category-reference']}, 'id': 'GI83767ghF', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 286, 'end': 406, 'text': 'Antonio Tajani, ministro degli Esteri e vicepresidente del consiglio, e di Matteo Piantedosi, responsabile degli Interni', 'choices': ['individual-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession', 'Proper noun']}, 'id': 'GI83767ghF', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_20feb2023_P.26 226
# Chiara_full_dataset/chiara/output-Re_20feb2023_P.26_LS-id226.csv
# found 322
# [{'value': {'start': 307, 'end': 344, 'text': 'settanta migranti (la metà minorenni)', 'labels': ['Target-category-reference']}, 'id': '1DuiWweEjM', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 307, 'end': 344, 'text': 'settanta migranti (la metà minorenni)', 'choices': ['middle-TC', 'Neutral', 'Outgroup', 'Victim', 'Age']}, 'id': '1DuiWweEjM', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_22feb2023_P.20 227
# Chiara_full_dataset/chiara/output-Re_22feb2023_P.20_LS-id227.csv
# found 322
# [{'value': {'start': 322, 'end': 339, 'text': 'tutta la famiglia', 'labels': ['Target-category-reference']}, 'id': 'mEEl7xki0B', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 322, 'end': 339, 'text': 'tutta la famiglia', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Perpetrator', 'Family role']}, 'id': 'mEEl7xki0B', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_23feb2023_P.17 228
# Chiara_full_dataset/chiara/output-Re_23feb2023_P.17_LS-id228.csv
# found 322
# [{'value': {'start': 321, 'end': 340, 'text': 'Il 33enne nigeriano', 'labels': ['Target-category-reference']}, 'id': 'Uyc_xQHbdG', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 340, 'text': 'Il 33enne nigeriano', 'choices': ['individual-TC', 'Neutral', 'Origin - TC', 'Age']}, 'id': 'Uyc_xQHbdG', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_25feb2023_P.38 229
# Chiara_full_dataset/chiara/output-Re_25feb2023_P.38_LS-id229.csv
# found 322
# [{'value': {'start': 318, 'end': 329, 'text': 'irritazione', 'labels': ['Behavior-predicate']}, 'id': '-Ked1M6QSt', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 329, 'text': 'irritazione', 'choices': ['MENT-ST', 'Neutral', 'Ingroup']}, 'id': '-Ked1M6QSt', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_25gen2023_P.11 230
# Chiara_full_dataset/chiara/output-Re_25gen2023_P.11_LS-id230.csv
# Re_26gen2023_P.16 231
# Chiara_full_dataset/chiara/output-Re_26gen2023_P.16_LS-id231.csv
# Re_26gen2023_P.16_b 232
# Chiara_full_dataset/chiara/output-Re_26gen2023_P.16_b_LS-id232.csv
# Re_27feb2023_P.2 233
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.2_LS-id233.csv
# Re_27feb2023_P.26 234
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.26_LS-id234.csv
# Re_27feb2023_P.3 235
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.3_LS-id235.csv
# found 322
# [{'value': {'start': 321, 'end': 330, 'text': 'sconvolto', 'labels': ['Behavior-predicate']}, 'id': 'xC_3fajLiN', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 330, 'text': 'sconvolto', 'choices': ['MENT-ST', 'Neutral', 'Ingroup']}, 'id': 'xC_3fajLiN', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_27feb2023_P.5 236
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.5_LS-id236.csv
# found 322
# [{'value': {'start': 322, 'end': 415, 'text': 'vittima numero quattordici, femmina, età stimata nove anni, era una bambina castana e paffuta', 'labels': ['Target-category-reference']}, 'id': 'vzKB-ejvBN', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 322, 'end': 415, 'text': 'vittima numero quattordici, femmina, età stimata nove anni, era una bambina castana e paffuta', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Victim', 'Gender', 'Age', 'Other category']}, 'id': 'vzKB-ejvBN', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_27feb2023_P.6 237
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.6_LS-id237.csv
# Re_27feb2023_P.7 238
# Chiara_full_dataset/chiara/output-Re_27feb2023_P.7_LS-id238.csv
# Re_27gen2023_P.4 239
# Chiara_full_dataset/chiara/output-Re_27gen2023_P.4_LS-id239.csv
# Re_27gen2023_P.6 240
# Chiara_full_dataset/chiara/output-Re_27gen2023_P.6_LS-id240.csv
# Re_28feb2023_P.12 241
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.12_LS-id241.csv
# Re_28feb2023_P.12_b 242
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.12_b_LS-id242.csv
# Re_28feb2023_P.13 243
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.13_LS-id243.csv
# Re_28feb2023_P.15 244
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.15_LS-id244.csv
# Re_28feb2023_P.26 245
# Chiara_full_dataset/chiara/output-Re_28feb2023_P.26_LS-id245.csv
# Re_28gen2023_P.8 246
# Chiara_full_dataset/chiara/output-Re_28gen2023_P.8_LS-id246.csv
# found 322
# [{'value': {'start': 321, 'end': 325, 'text': 'tifa', 'labels': ['Behavior-predicate']}, 'id': '3SZoJxgICB', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 321, 'end': 325, 'text': 'tifa', 'choices': ['CAT-BH', 'Neutral', 'Ingroup']}, 'id': '3SZoJxgICB', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# Re_29gen2023_P.12 247
# Chiara_full_dataset/chiara/output-Re_29gen2023_P.12_LS-id247.csv
# RdC_07feb2023_Bo 248
# Chiara_full_dataset/chiara/output-RdC_07feb2023_Bo_LS-id248.csv
# found 322
# [{'value': {'start': 320, 'end': 329, 'text': 'controllo', 'labels': ['Behavior-predicate']}, 'id': '9IOkTjkk5f', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 320, 'end': 329, 'text': 'controllo', 'choices': ['CAT-BH', 'Neutral', 'Ingroup']}, 'id': '9IOkTjkk5f', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_14gen2023_R.em 249
# Chiara_full_dataset/chiara/output-RdC_14gen2023_R.em_LS-id249.csv
# found 322
# [{'value': {'start': 248, 'end': 323, 'text': 'lui, Ahmed Charguia, 19enne nato in Tunisia e residente a Sassuolo (Modena)', 'labels': ['Target-category-reference']}, 'id': '9lVg2sSXb-', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 248, 'end': 323, 'text': 'lui, Ahmed Charguia, 19enne nato in Tunisia e residente a Sassuolo (Modena)', 'choices': ['individual-TC', 'Neutral', 'Outgroup', 'Perpetrator', 'Origin - TC', 'Residency', 'Age', 'Proper noun']}, 'id': '9lVg2sSXb-', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_16feb2023_Bo 250
# Chiara_full_dataset/chiara/output-RdC_16feb2023_Bo_LS-id250.csv
# found 322
# [{'value': {'start': 313, 'end': 324, 'text': 'intervenute', 'labels': ['Behavior-predicate']}, 'id': 'VWYjOoVRdq', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 313, 'end': 324, 'text': 'intervenute', 'choices': ['CAT-BH', 'Neutral', 'Ingroup']}, 'id': 'VWYjOoVRdq', 'from_name': 'LCM-behavior', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_17gen2023_Ri_b 251
# Chiara_full_dataset/chiara/output-RdC_17gen2023_Ri_b_LS-id251.csv
# found 322
# [{'value': {'start': 318, 'end': 337, 'text': 'la polizia di Stato', 'labels': ['Target-category-reference']}, 'id': 'L5Lr41BDNw', 'from_name': 'label', 'to_name': 'text', 'type': 'labels', 'origin': 'manual'}, {'value': {'start': 318, 'end': 337, 'text': 'la polizia di Stato', 'choices': ['middle-TC', 'Neutral', 'Ingroup', 'Istitutional actor', 'Profession']}, 'id': 'L5Lr41BDNw', 'from_name': 'TG-levels', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# RdC_28gen2023_Mo 252
# Chiara_full_dataset/chiara/output-RdC_28gen2023_Mo_LS-id252.csv

# %%
# tok_starts
